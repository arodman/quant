# %%
#eview techncialk everythign al right
#data is update iwth the lastest
#back test of te strategy
#grpahs better
#acompare last week score with this week scores
#techncaiol talbe
#show thios weeks changes onlym#
#dd comoditites data
#add jpm data c
#tot
#add 
#scatter plot biggest changes toda vs 1 week
#todas vs 2 week 
#todasy vs 1 month 
#biggest hcanges in fx variasotn 
#####backtest for straegyu
###hacer backtest, agregado y mejros estrategies
#graph macro indicators
#graph each time series
#and copy paste pdf
#and coonnects to each pdf. 
#hsitorico de macroindicators
#grafciar series del macroindicatos
#connecxion macro indicatrs copiar pegar
###########################################################


#Valuation Difference	REER (Broad CPI Based) 10yr Avg	3M	6M
#BEER	REER Deviation from 10yr Avg	Idiosyncratic Value proxy 3M	Idiosyncratic Value proxy 6M
#Valuation Conviction ranking
#Avg of Fair Value (Over/Undervaluation)
#Carry (Swap 6M)	VRP 6M	Momentum (1W)	IRP 6M	IRP 3M	Equity Driven (3M)	Aggregated Technical Conviction Score
#Score	Aggregated Technical Conviction Score

#MacroIndicator_Overall	MacroIndicator_External (+)	Macro Ranking	Macro Indicators Conviction Ranking
#MacroIndicator (Monthly update)	MacroIndicator (Monthly update)

# %%
################
#model x independnet variables



                 
 
                 
#BBGTKR::BLOOMBERG::BASPTDSP Index
#BBGTKR::BLOOMBERG::CO1 Comdty
#BBGTKR::BLOOMBERG::COA Comdty
#BBGTKR::BLOOMBERG::DAX Index
#BBGTKR::BLOOMBERG::HG1 Comdty
#BGTKR::BLOOMBERG::HGA Comdty
#BBGTKR::BLOOMBERG::MOODCAAA Index
#BBGTKR::BLOOMBERG::MOODCBAA Index
#BBGTKR::BLOOMBERG::UKX Index
#BBGTKR::BLOOMBERG::US0003M Index
#BBGTKR::BLOOMBERG::USGG10YR Index
#BBGTKR::BLOOMBERG::USGG2YR Index
#BBGTKR::BLOOMBERG::USGG3M Index
#BBGTKR::BLOOMBERG::USGG5YR Index
#BBGTKR::BLOOMBERG::USGG7YR Index
#BBGTKR::BLOOMBERG::USGGBE05 Index
#BBGTKR::BLOOMBERG::USGGBE10 Index
#BBGTKR::BLOOMBERG::XAG Curncy
#BBGTKR::BLOOMBERG::XAU Curncy
        

#msci 
#carry
#volatiltiy risk premiua
# momentum
#idyosyncratics



#fx valuaiton
#ididysyncratics
#reer jpm
#adne beer


#macroidnicators
#real
#monetary
#fiscal
#extertla
#overall

# %%
#IMPORT PACKAGES 
import datetime as dt
from datetime import date
import pandas as pd 
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas
import pandas as pd
from datetime import date
from datetime import datetime
from mdng_client import OTReader
#####CHANGE UAT TO PROD
reader = OTReader(tz='America/New_York', env='PROD') # the timezone for start/end and returned timestamps


import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas as pd

import pandas
from datetime import datetime
from mdng_client import OTReader
reader = OTReader(tz='America/New_York', env='PROD')


import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas as pd

import pandas
from datetime import datetime
from mdng_client import OTReader
reader = OTReader(tz='America/New_York', env='PROD')


from datetime import datetime

# %%
#parameters
start = '2009-12-31'
end = datetime.today().strftime('%Y-%m-%d')

time = pd.date_range(start=start, end=end, freq='7d')
print(time)
#np.array(times)
#>>> from datetime import datetime as date
#>>> date.today().strftime("%A")
#'Monday'

#time = DataFrame(times,columns=['date'])
#print(time)
# Out:
# DatetimeIndex(['2009-12-31', '2010-01-07', '2010-01-14', '2010-01-21',
#                '2010-01-28', '2010-02-04', '2010-02-11', '2010-02-18',
#                '2010-02-25', '2010-03-04',
#                ...
#                '2021-08-05', '2021-08-12', '2021-08-19', '2021-08-26',
#                '2021-09-02', '2021-09-09', '2021-09-16', '2021-09-23',
#                '2021-09-30', '2021-10-07'],
#               dtype='datetime64[ns]', length=615, freq='7D')

# %%
#IMPORT PACKAGES 
import datetime as dt
from datetime import date
import pandas as pd 
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas
import pandas as pd
from datetime import date
from datetime import datetime
from mdng_client import OTReader
#####CHANGE UAT TO PROD
reader = OTReader(tz='America/New_York', env='PROD')

# the timezone for start/end and returned timestamps

from mdng_client.utils import format_to_melted_df
from mdng_client import OTReader
import onetick.query as otq
from datetime import datetime, timedelta
import numpy as np

reader = OTReader(tz='America/New_York', env='PROD')
reader = OTReader(tz='America/New_York', env='PROD')

import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas as pd

import pandas
from datetime import datetime
from mdng_client import OTReader
reader = OTReader(tz='America/New_York', env='PROD')

import datetime as datetime

# %%
now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# Y 2021 / M 10 / D 12 /// H 16 : M 4 : S 46

# %%
def from_name_source_as_of_time(names, source, as_of_time, is_eod):
    # need some logic to determine if they are querying EOD or intradaY
    if is_eod:
        tick_type = 'DAY' # change as needed for object
    else:
        tick_type = 'TRD'
        
    symbols = ['BBGTKR::BLOOMBERG::' + name.upper() for name in names]
    graph = otq.Graph(
            otq.Chainlet(
                otq.Passthrough().tick_type(tick_type),
                otq.WhereClause(discard_on_match=False, where="SOURCE='{}'".format(source.upper()))
            )
    )
    # interval is [start, end)
    start = as_of_time - timedelta(days=10000)
    end = as_of_time

    result = reader.run_generic_query(
        graph_or_otq=graph,
        symbols=symbols,
        start=start,
        end=end,
        symbol_date=as_of_time,
    )
    return format_to_melted_df(symbols=symbols, result=result)
########

# %%
as_of_date = datetime.datetime.today()

symbols = ['BRL CURNCY', 'CLP CURNCY','CZK CURNCY','IDR CURNCY','ILS CURNCY','INR CURNCY','KRW CURNCY','MXN CURNCY',
           'PEN CURNCY','PLN CURNCY','RUB CURNCY','HUF CURNCY','ZAR CURNCY','THB CURNCY','PHP CURNCY','TRY CURNCY',
           'CNH CURNCY','COP CURNCY','TWD CURNCY','MYR CURNCY']           
#'EUR CURNCY','GBP CURNCY','JPY CURNCY' ,'NZD CURNCY','AUD CURNCY', 'CHF CURNCY','NOK CURNCY','CAD CURNCY']        
     
test00001 = from_name_source_as_of_time(symbols, 'BGN', as_of_date, True)
test00001.drop_duplicates()
test00001 = test00001.reset_index()  
test00001["TIME"]=test00001["TIME"].dt.strftime("%Y-%m-%d")
test00001=test00001[['TIME','PX_LAST','TICKER']]
#test00001.drop_duplicates()
#test00001['TIME']=str(test00001['TIME'])               
#test00001['year'] = pd.DatetimeIndex(test00001['TIME']).year
#test00001['month'] = str(pd.DatetimeIndex(test00001['TIME']).month)
#test00001['day'] = str(pd.DatetimeIndex(test00001['TIME']).day)
#df['Dates'] = pd.to_datetime(df['Dates'], format='%y%m%d')

test00002=pd.pivot_table(test00001,index=["TIME"],values=["PX_LAST"], columns=["TICKER"],aggfunc=[np.sum])
test00002=test00002.fillna(method='bfill')
test00002=test00002.fillna(method='bfill')
#remove amount
test00002.columns = test00002.columns.droplevel(0) 
test00002.columns = test00002.columns.droplevel(0) 

test00002 = test00002.reset_index()  
test00002=test00002.set_index('TIME')
#test00002['date'] = test00002['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))


test00002=test00002.replace(to_replace=0, method='ffill')

test00002.to_csv (r'K:\2020_2431\q\sandbox_fx\fx_tmp.csv', index = True, header=True)
print("Complete!!!!")
now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# Complete!!!!
# Y 2021 / M 10 / D 12 /// H 16 : M 4 : S 53

# %%
#historical volatility
symbols = ['BBGTKR::BLOOMBERG::USDBRLH6M CURNCY','BBGTKR::BLOOMBERG::USDCLPH6M CURNCY','BBGTKR::BLOOMBERG::USDCNHH6M CURNCY',
           'BBGTKR::BLOOMBERG::USDCOPH6M CURNCY','BBGTKR::BLOOMBERG::USDCZKH6M CURNCY','BBGTKR::BLOOMBERG::USDHUFH6M CURNCY',
           'BBGTKR::BLOOMBERG::USDIDRH6M CURNCY','BBGTKR::BLOOMBERG::USDILSH6M CURNCY','BBGTKR::BLOOMBERG::USDINRH6M CURNCY',
           'BBGTKR::BLOOMBERG::USDKRWH6M CURNCY','BBGTKR::BLOOMBERG::USDMXNH6M CURNCY','BBGTKR::BLOOMBERG::USDPENH6M CURNCY',
           'BBGTKR::BLOOMBERG::USDPLNH6M CURNCY','BBGTKR::BLOOMBERG::USDRUBH6M CURNCY','BBGTKR::BLOOMBERG::USDTRYH6M CURNCY',
           'BBGTKR::BLOOMBERG::USDZARH6M CURNCY','BBGTKR::BLOOMBERG::USDTHBH6M CURNCY','BBGTKR::BLOOMBERG::USDTWDH6M CURNCY',
           'BBGTKR::BLOOMBERG::USDMYRH6M CURNCY']

fx_h =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PRICE',
                        )




fx_h.head()
fx_h=fx_h.fillna(method='bfill')
fx_h.to_csv (r'K:\2020_2431\q\sandbox_fx\fx_h_tmp.csv', index = True, header=True)
print("Complete!!!!")
now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# Complete!!!!
# Y 2021 / M 10 / D 12 /// H 16 : M 4 : S 57

# %%
##option implied volatility

symbols = ['BBGTKR::BLOOMBERG::USDBRLV6M CURNCY','BBGTKR::BLOOMBERG::USDCLPV6M CURNCY','BBGTKR::BLOOMBERG::USDCNHV6M CURNCY',
           'BBGTKR::BLOOMBERG::USDCOPV6M CURNCY','BBGTKR::BLOOMBERG::USDCZKV6M CURNCY','BBGTKR::BLOOMBERG::USDHUFV6M CURNCY',
           'BBGTKR::BLOOMBERG::USDIDRV6M CURNCY','BBGTKR::BLOOMBERG::USDILSV6M CURNCY','BBGTKR::BLOOMBERG::USDINRV6M CURNCY',
           'BBGTKR::BLOOMBERG::USDKRWV6M CURNCY','BBGTKR::BLOOMBERG::USDMXNV6M CURNCY','BBGTKR::BLOOMBERG::USDPENV6M CURNCY',
           'BBGTKR::BLOOMBERG::USDPLNV6M CURNCY','BBGTKR::BLOOMBERG::USDRUBV6M CURNCY','BBGTKR::BLOOMBERG::USDTRYV6M CURNCY',
           'BBGTKR::BLOOMBERG::USDZARV6M CURNCY','BBGTKR::BLOOMBERG::USDTHBV6M CURNCY','BBGTKR::BLOOMBERG::USDTWDV6M CURNCY',
           'BBGTKR::BLOOMBERG::USDMYRV6M CURNCY']


#s&p retunr
     ##   is stock sp500 weekly retunr#SP500 Weekly Returns	Global
fx_v =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PRICE',
                        )




fx_v.head()
fx_v=fx_v.fillna(method='bfill')
#fx_v=pd.merge(time, msci_us,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
fx_v.to_csv (r'K:\2020_2431\q\sandbox_fx\fx_v_tmp.csv', index = True, header=True)

print("Complete!!!!")
now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# Complete!!!!
# Y 2021 / M 10 / D 12 /// H 16 : M 5 : S 2

# %%
#excess carry divided vyl hostical volatiltiy1
#ODG21 Comdty - US0006M  Index / USDBRLH6M BGN Curncy

#symbols = ['BBGTKR::BLOOMBERG::ODG22 Comdty',#brl
#           'BBGTKR::BLOOMBERG::CHSWPF Curncy',#clp
#           'BBGTKR::BLOOMBERG::CNHI6M Curncy',#cnh
#           'BBGTKR::BLOOMBERG::CLNI6M Curncy',#cop
#           'BBGTKR::BLOOMBERG::CKFR0CF Curncy',#czk
#           'BBGTKR::BLOOMBERG::HFFR0CF Curncy',#huf
#           'BBGTKR::BLOOMBERG::ISFR0CF Curncy',#ils
#           'BBGTKR::BLOOMBERG::IRNI6M Curncy',#ind
#           'BBGTKR::BLOOMBERG::KWNI6M Curncy',#korea
#           'BBGTKR::BLOOMBERG::MPSWF Curncy',#mxn
##           'BBGTKR::BLOOMBERG::PSNI6M Curncy',#pen
#           'BBGTKR::BLOOMBERG::PZFR0CF Curncy',#pln
#           'BBGTKR::BLOOMBERG::MOSKP6 Index',#rub
#           'BBGTKR::BLOOMBERG::TRLIB6M Index',#try
#           'BBGTKR::BLOOMBERG::SAFR0CF Curncy',#zar
#           'BBGTKR::BLOOMBERG::TBOI6M Curncy',#thb
#           'BBGTKR::BLOOMBERG::NTNI6M Curncy',#twd
#           'BBGTKR::BLOOMBERG::MRSWNIF Curncy']#myr
#'BBGTKR::BLOOMBERG::US0006M  Index']#usd

# %%
symbols = ['BBGTKR::BLOOMBERG::ODG22 Comdty',
           'BBGTKR::BLOOMBERG::CHSWPF Curncy',
           'BBGTKR::BLOOMBERG::CNHI6M Curncy',
           'BBGTKR::BLOOMBERG::CLNI6M Curncy',
           'BBGTKR::BLOOMBERG::CKFR0CF Curncy',
           'BBGTKR::BLOOMBERG::HFFR0CF Curncy',
           'BBGTKR::BLOOMBERG::ISFR0CF Curncy',
           'BBGTKR::BLOOMBERG::IRNI6M Curncy',
           'BBGTKR::BLOOMBERG::KWNI6M Curncy',
           'BBGTKR::BLOOMBERG::MPSWF Curncy',
           'BBGTKR::BLOOMBERG::PSNI6M Curncy',
           'BBGTKR::BLOOMBERG::PZFR0CF Curncy',
           'BBGTKR::BLOOMBERG::MOSKP6 Index',
           'BBGTKR::BLOOMBERG::TRLIB6M Index',
           'BBGTKR::BLOOMBERG::SAFR0CF Curncy',
           'BBGTKR::BLOOMBERG::TBOI6M Curncy',
           'BBGTKR::BLOOMBERG::NTNI6M Curncy',
           'BBGTKR::BLOOMBERG::MRSWNIF Curncy',
           'BBGTKR::BLOOMBERG::US0006M  Index']


fx_crry =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PRICE',
                        )




fx_crry.head()
fx_crry=fx_crry.fillna(method='bfill')
fx_crry.to_csv (r'K:\2020_2431\q\sandbox_fx\fx_crry_tmp.csv', index = True, header=True)
print("Complete!!!!")


now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# Complete!!!!
# Y 2021 / M 10 / D 12 /// H 16 : M 5 : S 6

# %%
#First only extract weekly CDS adn save it
      
#EXTRACT CDS DATA
cds5y_czech = MarketDataProvider(source='dataquery', tickers='CDSI.CZ.5Y.LAST_PRICE', start_date=start).data()
cds5y_czech.columns=['cds5y_CZK']
#print(czech_cds5y)

cds5y_russia = MarketDataProvider(source='dataquery', tickers='CDSI.RU.5Y.LAST_PRICE', start_date=start).data()
cds5y_russia.columns=['cds5y_RUB'] 
#print(russia_cds5y)

cds5y_peru = MarketDataProvider(source='dataquery', tickers='CDSI.PE.5Y.LAST_PRICE', start_date=start).data()
cds5y_peru.columns=['cds5y_PEN'] 
#print(peru_cds5y)
#peru cds	mdp	dataquery		CDSI.PE.5Y.LAST_PRICE

cds5y_china = MarketDataProvider(source='dataquery', tickers='CDSI.CN.5Y.LAST_PRICE', start_date=start).data()
cds5y_china.columns=['cds5y_CNH'] 
#print(china_cds5y)
#China cds	mdp	dataquery		CDS.CY.5Y.LAST_PRICE
#China cds	mdp	dataquery		CDS.CY.5Y.LAST_PRICE
#china cds	mdp	dataquery		CDSI.CN.5Y.LAST_PRICE

#india_cds5y = MarketDataProvider(source='MARKIT', tickers='CDSI.IN.5Y.LAST_PRICE', start_date=start).data()
#print(india_cds5y)
#india cds	mdp	dataquery		CDS.IN.5Y.LAST_PRICE
#china_cds5y.columns=['china_cds5y'] 

cds5y_brazil = MarketDataProvider(source='dataquery', tickers='CDSI.BR.5Y.LAST_PRICE', start_date=start).data()
cds5y_brazil.columns=['cds5y_BRL'] 
#print(brazil_cds5y)
#BRAZIL cds	mdp	dataquery		CDSI.BR.5Y.LAST_PRICE

cds5y_chile = MarketDataProvider(source='dataquery', tickers='CDSI.CL.5Y.LAST_PRICE', start_date=start).data()
cds5y_chile.columns=['cds5y_CLP'] 
#print(chile_cds5y)
#chile cds	mdp	dataquery		CDSI.CL.5Y.LAST_PRICE

cds5y_colombia = MarketDataProvider(source='dataquery', tickers='CDSI.CO.5Y.LAST_PRICE', start_date=start).data()
cds5y_colombia.columns=['cds5y_COP'] 
#print(colombia_cds5y)
#colombia cds	mdp	dataquery		CDSI.CO.5Y.LAST_PRICE

cds5y_hungary = MarketDataProvider(source='dataquery', tickers='CDSI.HU.5Y.LAST_PRICE', start_date=start).data()
cds5y_hungary.columns=['cds5y_HUF'] 
#print(hungary_cds5y)
#hungary cds	mdp	dataquery		CDSI.HU.5Y.LAST_PRICE

cds5y_israel = MarketDataProvider(source='dataquery', tickers='CDSI.IL.5Y.LAST_PRICE', start_date=start).data()
cds5y_israel.columns=['cds5y_ILS'] 
#print(israel_cds5y)
#israel cds	mdp	dataquery		CDSI.IL.5Y.LAST_PRICE

cds5y_southafrica = MarketDataProvider(source='dataquery', tickers='CDSI.ZA.5Y.LAST_PRICE', start_date=start).data()
cds5y_southafrica.columns=['cds5y_ZAR'] 
#print(southafrica_cds5y)
#south africa cds	mdp	dataquery		CDSI.ZA.5Y.LAST_PRICE

cds5y_mexico = MarketDataProvider(source='dataquery', tickers='CDSI.MX.5Y.LAST_PRICE', start_date=start).data()
cds5y_mexico.columns=['cds5y_MXN'] 
#print(mexico_cds5y)
#mexico cds	mdp	dataquery		CDSI.MX.5Y.LAST_PRICE

cds5y_korea = MarketDataProvider(source='dataquery', tickers='CDSI.KR.5Y.LAST_PRICE', start_date=start).data()
cds5y_korea.columns=['cds5y_KRW']
#print(korea_cds5y)
#korea cds	mdp	dataquery		CDSI.KR.5Y.LAST_PRICE

cds5y_malaysia = MarketDataProvider(source='dataquery', tickers='CDSI.MY.5Y.LAST_PRICE', start_date=start).data()
cds5y_malaysia.columns=['cds5y_MYR']
#print(malaysia_cds5y)
#malaysia cds	mdp	dataquery		CDSI.MY.5Y.LAST_PRICE

cds5y_poland = MarketDataProvider(source='dataquery', tickers='CDSI.PL.5Y.LAST_PRICE', start_date=start).data()
cds5y_poland.columns=['cds5y_PLN']
#print(poland_cds5y)
#polan cds	mdp	dataquery		CDSI.PL.5Y.LAST_PRICE

cds5y_turkey = MarketDataProvider(source='dataquery', tickers='CDSI.TR.5Y.LAST_PRICE', start_date=start).data()
cds5y_turkey.columns=['cds5y_TRY']
#print(turkey_cds5y)
#turkey cds	mdp	dataquery		CDSI.TR.5Y.LAST_PRICE

cds5y_indonesia = MarketDataProvider(source='dataquery', tickers='CDSI.ID.5Y.LAST_PRICE', start_date=start).data()
cds5y_indonesia.columns=['cds5y_IDR']
#print(indonesia_cds5y)
#indonesia cds	mdp	dataquery		CDSI.ID.5Y.LAST_PRICE

cds5y_thailand = MarketDataProvider(source='dataquery', tickers='CDSI.TH.5Y.LAST_PRICE', start_date=start).data()
cds5y_thailand.columns=['cds5y_THB']
#print(thailand_cds5y)
#indonesia cds	mdp	dataquery		CDSI.ID.5Y.LAST_PRICE

cds5y_philippines = MarketDataProvider(source='dataquery', tickers='CDSI.PH.5Y.LAST_PRICE', start_date=start).data()
cds5y_philippines.columns=['cds5y_PHP']
#print(philippines_cds5y)

cds5y_argentina = MarketDataProvider(source='dataquery', tickers='CDSI.AR.5Y.LAST_PRICE', start_date=start).data()
cds5y_argentina.columns=['cds5y_ARG']
#print(argentina_cds5y)
#argentina cds	mdp	dataquery		CDSI.AR.5Y.LAST_PRICE

####add taiwan


cds_db = pd.concat([cds5y_philippines,
                     cds5y_czech,
                     cds5y_thailand,
                     cds5y_turkey,
                     cds5y_indonesia,
                     cds5y_poland,
                     cds5y_malaysia,
                     cds5y_korea,
                     cds5y_mexico,
                     cds5y_southafrica,
                     cds5y_israel,
                     cds5y_hungary,
                     cds5y_colombia,
                     cds5y_chile,
                     cds5y_brazil,
                     cds5y_china,
                     cds5y_russia,
                     cds5y_peru], axis=1).fillna(method="ffill").dropna() 


cds_db.head()
#cds_db['date'] = cds_db.index
#print(cds_db)
#cds_rs=pd.merge(time, cds_db,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
cds_db.to_csv (r'K:\2020_2431\q\sandbox_gm\cds_tmp.csv', index = True, header=True)
#cds_rs=cds_rs
print(cds_db)
print("Complete!!!")

now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
          'BBGTKR::BLOOMBERG::MXZA Index','BBGTKR::BLOOMBERG::MXTH Index',
          'BBGTKR::BLOOMBERG::TAMSCI Index','BBGTKR::BLOOMBERG::MXMY Index',
          'BBGTKR::BLOOMBERG::MXPH Index','BBGTKR::BLOOMBERG::MXID Index']


# # notice here we are retrieving data from dataquery and bloomberg using the bloomberg ticker

l_msci =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
l_msci.head()
l_msci=l_msci.fillna(method='bfill')
#l_msci=pd.merge(time, l_msci,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
l_msci.to_csv (r'K:\2020_2431\q\sandbox_fx\l_msci_tmp.csv', index = True, header=True)

now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# Y 2021 / M 10 / D 12 /// H 16 : M 5 : S 23

# %%
#s&p retunr
##   is stock sp500 weekly retunr#SP500 Weekly Returns	Global
#msci_us =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::MXUS INDEX'],
#                        start=start,
#                        end=end,
#                        fields='PRICE',
#                        )
#msci_us.head()
#msci_us=msci_us.fillna(method='bfill')
#msci_us=pd.merge(time, msci_us,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
#msci_us.to_csv (r'K:\2020_2431\q\sandbox_fx\msci_us_tmp.csv', index = False, header=True)##
#now = datetime.datetime.now()
#print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)

# %%
#s&p retunr
     ##   is stock sp500 weekly retunr#SP500 Weekly Returns	Global
msci_us =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::MXUS INDEX'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
msci_us.head()
msci_us=msci_us.fillna(method='bfill')
#msci_us=pd.merge(time, msci_us,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
msci_us.to_csv (r'K:\2020_2431\q\sandbox_fx\msci_us_tmp.csv', index = True, header=True)


    
# ust t bill yield weekly differnece
#TREASURY BILL ChANGE#TBILL Weekly difference	Global
#TREASURY BILL CANGE

ust =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::USGG10YR Index'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
ust.head()
ust=ust.fillna(method='bfill')
#ust=pd.merge(time, ust,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
ust.to_csv (r'K:\2020_2431\q\sandbox_fx\ust_tmp.csv', index = True, header=True)


us_y =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::H15T10Y Index'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
us_y.head()
us_y=us_y.fillna(method='bfill')
#us_y=pd.merge(time, us_y,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
us_y.to_csv (r'K:\2020_2431\q\sandbox_fx\us_y_tmp.csv', index = True, header=True)


carry_index =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::MSCBFCAE Index'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
carry_index.head()
carry_index=carry_index.fillna(method='bfill')
#carry_index=pd.merge(time, carry_index,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
carry_index.to_csv (r'K:\2020_2431\q\sandbox_fx\carry_index_tmp.csv', index = True, header=True)


#Vix
vix =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::VIX INDEX'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
vix.head()
vix=vix.fillna(method='bfill')
#vix=pd.merge(time, vix,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
vix.to_csv (r'K:\2020_2431\q\sandbox_fx\vix_tmp.csv', index = True, header=True)


print("COmplete")
now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# COmplete
# Y 2021 / M 10 / D 12 /// H 16 : M 5 : S 33

# %%
#us_6m
us_6m =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::US0006M INDEX'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
us_6m.head()
us_6m=us_6m.fillna(method='bfill')
#vix=pd.merge(time, vix,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
us_6m.to_csv (r'K:\2020_2431\q\sandbox_fx\us6m_tmp.csv', index = True, header=True)




print("COmplete")
now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# COmplete
# Y 2021 / M 10 / D 12 /// H 16 : M 5 : S 34
