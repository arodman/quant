# %%
from alphapy.core import *


    
    
#BR-USD does not use a treasury curve,  We have a treasury proxy crv build off of part rates implied from swap curve
#t1 = BondTradeInfo(issue="BR-USD", tenor="10Y")


#usd
#FINLAND FI-USD
#BELGIUM
#CHINA
#SOUTH KOREA
#ISRAEL
#PHILIPPINES
#CHILE
#ITALY IT-USD
#SAUDI ARABIA
#INDONESIA
#PERU---------------
#QATAR
#ROMANIA
#RUSSIA RU-USD
#MEXICO----------
#COLOMBIA---------------
#BRAZIL BR-USD
#SOUTH AFRICA
#TURKEY
#UKRAINE
#EGYPT
#ECUADOR


#EUR

AUSTRIA
CHINA
CROATIA
CYPRUS
EGYPT
FINLAND
FRANCE
GREECE
HUNGARY
ICELAND
INDONESIA
IRELAND
ISRAEL
ITALY
LATVIA
LITHUANIA
LUXEMBOURG
MALTA
MEXICO
NETHERLANDS
PERU
PHILIPPINES
POLAND
portugal
ROMANIA
RUSSIA
SAUDI ARABIA
Serbia
SLOVAKIA
SLOVENIA
SPAIN
SWEDEN
TURKEY
UKRAINE
CHILE
Morocco
belgium
Bulgaria

# %%
from alphapy.core import *

issuer_n="BG-EUR"
tenor_n="10Y"

tsr = TimeSeriesRequest()
t1 = BondTradeInfo(issue=str(issuer_n), tenor=str(tenor_n))
tsr.pos_append(t1)
tsr.calc_output_list_extend(["price", "ytm"])
tsr.DataSources.fetch_bonds_from_mds_dataquery = True
tsr.StartDate = dt.datetime(2010, 1, 1)
tsr.EndDate = dt.datetime(2021, 6, 17)
df = tsr.get_as_frame()
print(df)
df.to_clipboard()
# Out:
#            date                                    ID                                              Error price calcsymbol   ytm
# 0    2010-01-01  7931937C-036D-4087-AC51-2E16B8CC0B3F  Cannot Create Position.TradeAccesorBuilder fai...  None       None  None
# 1    2010-01-04  7931937C-036D-4087-AC51-2E16B8CC0B3F  Cannot Create Position.TradeAccesorBuilder fai...  None       None  None
# 2    2010-01-05  7931937C-036D-4087-AC51-2E16B8CC0B3F  Cannot Create Position.TradeAccesorBuilder fai...  None       None  None
# 3    2010-01-06  7931937C-036D-4087-AC51-2E16B8CC0B3F  Cannot Create Position.TradeAccesorBuilder fai...  None       None  None
# 4    2010-01-07  7931937C-036D-4087-AC51-2E16B8CC0B3F  Cannot Create Position.TradeAccesorBuilder fai...  None       None  None
# 5    2010-01-08  7931937C-036D-4087-AC51-2E16B8CC0B3F  Cannot Create Position.TradeAccesorBuilder fai...  None       None  None
# ...
