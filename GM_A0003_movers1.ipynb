# %%
###market mover
#'highest move sin EM FX

#separeate for each 5 of th eproduct

#last week
#last month
#last 3 monthjs

#HIGHEST MVOE IN ALL
# Z SCORES'
###comapre hroionzta.




# HIGHESS TMOVES INR ATES
#HIGEHST MOVES IN hc
#HIGHES MOVE ION ALL ARATES
#HIGHEST MOVES IN MSCI
#HIGEST MOVE IN CDS
# HIGHEST MOVE IN PLUS COMODIDITES

#VARIATION
#'ABOLSITOS DIFFERNECE. 

#IMPORT PACKAGES

# %%
import pandas as pd 
import os
from datetime import date
import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
from pandas import DataFrame
#from statsmodels.regression.rolling import RollingOLS
import matplotlib.pyplot as plt
import numpy as np # numerical python
import seaborn as sns

#stacked
import tkinter
import matplotlib
matplotlib.use('TkAgg')


import PIL
from PIL import Image
#import os
from PyPDF2 import PdfFileMerger
from PyPDF2 import PdfFileMerger
from datetime import datetime as dt


import statsmodels.api as sm
from scipy import stats
import numpy as np
from dateutil.relativedelta import relativedelta
import time


import pandas as pd
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from pandas.plotting import table
import os
from datetime import date
import seaborn as sns
from random import seed
from random import random
import numpy as np
import PIL
from PIL import Image
#import os
from PyPDF2 import PdfFileMerger
from codetiming import Timer

import matplotlib.lines as mlines
from numpy.polynomial.polynomial import polyfit
import numpy
import scipy.stats

import scipy.stats



import pandas as pd
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from pandas.plotting import table
import os
from datetime import date
import seaborn as sns
from random import seed
from random import random
import numpy as np
import PIL
from PIL import Image
#import os
from PyPDF2 import PdfFileMerger
from codetiming import Timer
timeclock = Timer(name="class")
timeclock.start()
# Do something

###variatons 
#latest vlaues  - avera
#latest value - averar / standar decaitons

# %%
#############
data_z= pd.read_csv  (r'K:\2020_2431\q\sandbox_gm\data_z.csv')
data_z=data_z.tail(365)
data_z=data_z.reset_index(drop=True)
data_z=data_z.fillna(method='bfill')
data_z.to_clipboard()

#cds5y_CLP
#fx_IDR
#l_msci_CZK
#hccy_MXN
#dv_lccy_TRY

# %%
###GENERATE THE DATA

#list_x0 = ['BRL','COP','MXN','CLP','PEN','CZK','HUF','PLN','RUB','ILS','ZAR','TRY','IDR','THB','MYR','KRW','PHP']
list_y0 = ["cds5y_","fx_","l_msci_","hccy_","lccy_"]
## inr,twd
list_x0 = ['BRL','CLP','CNH','COP','CZK','IDR','ILS','INR','KRW','MXN','PEN','PLN','RUB','HUF','ZAR','THB','TWD','MYR','TRY']
list_z0 = ['1_Week','1_Month','3_Months','6_Months']
list_z1 = ['5','22','66','132']
diff0=5
diff1=22
diff2=66
diff3=132

# %%
###variatons 
#latest vlaues  - avera
#latest value - averar / standar decaitons

mm=pd.DataFrame()
mm["date"]=data_z["date"]

loop_list1=list_y0
loop_list2=list_x0
loop_list3=list_z0
loop_list4=list_z1

for x in range(len(loop_list1)): 
    print(x)
    variable=str(loop_list1[x])  
    print(variable)
    
    for y in range(len(loop_list2)): 
        print(y)
        country=str(loop_list2[y])  
        print(country)       
        c_v=str(variable+country)
        for z in range(len(loop_list3)):
            print(z)
            time_l=str(loop_list3[z])            
            print(time_l)
            window=str(loop_list4[z])
            print(window)
            window=int(window)+0                 
            try:
                mm[str(c_v)]=data_z[str(c_v)]
                mm[str("m_"+c_v)]=data_z[str(c_v)].rolling(window=window).mean()
                mm[str("s_"+c_v)]=data_z[str(c_v)].rolling(window=window).std() 
                mm[str("lg_"+time_l+"_"+c_v)]= (data_z[str(c_v)].shift((window)))
                mm[str("var_"+time_l+"_"+c_v)]=((mm[str(c_v)]/mm[str("lg_"+time_l+"_"+c_v)])-1)
                mm[str("z_score_"+time_l+"_"+c_v)]=((mm[str(c_v)]-mm[str("m_"+c_v)])/mm[str("s_"+c_v)])           
            except KeyError:
                pass
            
#########################################
#                                                      
mm=mm.fillna(method='ffill')
mm=mm.tail(1)            
print("Complete")

# %%
#mm.to_clipboard()

#PART SUMARRY table 

dateTimeObj = str(datetime.now())
print(dateTimeObj)
today0 = str(date.today())

# %%
###GROUP THE DATA AND MAKE THE CAHRTS

os.chdir('K:/2020_2431/q/gm_marketmovers/images/z')
print(os.getcwd())

parameter_s1=10
parameter_s2=10
y_label="y_label"
c_label="c_label"
title_text="title_text"

        

analysis=str("z_score_")
mm0=pd.DataFrame()
loop_list1=list_y0
loop_list2=list_x0
loop_list3=list_z0
loop_list4=list_z1

for x in range(len(loop_list3)): 
    print(x)
    time_l=str(loop_list3[x])  
    print(time_l)    
    for y in range(len(loop_list1)): 
        print(y)
        variable=str(loop_list1[y])          
        list_z = [item if i%1 else analysis+time_l+ "_" + variable + item for i,item in enumerate(list_x0)]
        print(list_z)
        
        mm1 = pd.DataFrame(data=mm, columns=list_z,)
        print(mm1)
        mm1 = mm1.transpose()
        mm1.reset_index(level=0, inplace=True)
        mm1.columns = ['ticker', 'output']           
        mm1['ticker'] = mm1['ticker'].str[-3:]
        mm1.dropna(subset = ["output"], inplace=True)
        mm1 = mm1.sort_values(['output'], ascending=[True])
        print(mm1)      

        y_label=str(analysis)
        c_label="EM Country" +str(variable)+" ["+today0+"]"
        title_text="EM Market Movers: " + str(analysis) +" ("+str(time_l)+") _" + str(variable)+" ["+today0+"]"
        
        plt.figure(figsize=(parameter_s1,parameter_s2))
        sns.set_style('whitegrid')
        #hue="Status",
        splot=sns.barplot(x='ticker', y="output",
                          palette=["blue"], 
                          data=mm1)
        plt.ylabel(str(y_label), size=20)
        plt.xlabel(str(c_label), size=20)
        plt.title(str(title_text), size=20)
        sns.color_palette("rocket", as_cmap=True)

        for p in splot.patches:
                splot.annotate(format(p.get_height(), '.00f'), 
                           (p.get_x() + p.get_width() / 2., p.get_height()), 
                           ha = 'center', va = 'center', 
                           size=10,
                           xytext = (0, -12), 
                           textcoords = 'offset points')
                #plt.savefig("grouped_barplot_Seaborn_barplot_Python.png")

        plt.savefig(str(variable+"/"+variable+analysis+time_l+'.pdf'), bbox_inches='tight')



#mm1['ticker'] = ticker['ticker'].str[-5:]

# %%
###GROUP THE DATA AND MAKE THE CAHRTS

os.chdir('K:/2020_2431/q/gm_marketmovers/images/v')
print(os.getcwd())

parameter_s1=10
parameter_s2=10
y_label="y_label"
c_label="c_label"
title_text="title_text"

        

analysis=str("var_")
mm0=pd.DataFrame()
loop_list1=list_y0
loop_list2=list_x0
loop_list3=list_z0
loop_list4=list_z1

for x in range(len(loop_list3)): 
    print(x)
    time_l=str(loop_list3[x])  
    print(time_l)    
    for y in range(len(loop_list1)): 
        print(y)
        variable=str(loop_list1[y])          
        list_z = [item if i%1 else analysis+time_l+ "_" + variable + item for i,item in enumerate(list_x0)]
        print(list_z)
        
        mm1 = pd.DataFrame(data=mm, columns=list_z,)
        print(mm1)
        mm1 = mm1.transpose()
        mm1.reset_index(level=0, inplace=True)
        mm1.columns = ['ticker', 'output']           
        mm1['ticker'] = mm1['ticker'].str[-3:]
        mm1.dropna(subset = ["output"], inplace=True)
        mm1 = mm1.sort_values(['output'], ascending=[True])
        print(mm1)      

        y_label=str(analysis)
        c_label="EM Country" +str(variable)+" ["+today0+"]"
        title_text="EM Market Movers: " + str(analysis) +" ("+str(time_l)+") _" + str(variable)+" ["+today0+"]"
        
        
        plt.figure(figsize=(parameter_s1,parameter_s2))
        sns.set_style('whitegrid')
        #hue="Status",
        splot=sns.barplot(x='ticker', y="output",
                          palette=["blue"], 
                          data=mm1)
        plt.ylabel(str(y_label), size=20)
        plt.xlabel(str(c_label), size=20)
        plt.title(str(title_text), size=20)
        sns.color_palette("rocket", as_cmap=True)

        for p in splot.patches:
                splot.annotate(format(p.get_height(), '.00f'), 
                           (p.get_x() + p.get_width() / 2., p.get_height()), 
                           ha = 'center', va = 'center', 
                           size=10,
                           xytext = (0, -12), 
                           textcoords = 'offset points')
                #plt.savefig("grouped_barplot_Seaborn_barplot_Python.png")

        plt.savefig(str(variable+"/"+variable+analysis+time_l+'.pdf'), bbox_inches='tight')

# %%
os.chdir('K:/2020_2431/q/gm_marketmovers/images')
print(os.getcwd())



  
for y in range(len(loop_list1)): 
    print(y)
    variable=str(loop_list1[y])
    source_dir= 'K:/2020_2431/q/gm_marketmovers/images/z/'+variable+'/'
    source_dir2= 'K:/2020_2431/q/gm_marketmovers/images/z/'
    merger = PdfFileMerger()
    for item in os.listdir(source_dir):
        if item.endswith('pdf'):
            merger.append(source_dir + item)

    merger.write(str(source_dir2)+"zscore_"+variable+".pdf") 
    merger.close()


      
for y in range(len(loop_list1)): 
    print(y)
    variable=str(loop_list1[y])
    source_dir= 'K:/2020_2431/q/gm_marketmovers/images/v/'+variable+'/'
    source_dir2= 'K:/2020_2431/q/gm_marketmovers/images/v/'
    merger = PdfFileMerger()
    for item in os.listdir(source_dir):
        if item.endswith('pdf'):
            merger.append(source_dir + item)

    merger.write(str(source_dir2)+"var_"+variable+".pdf") 
    merger.close()
    
    

print("Complete")
now = datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)



#P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm

# %%
import subprocess

src=r'K:\2020_2431\q\gm_marketmovers\images\z\zscore_cds5y_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm\emmm_zscore_cds5y_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


src=r'K:\2020_2431\q\gm_marketmovers\images\z\zscore_fx_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm\emmm_zscore_fx_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


src=r'K:\2020_2431\q\gm_marketmovers\images\z\zscore_hccy_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm\emmm_zscore_hccy_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


src=r'K:\2020_2431\q\gm_marketmovers\images\z\zscore_l_msci_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm\emmm_zscore_l_msci_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)

src=r'K:\2020_2431\q\gm_marketmovers\images\z\zscore_lccy_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm\emmm_zscore_lccy_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


##################################

src=r'K:\2020_2431\q\gm_marketmovers\images\v\var_cds5y_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm\emmm_var_cds5y_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


src=r'K:\2020_2431\q\gm_marketmovers\images\v\var_fx_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm\emmm_var_fx_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


src=r'K:\2020_2431\q\gm_marketmovers\images\v\var_hccy_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm\emmm_var_hccy_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


src=r'K:\2020_2431\q\gm_marketmovers\images\v\var_l_msci_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm\emmm_var_l_msci_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)

src=r'K:\2020_2431\q\gm_marketmovers\images\v\var_lccy_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\emmm\emmm_var_lccy_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)

# %%
###### clear output and then save
import os
def clear():
    os.system( 'cls' )


clear()
