# %%
#Adyne nbeer, jopm reer, citi narrow broad, exantes. Ytd 3 motnh changes.

# %%
import pandas as pd 
import os
from datetime import date
import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
from pandas import DataFrame
#from statsmodels.regression.rolling import RollingOLS
#import matplotlib.pyplot as plt
import numpy as np # numerical python
#import seaborn as sns

#stacked
#import tkinter
#import matplotlib
#matplotlib.use('TkAgg')


#import PIL
#from PIL import Image
##import os
from PyPDF2 import PdfFileMerger
from datetime import datetime as dt


import statsmodels.api as sm
from scipy import stats
import numpy as np
from dateutil.relativedelta import relativedelta
import time


import pandas as pd
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from pandas.plotting import table
import os
from datetime import date
import seaborn as sns
from random import seed
from random import random
import numpy as np
import PIL
from PIL import Image
#import os
from PyPDF2 import PdfFileMerger
from codetiming import Timer

import matplotlib.lines as mlines
from numpy.polynomial.polynomial import polyfit
import numpy
import scipy.stats



import datetime as dt
import datetime as datetime
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from statsmodels.regression.rolling import RollingOLS
import matplotlib.pyplot as plt
import numpy as np # numerical python
import pandas as pd # pannel datasets
import matplotlib.pyplot as plt 
import seaborn as sns
from datetime import date
import datetime as datetime

import subprocess

# %% [markdown]
# # Fair value Indicator

# %%
###Fair vlaue idnicatoR


#TOTDEV
#TEER# 1
#PPP T2


####exante models

#0       australia     0    AUD       AUD       NaN
#1          canada     0    CAD       CAD       NaN
#2        eurozone     0    EUR       EUR       NaN
#3           japan     0    JPY       JPY       NaN
#4          norway     0    NOK       NOK       NaN
#5     switzerland     0    CHF       CHF       NaN
#6          sweden     0    SEK       SEK       NaN
#7  united kingdom     0    GBP       GBP       NaN
#8   united states     0    USD       USD       NaN
#9     new zealand  


ea_teer = pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\ea1_tmp.csv')
ea_ppp  = pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\ea2_tmp.csv')
ea_broad10 = pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\ea3_tmp.csv')
ea_broad20  = pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\ea4_tmp.csv')
ea_narrow   = pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\ea5_tmp.csv')
citi = pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\citi_reer.csv')

# %%
print(ea_teer)
print(ea_ppp)

tt = {'country': ['EU', 'SE', 'NZ', 'AU', 'US', 'JP', 'NO', 'CH', 'CA', 'GB'],
        'fx_ticker': ['EUR', 'SEK', 'NZD', 'AUD', 'USD', 'JPY', 'NOK', 'CHF', 'CAD', 'GBP']}  
  
# Create DataFrame  
tt = pd.DataFrame(tt)  
tt["country"]=tt["country"].str.lower()
tt["fx_ticker"]=tt["fx_ticker"].str.lower()
print(tt)


ea_teer =ea_teer.transpose()
ea_teer.reset_index(level=0, inplace=True)
#mm1.columns = ['ticker', 'output'] 
#ea_teer.rename(columns={ ea_teer.columns[0]: "country" }, inplace = True)
#ea_teer=ea_teer[["country",]]
ea_teer.columns=["country","teer"]
ea_teer['country'] = ea_teer['country'].str.lower()
ea_teer['country'] = ea_teer['country'].str[:2]
ea_teer=pd.merge(ea_teer, tt,  how='left', left_on=['country'], right_on = ['country'])
ea_teer.dropna(subset = ["fx_ticker"], inplace=True)
ea_teer=ea_teer[["fx_ticker","teer"]]
ea_teer["teer"]=(ea_teer["teer"]/100)
ea_teer["fx_ticker"]=ea_teer["fx_ticker"].str.upper()
ea_teer.reset_index(level=0, inplace=True)
del ea_teer['index']
print(ea_teer)



#ady_beer=pd.merge(ady_beer, matrix_country,  how='left', left_on=['country'], right_on = ['country'])
#ady_beer=ady_beer[ady_beer['d_em']==1]
#ady_beer.reset_index(level=0, inplace=True)
#del ady_beer['index']
#ady_beer=ady_beer[['country',str(vb1),'fx_ticker']]
#print(ady_beer)

ea_ppp =ea_ppp.transpose()
ea_ppp.reset_index(level=0, inplace=True)
ea_ppp.columns=["country","ppp"]
ea_ppp['country'] = ea_ppp['country'].str.lower()
ea_ppp['country'] = ea_ppp['country'].str[:2]
ea_ppp=pd.merge(ea_ppp, tt,  how='left', left_on=['country'], right_on = ['country'])
ea_ppp.dropna(subset = ["fx_ticker"], inplace=True)
ea_ppp=ea_ppp[["fx_ticker","ppp"]]
ea_ppp["ppp"]=(ea_ppp["ppp"]/100)
ea_ppp["fx_ticker"]=ea_ppp["fx_ticker"].str.upper()
ea_ppp.reset_index(level=0, inplace=True)
del ea_ppp['index']
print(ea_ppp)


######





ea_broad10 =ea_broad10.transpose()
ea_broad10.reset_index(level=0, inplace=True)
ea_broad10.columns=["country","broad10"]
ea_broad10['country'] = ea_broad10['country'].str.lower()
ea_broad10['country'] = ea_broad10['country'].str[:2]
ea_broad10=pd.merge(ea_broad10, tt,  how='left', left_on=['country'], right_on = ['country'])
ea_broad10.dropna(subset = ["fx_ticker"], inplace=True)
ea_broad10=ea_broad10[["fx_ticker","broad10"]]
ea_broad10["broad10"]=(ea_broad10["broad10"]/100)
ea_broad10["fx_ticker"]=ea_broad10["fx_ticker"].str.upper()
ea_broad10.reset_index(level=0, inplace=True)
del ea_broad10['index']
print(ea_broad10)



######


ea_broad20 =ea_broad20.transpose()
ea_broad20.reset_index(level=0, inplace=True)
ea_broad20.columns=["country","broad20"]
ea_broad20['country'] = ea_broad20['country'].str.lower()
ea_broad20['country'] = ea_broad20['country'].str[:2]
ea_broad20=pd.merge(ea_broad20, tt,  how='left', left_on=['country'], right_on = ['country'])
ea_broad20.dropna(subset = ["fx_ticker"], inplace=True)
ea_broad20=ea_broad20[["fx_ticker","broad20"]]
ea_broad20["broad20"]=(ea_broad20["broad20"]/100)
ea_broad20["fx_ticker"]=ea_broad20["fx_ticker"].str.upper()
ea_broad20.reset_index(level=0, inplace=True)
del ea_broad20['index']
print(ea_broad20)


############


ea_narrow =ea_narrow.transpose()
ea_narrow.reset_index(level=0, inplace=True)
ea_narrow.columns=["country","narrow"]
ea_narrow['country'] = ea_narrow['country'].str.lower()
ea_narrow['country'] = ea_narrow['country'].str[:2]
ea_narrow=pd.merge(ea_narrow, tt,  how='left', left_on=['country'], right_on = ['country'])
ea_narrow.dropna(subset = ["fx_ticker"], inplace=True)
ea_narrow=ea_narrow[["fx_ticker","narrow"]]
ea_narrow["narrow"]=(ea_narrow["narrow"]/100)
ea_narrow["narrow"]=(ea_narrow["narrow"]-1)
ea_narrow["fx_ticker"]=ea_narrow["fx_ticker"].str.upper()
ea_narrow.reset_index(level=0, inplace=True)
del ea_narrow['index']
print(ea_narrow)
# Out:
#             Unnamed: 0  AR.VAL.TOTDEV.EST.D  AU.VAL.TOTDEV.EST.D  \
# 0  2021-11-24 00:00:00            -3.619904           -18.417077
#
#    BR.VAL.TOTDEV.EST.D  CA.VAL.TOTDEV.EST.D  CH.VAL.TOTDEV.EST.D  \
# 0           -20.889851           -17.755265             0.233754
#
#    CL.VAL.TOTDEV.EST.D  CN.VAL.TOTDEV.EST.D  CO.VAL.TOTDEV.EST.D  \
# 0           -12.475835            10.601185           -30.625141
#
#    CZ.VAL.TOTDEV.EST.D  ...  NZ.VAL.TOTDEV.EST.D  PH.VAL.TOTDEV.EST.D  \
# 0             7.760012  ...            -2.196283            -2.030499
#
#    PL.VAL.TOTDEV.EST.D  RU.VAL.TOTDEV.EST.D  SE.VAL.TOTDEV.EST.D  \
# 0            -3.956127           -15.761727            -2.576314
#
#    SG.VAL.TOTDEV.EST.D  TH.VAL.TOTDEV.EST.D  TR.VAL.TOTDEV.EST.D  \
# 0             4.488829            -6.679176           -55.554749
#
#    US.VAL.TOTDEV.EST.D  ZA.VAL.TOTDEV.EST.D
# 0             5.544279           -14.684165
#
# [1 rows x 31 columns]
# ...

# %%
print(citi)
# Out:
#            TIME  BBGTKR::BLOOMBERG::CTTWBAED Index  \
# 0    2019-12-31                            99.0870
# 1    2020-01-01                            99.0928
# 2    2020-01-02                            99.2559
# 3    2020-01-03                            99.4818
# 4    2020-01-06                            99.3387
# ..          ...                                ...
# 491  2021-11-17                           100.0580
# 492  2021-11-18                           100.0850
# 493  2021-11-19                           100.3604
# 494  2021-11-22                           100.4101
# 495  2021-11-23                           100.8912
#
#      BBGTKR::BLOOMBERG::CTTWBARS Index  BBGTKR::BLOOMBERG::CTTWBAUD Index  \
# 0                              27.3006                            94.9505
# 1                              27.2619                            95.0484
# 2                              27.3317                            94.7365
# ...

# %%
#extract the latest
ady_beer = pd.read_csv (r'P:\EGM\FX_Tools\Valuation\Adyne_BEER\Adyne_BEER.csv')
jpm_reer= pd.read_csv (r'P:\EGM\FX_Tools\Valuation\REER_Avg\JPM_CPI_REER_10yrAvg.csv')
matrix_country = pd.read_csv (r'K:\2020_2431\q\matrix_ticker\matrix_country_dm.csv')
matrix_country['country']=matrix_country['country'].str.lower()
#matrix_country=matrix_country[['country','fx_ticker']]
matrix_country['fx_ticker']=matrix_country['fx_ticker'].str.upper()
print(matrix_country)

print(ady_beer)
print(jpm_reer)
# Out:
#           country  d_em ticker fx_ticker  name_ccy
# 0       australia     0    AUD       AUD       NaN
# 1          canada     0    CAD       CAD       NaN
# 2        eurozone     0    EUR       EUR       NaN
# 3           japan     0    JPY       JPY       NaN
# 4          norway     0    NOK       NOK       NaN
# 5     switzerland     0    CHF       CHF       NaN
# 6          sweden     0    SEK       SEK       NaN
# 7  united kingdom     0    GBP       GBP       NaN
# 8   united states     0    USD       USD       NaN
# 9     new zealand     0    NZD       NZD       NaN
#         Unnamed: 0  Valuation Difference           TOT Coeff  \
# 0      New Zealand                 0.018     0.22( 4.50E-4 )
# 1           Mexico                 0.088    0.78( 5.11E-45 )
# 2         Eurozone                -0.011   -0.304( 5.00E-4 )
# 3           Norway                -0.029    0.23( 9.51E-24 )
# 4        Singapore                -0.030    0.078( 4.68E-1 )
# ...

# %%
citi_br=citi[["BBGTKR::BLOOMBERG::CTTWBRJP Index","BBGTKR::BLOOMBERG::CTTWBRUS Index",
           "BBGTKR::BLOOMBERG::CTTWBRCH Index","BBGTKR::BLOOMBERG::CTTWBRGB Index",
           "BBGTKR::BLOOMBERG::CTTWBRAU Index",
           "BBGTKR::BLOOMBERG::CTTWBREU Index","BBGTKR::BLOOMBERG::CTTWBRCA Index",
           "BBGTKR::BLOOMBERG::CTTWBRSE Index","BBGTKR::BLOOMBERG::CTTWBRNO Index",
           "BBGTKR::BLOOMBERG::CTTWBRNZ Index"]]
              
citi_nr=citi[["BBGTKR::BLOOMBERG::CTTWNRJP Index","BBGTKR::BLOOMBERG::CTTWNRUS Index",
           "BBGTKR::BLOOMBERG::CTTWNRCH Index","BBGTKR::BLOOMBERG::CTTWNRGB Index",
           "BBGTKR::BLOOMBERG::CTTWNRAU Index",
           "BBGTKR::BLOOMBERG::CTTWNREU Index","BBGTKR::BLOOMBERG::CTTWNRCA Index",
           "BBGTKR::BLOOMBERG::CTTWNRSE Index","BBGTKR::BLOOMBERG::CTTWNRNO Index",
           "BBGTKR::BLOOMBERG::CTTWNRNZ Index"]]

####rename all columns
citi_br.rename(columns={"BBGTKR::BLOOMBERG::CTTWBRJP Index":'fx_br_JPY'}, inplace=True)
citi_br.rename(columns={"BBGTKR::BLOOMBERG::CTTWBRUS Index":'fx_br_USD'}, inplace=True)
citi_br.rename(columns={"BBGTKR::BLOOMBERG::CTTWBRCH Index":'fx_br_CHF'}, inplace=True)
citi_br.rename(columns={"BBGTKR::BLOOMBERG::CTTWBRGB Index":'fx_br_GBP'}, inplace=True)
citi_br.rename(columns={"BBGTKR::BLOOMBERG::CTTWBRAU Index":'fx_br_AUD'}, inplace=True)
citi_br.rename(columns={"BBGTKR::BLOOMBERG::CTTWBREU Index":'fx_br_EUR'}, inplace=True)
citi_br.rename(columns={"BBGTKR::BLOOMBERG::CTTWBRCA Index":'fx_br_CAD'}, inplace=True)
citi_br.rename(columns={"BBGTKR::BLOOMBERG::CTTWBRSE Index":'fx_br_SEK'}, inplace=True)
citi_br.rename(columns={"BBGTKR::BLOOMBERG::CTTWBRNO Index":'fx_br_NOK'}, inplace=True)
citi_br.rename(columns={"BBGTKR::BLOOMBERG::CTTWBRNZ Index":'fx_br_NZD'}, inplace=True)

citi_nr.rename(columns={"BBGTKR::BLOOMBERG::CTTWNRJP Index":'fx_nr_JPY'}, inplace=True)
citi_nr.rename(columns={"BBGTKR::BLOOMBERG::CTTWNRUS Index":'fx_nr_USD'}, inplace=True)
citi_nr.rename(columns={"BBGTKR::BLOOMBERG::CTTWNRCH Index":'fx_nr_CHF'}, inplace=True)
citi_nr.rename(columns={"BBGTKR::BLOOMBERG::CTTWNRGB Index":'fx_nr_GBP'}, inplace=True)
citi_nr.rename(columns={"BBGTKR::BLOOMBERG::CTTWNRAU Index":'fx_nr_AUD'}, inplace=True)
citi_nr.rename(columns={"BBGTKR::BLOOMBERG::CTTWNREU Index":'fx_nr_EUR'}, inplace=True)
citi_nr.rename(columns={"BBGTKR::BLOOMBERG::CTTWNRCA Index":'fx_nr_CAD'}, inplace=True)
citi_nr.rename(columns={"BBGTKR::BLOOMBERG::CTTWNRSE Index":'fx_nr_SEK'}, inplace=True)
citi_nr.rename(columns={"BBGTKR::BLOOMBERG::CTTWNRNO Index":'fx_nr_NOK'}, inplace=True)
citi_nr.rename(columns={"BBGTKR::BLOOMBERG::CTTWNRNZ Index":'fx_nr_NZD'}, inplace=True)




#print(citi_nr)
#print(citi_br)

#Citi Broad Nominal Effective Exchange Rate Index - JPY
citi_nr=citi_nr.tail(1)
citi_nr =citi_nr.transpose()
citi_nr.reset_index(level=0, inplace=True)
citi_nr.columns=["fx_ticker","narrow_neer"]
print(citi_nr)
citi_nr['fx_ticker'] = citi_nr['fx_ticker'].str.lower()
citi_nr['fx_ticker'] = citi_nr['fx_ticker'].str[6:]
citi_nr['fx_ticker'] = citi_nr['fx_ticker'].str.upper()
citi_nr['narrow_neer'] = ((citi_nr['narrow_neer']/100)-1)

#citi_nr=pd.merge(citi_nr, tt,  how='left', left_on=['fx_ticker'], right_on = ['fx_ticker'])
#ea_broad20.dropna(subset = ["fx_ticker"], inplace=True)
#ea_broad20=ea_broad20[["fx_ticker","broad20"]]
#ea_broad20["broad20"]=(ea_broad20["broad20"]/100)
#ea_broad20["fx_ticker"]=ea_broad20["fx_ticker"].str.upper()
#ea_broad20.reset_index(level=0, inplace=True)
#del ea_broad20['index']
#print(ea_broad20)
print(citi_nr)


#Citi Broad Nominal Effective Exchange Rate Index - JPY
citi_br=citi_br.tail(1)
citi_br =citi_br.transpose()
citi_br.reset_index(level=0, inplace=True)
citi_br.columns=["fx_ticker","broad_neer"]
citi_br['fx_ticker'] = citi_br['fx_ticker'].str.lower()
citi_br['fx_ticker'] = citi_br['fx_ticker'].str[6:]
citi_br['fx_ticker'] = citi_br['fx_ticker'].str.upper()
citi_br['broad_neer'] = ((citi_br['broad_neer']/100)-1)


print(citi_nr)

print(citi_br)
# Out:
#    fx_ticker  narrow_neer
# 0  fx_nr_JPY      92.5186
# 1  fx_nr_USD      99.0289
# 2  fx_nr_CHF      97.6474
# 3  fx_nr_GBP     106.3471
# 4  fx_nr_AUD      98.3187
# 5  fx_nr_EUR     101.8488
# 6  fx_nr_CAD     103.1525
# 7  fx_nr_SEK      95.7011
# 8  fx_nr_NOK      93.9336
# 9  fx_nr_NZD      98.0854
#   fx_ticker  narrow_neer
# 0       JPY    -0.074814
# 1       USD    -0.009711
# 2       CHF    -0.023526
# 3       GBP     0.063471
# 4       AUD    -0.016813
# 5       EUR     0.018488
# 6       CAD     0.031525
# 7       SEK    -0.042989
# 8       NOK    -0.060664
# 9       NZD    -0.019146
#   fx_ticker  narrow_neer
# 0       JPY    -0.074814
# 1       USD    -0.009711
# 2       CHF    -0.023526
# 3       GBP     0.063471
# 4       AUD    -0.016813
# 5       EUR     0.018488
# 6       CAD     0.031525
# 7       SEK    -0.042989
# 8       NOK    -0.060664
# 9       NZD    -0.019146
#   fx_ticker  broad_neer
# 0       JPY   -0.078619
# 1       USD   -0.011357
# ...

# %%
#CTTWNRJP Index
#citi_reer

# %%
print("beer")
vb1= 'beer'
#del ady_beer['index']
ady_beer.rename(columns={ ady_beer.columns[0]: "country" }, inplace = True)
ady_beer=ady_beer[["country","Valuation Difference"]]
ady_beer.columns=["country",str(vb1)]
ady_beer['country']=ady_beer['country'].str.lower()
print(ady_beer)
ady_beer=pd.merge(ady_beer, matrix_country,  how='left', left_on=['country'], right_on = ['country'])
ady_beer=ady_beer[ady_beer['d_em']==0]
ady_beer.reset_index(level=0, inplace=True)
del ady_beer['index']
ady_beer=ady_beer[['country',str(vb1),'fx_ticker']]
print(ady_beer)
# Out:
# beer
#            country   beer
# 0      new zealand  0.018
# 1           mexico  0.088
# 2         eurozone -0.011
# 3           norway -0.029
# 4        singapore -0.030
# 5      south korea -0.013
# 6         malaysia  0.006
# 7           canada -0.013
# 8        argentina  0.116
# 9           russia  0.005
# 10            peru -0.078
# 11          taiwan  0.031
# 12        colombia -0.275
# 13           japan -0.057
# 14     switzerland  0.011
# 15           india  0.022
# 16           china  0.012
# 17        thailand -0.018
# 18  czech republic -0.048
# 19          sweden -0.016
# 20         hungary -0.037
# 21          poland -0.031
# 22       indonesia  0.030
# 23  united kingdom  0.032
# 24          israel  0.029
# 25    south africa  0.018
# 26          brazil -0.197
# 27           chile -0.215
# 28          turkey -0.100
# 29       australia -0.011
# 30     philippines  0.025
#           country   beer fx_ticker
# 0     new zealand  0.018       NZD
# ...

# %%
print("reer")
vb2= 'reer_10y'
#del jpm_reer['index']
jpm_reer.rename(columns={ jpm_reer.columns[0]: "country" }, inplace = True)
jpm_reer=jpm_reer[["country","REER (Broad CPI Based) 10yr Avg"]]
jpm_reer.columns=["country",str(vb2)]
jpm_reer['country']=jpm_reer['country'].str.lower()
jpm_reer=pd.merge(jpm_reer, matrix_country,  how='left', left_on=['country'], right_on = ['country'])
jpm_reer=jpm_reer[jpm_reer['d_em']==0]
jpm_reer.reset_index(level=0, inplace=True)
jpm_reer[str(vb2)]=(jpm_reer[str(vb2)]/100)   
del jpm_reer['index']
jpm_reer=jpm_reer[['country',str(vb2),'fx_ticker']]
print(jpm_reer)
# Out:
# reer
#           country  reer_10y fx_ticker
# 0       australia -0.062905       AUD
# 1          canada -0.016816       CAD
# 2        eurozone -0.018949       EUR
# 3           japan -0.130689       JPY
# 4     new zealand  0.015999       NZD
# 5          norway -0.048292       NOK
# 6     switzerland  0.002510       CHF
# 7          sweden -0.062194       SEK
# 8  united kingdom  0.009547       GBP
# 9   united states  0.090082       USD

# %%
####teer
print("fair_value")
fair_value=pd.merge(ady_beer, jpm_reer,  how='left', left_on=['country','fx_ticker'], right_on =['country','fx_ticker'])
print(fair_value)

######teer
fair_value=pd.merge(fair_value, ea_teer,  how='left', left_on=['fx_ticker'], right_on = ['fx_ticker'])
print(fair_value)

###ppp
fair_value=pd.merge(fair_value, ea_ppp,  how='left', left_on=['fx_ticker'], right_on = ['fx_ticker'])
print(fair_value)

####

###ppp
fair_value=pd.merge(fair_value, ea_broad10,  how='left', left_on=['fx_ticker'], right_on = ['fx_ticker'])
print(fair_value)

####

###
fair_value=pd.merge(fair_value, ea_broad20,  how='left', left_on=['fx_ticker'], right_on = ['fx_ticker'])
print(fair_value)



###
fair_value=pd.merge(fair_value, ea_narrow,  how='left', left_on=['fx_ticker'], right_on = ['fx_ticker'])
print(fair_value)




###
fair_value=pd.merge(fair_value, citi_br,  how='left', left_on=['fx_ticker'], right_on = ['fx_ticker'])
print(fair_value)
###
fair_value=pd.merge(fair_value, citi_nr,  how='left', left_on=['fx_ticker'], right_on = ['fx_ticker'])
print(fair_value)
# Out:
# fair_value
#           country   beer fx_ticker  reer_10y
# 0     new zealand  0.018       NZD  0.015999
# 1        eurozone -0.011       EUR -0.018949
# 2          norway -0.029       NOK -0.048292
# 3          canada -0.013       CAD -0.016816
# 4           japan -0.057       JPY -0.130689
# 5     switzerland  0.011       CHF  0.002510
# 6          sweden -0.016       SEK -0.062194
# 7  united kingdom  0.032       GBP  0.009547
# 8       australia -0.011       AUD -0.062905
#           country   beer fx_ticker  reer_10y      teer
# 0     new zealand  0.018       NZD  0.015999 -0.021963
# 1        eurozone -0.011       EUR -0.018949 -0.090893
# 2          norway -0.029       NOK -0.048292 -0.218734
# 3          canada -0.013       CAD -0.016816 -0.177553
# 4           japan -0.057       JPY -0.130689  -0.20237
# 5     switzerland  0.011       CHF  0.002510  0.002338
# 6          sweden -0.016       SEK -0.062194 -0.025763
# 7  united kingdom  0.032       GBP  0.009547 -0.091915
# ...

# %%
####average cahnge


fair_value['avg_score_fv']=fair_value[['beer','reer_10y','teer','ppp',
                                       "broad10","broad20", "narrow","broad_neer","narrow_neer"]].mean(axis=1)
print(fair_value)

fair_value=fair_value[["country","fx_ticker","beer", "reer_10y", "teer", "ppp", "broad10", "broad20", "narrow",
                       "broad_neer","narrow_neer","avg_score_fv"]]
    

fair_value["beer"]=(fair_value["beer"]).round(2)
fair_value["reer_10y"]=(fair_value["reer_10y"]).round(2)
fair_value["teer"]=(fair_value["teer"]).astype(float)
fair_value["teer"]=(fair_value["teer"]).round(2)
fair_value["ppp"]=(fair_value["ppp"]).astype(float)
fair_value["ppp"]=(fair_value["ppp"]).round(2)
fair_value["broad10"]=(fair_value["broad10"]).astype(float)
fair_value["broad10"]=(fair_value["broad10"]).round(2)
fair_value["broad20"]=(fair_value["broad20"]).astype(float)
fair_value["broad20"]=(fair_value["broad20"]).round(2)
fair_value["narrow"]=(fair_value["narrow"]).astype(float)
fair_value["narrow"]=(fair_value["narrow"]).round(2)

fair_value["broad_neer"]=(fair_value["broad_neer"]).astype(float)
fair_value["broad_neer"]=(fair_value["broad_neer"]).round(2)
fair_value["narrow_neer"]=(fair_value["narrow_neer"]).astype(float)
fair_value["narrow_neer"]=(fair_value["narrow_neer"]).round(2)



fair_value["avg_score_fv"]=(fair_value["avg_score_fv"]).round(2)


print("Complete")
now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
#           country   beer fx_ticker  reer_10y      teer       ppp   broad10  \
# 0     new zealand  0.018       NZD  0.015999 -0.021963  0.315417  0.013431
# 1        eurozone -0.011       EUR -0.018949 -0.090893 -0.000373 -0.001971
# 2          norway -0.029       NOK -0.048292 -0.218734 -0.252578 -0.075994
# 3          canada -0.013       CAD -0.016816 -0.177553  0.101268 -0.048464
# 4           japan -0.057       JPY -0.130689  -0.20237   0.03272 -0.105995
# 5     switzerland  0.011       CHF  0.002510  0.002338  0.236344 -0.002475
# 6          sweden -0.016       SEK -0.062194 -0.025763  0.059347 -0.063306
# 7  united kingdom  0.032       GBP  0.009547 -0.091915  0.130848  0.002803
# 8       australia -0.011       AUD -0.062905 -0.184171  0.135032 -0.081195
#
#     broad20  narrow  broad_neer  narrow_neer  avg_score_fv
# 0  0.049002  0.1424   -0.030378    -0.019146      0.053640
# 1 -0.045185  -0.071    0.031279     0.018488     -0.021067
# ...

# %%
print(fair_value)
# Out:
#           country fx_ticker  beer  reer_10y  teer   ppp  broad10  broad20  \
# 0     new zealand       NZD  0.02      0.02 -0.02  0.32     0.01     0.05
# 1        eurozone       EUR -0.01     -0.02 -0.09 -0.00    -0.00    -0.05
# 2          norway       NOK -0.03     -0.05 -0.22 -0.25    -0.08    -0.13
# 3          canada       CAD -0.01     -0.02 -0.18  0.10    -0.05    -0.07
# 4           japan       JPY -0.06     -0.13 -0.20  0.03    -0.11    -0.20
# 5     switzerland       CHF  0.01      0.00  0.00  0.24    -0.00     0.04
# 6          sweden       SEK -0.02     -0.06 -0.03  0.06    -0.06    -0.11
# 7  united kingdom       GBP  0.03      0.01 -0.09  0.13     0.00    -0.06
# 8       australia       AUD -0.01     -0.06 -0.18  0.14    -0.08    -0.06
#
#    narrow  broad_neer  narrow_neer  avg_score_fv
# 0    0.14       -0.03        -0.02          0.05
# 1   -0.07        0.03         0.02         -0.02
# 2   -0.13       -0.05        -0.06         -0.11
# ...

# %%
dateTimeObj = str(datetime.datetime.now())
print(dateTimeObj)
today0 = str(date.today())
# Out:
# 2021-11-25 10:17:59.184452

# %%
os.chdir('K:/2020_2431/q/fx_g10/fair')
print(os.getcwd())

ms = pd.DataFrame(fair_value)
t_label=str("G10  Fair value Models  ("+today0+")")

parameter_sum1 = 13
parameter_sum2 = 5
parameter_fontsize = 9
parameter_t_fontsize = 20
parameter_f_fontsize = 10

p_l=-0.025
p_h=0.025
n=2      
colors = []
for _, row in ms.iterrows():
    colors_in_column = ["w","w","w","w","w","w","w","w","w","w","w","w"]
    if row["beer"]<=(p_l):
        colors_in_column[n] = "g"
    if row["beer"]>=(p_h):
        colors_in_column[n] = "r"
        
        
    if row["reer_10y"]<=(p_l):
        colors_in_column[n+1] = "g"
    if row["reer_10y"]>=(p_h):
        colors_in_column[n+1] = "r"
        
    if row["teer"]<=(p_l):
        colors_in_column[n+2] = "g"   
    if row["teer"]>=(p_h):
        colors_in_column[n+2] = "r"        
    if row["ppp"]<=(p_l):
        colors_in_column[n+3] = "g"
    if row["ppp"]>=(p_h):
        colors_in_column[n+3] = "r"
    if row["broad10"]<=(p_l):
        colors_in_column[n+4] = "g"
    if row["broad10"]>=(p_h):
        colors_in_column[n+4] = "r"    
    if row["broad20"]<=(p_l):
        colors_in_column[n+5] = "g"
    if row["broad20"]>=(p_h):
        colors_in_column[n+5] = "r"   
    if row["narrow"]<=(p_l):
        colors_in_column[n+6] = "g"
    if row["narrow"]>=(p_h):
        colors_in_column[n+6] = "r"      
    
    if row["narrow_neer"]<=(p_l):
        colors_in_column[n+7] = "g"
    if row["narrow_neer"]>=(p_h):
        colors_in_column[n+7] = "r"      

    if row["broad_neer"]<=(p_l):
        colors_in_column[n+8] = "g"
    if row["broad_neer"]>=(p_h):
        colors_in_column[n+8] = "r"      
    colors.append(colors_in_column)
    


# set fig size
fig, ax = plt.subplots(figsize=(parameter_sum1, parameter_sum2)) 
# no axes
ax.xaxis.set_visible(False)  
ax.yaxis.set_visible(False)  
# no frame
ax.set_frame_on(False)  
# plot table
#tab = table(ax, ms, loc='center', cellLoc ='center', cellColours=colores)
tab = table(ax, ms, loc='center', cellLoc ='center', cellColours=colors)


# set font manually
tab.auto_set_font_size(False)
tab.set_fontsize(parameter_fontsize) 
plt.title(str(t_label), 
          size=parameter_t_fontsize,
          loc='center',
          weight='bold',
          color='darkblue')           
#plt.xlabel("TODAY DATE TIME", size=20)
plt.figtext(0.95, 0.05, str(today0),
            horizontalalignment='center',
            size=parameter_f_fontsize,
            weight='light', color='black')
plt.tight_layout()
# save the result
#plt.savefig(location)
plt.savefig("001_fv_summary.pdf")
#plt.savefig(final_location_first+ "001_technical" +final_location_last )
# Out:
# K:\2020_2431\q\fx_g10\fair

# %%
os.chdir('K:/2020_2431/q/fx_g10/fair')

src=r'K:\2020_2431\q\fx_g10\fair\001_fv_summary.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\g10_fx\001_fv_summary.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)

print("Compeltye")
# Out:
# Compeltye

# %%
print("Compeltye")
# Out:
# Compeltye
