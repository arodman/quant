# %%
#regiume aswith inputs


#CDS weekley time series,
#REGIONAL cds (the rest of the region cds average exlcuidng the variablee
    #CDS REGIONS: AVERAGE MREGIONAL CDES SPREASD EXCLUDIGN THE SUBJECT COUNTRY

#Local MSCI	Local
    #Local stock retnr, msci., retunr each week
    #Local stock retnr, msci
#aVERAGE RATING CHANGE. ,, manual, detect change in rating
#Exchange rate	Local
    #fx returns, change in fx

    
#vix weekly chage
    #   weekly vix percentage change#Vix weekly change	Global
#s&p retunr
     ##   is stock sp500 weekly retunr#SP500 Weekly Returns	Global
#   ust t bill yield weekly differnece
    #TREASURY BILL ChANGE#TBILL Weekly difference	Global


#residuals
 #   residual of r local regressed on glibal variables
 #   residual of change fx regressed on glboal varialbers

#Residual of local MSC	Local regresion of locall MSCI EXPLAINED BY  CHANGE IN VIX, SP500 AND ust10y
#Residual of Exchange rate	Local, change in lcoal fx EXPLAINED BY  CHANGE IN VIX, SP500 AND ust10y
#Residual Regional CDS	Local, change in reigonal CDS EXPLAINED BY  CHANGE IN VIX, SP500 AND ust10y


#cange cds			
#resisdual local stock marters			negative
#residuacl cahnge inexncechange rate			mostly positve
#change rating			mostly negative
#residual  of regional cds			positive
#retunr s&p market			negative
#change in vix			positive
#differece in treasury yield			negative


#latam	Brazil
#latam	Chile
#latam	Colombia
#latam	Mexico
#latam	Peru
#emea	Czech Republic
#emea	Russia
#emea	Turkey
#emea	Hungary
#emea	Israel
#emea	Poland
#emea	South Africa
#Asia	China
#Asia	Indonesia
#Asia	Thailand
#Asia	Korea
#Asia	Phillipiness
#Asia	Malaysia







#RTG_MDY_FC_CURR_ISSUER_RATING
#RTG_SP_LT_FC_ISSUER_CREDIT
#RTG_FITCH_LT_FC_DEBT


#Brazil	1323Z BZ Equity
#Colombia	1153Z CB Equity
#Mexico	1426Z MM Equity
#Chile	45793Z CI Equity
#Peru	1131Z PE Equity
#Turkey	114144Z TI Equity
#Russia	4458Z RU Equity
#South Africa	50184Z SJ Equity
#Poland	1084Z PW Equity
#Hungary	1182Z HB Equity
#Israel	3343943Z IT Equity
#Czech Republic	1040Z CP Equity
#Korea	ROKZ KS Equity
#China	PRCH CH Equity
#Indonesia	1133Z IJ Equity
#Malaysia	1124Z MK Equity
#India	1504Z IN Equity
#Philippines	279379Z PM Equity
#Thailand	1179Z TB Equity


#fx returns

#BRL Curncy
#CLP Curncy
#CNH Curncy
#COP Curncy
#CZK Curncy
#HUF Curncy
#IDR Curncy
#ILS Curncy
#INR Curncy
#KRW Curncy
#MXN Curncy
#PEN Curncy
#PLN  Curncy
#RUB Curncy
#TRY Curncy
#ZAR Curncy
#THB Curncy
#TWD Curncy
#MYR Curncy
#INR Curncy
#PHP Curncy

#msci stock retunrs 
#BRL	MSCI	MXBR Index
#CLP	MSCI	MXCL Index
#CNH	MSCI	MXCN Index
#COP	MSCI	MXco Index
#CZK	MSCI	MXCZ Index
#HUF	MSCI	MXHU Index
#IDR	MSCI	MXID index
#ILS	MSCI	MXIL index
#INR	MSCI	MXIN index
#KRW	MSCI	MXKR index
#MXN	MSCI	MXMX Index
#PEN	MSCI	MXPE index
#PLN	MSCI	MXPL index
#RUB	MSCI	MXRU INDEX
#TRY	MSCI	MXTR Index
#ZAR	MSCI	MXZA Index
#THB	MSCI	MXTH Index
#TWD	MSCI	TAMSCI Index
#MYR	MSCI	mxmy index

q=['MXBR Index',
   'MXCL Index','MXCN Index','MXco Index','MXCZ Index','MXHU Index','MXID index','MXIL index',
   'MXIN index','MXKR index','MXMX Index','MXPE index','MXPL index','MXRU INDEX','MXTR Index',
   'MXZA Index','MXTH Index','TAMSCI Index','MXMY index']




#vix weekly chage
#VIX Index	VIX Index		VIX Index
#s&p retunr
#MSCI		
#mxus index		spx index
#TREASURY BILL CANGE
#t bill
#US Generic Govt 10 Yr		
#TREASURY BILL	
#TREASURY BILL
#USGG10YR Index		
#cb12 govt	
#gb12 govt

#residuals
#weekly time series
#for each coutnry do a regression , forecasts and then extract the residual 
#with itnercept
#time horizon is 3 months

#first exmpels msci by weekly change spx, weekly change vix, weccly chnage 10 y treasury
# seocnd explain fx change explainsd by weekly change spx, weekly change vix, weccly chnage 10 y treasury
# thrid esxlaines regional explainsd by weekly change spx, weekly change vix, weccly chnage 10 y treasury

#Intercept
#X1,X2X3
#R SquareF
#Standard ErrorRegressionResidual
#y forecastedresidual


#First only extract weekly CDS adn save it
#will create regional CDS laters
#will oad rating laters
#second extract weekly fx, WILL ALTER TRASNOFMRA
#THRID EXTRACT local msci, wil llater trasnofrm
# foruth extract VIX
#FIFT EXTRACT SP500
#SICTH EXTRACT UST YIELD
#APPEND CONCATENATE ALL COLUMNS AND SAVE ALL
#SAVE csv

# %%
#improt packages

import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas as pd

import pandas
from datetime import datetime
from mdng_client import OTReader
reader = OTReader(tz='America/New_York', env='PROD')

# %%
#parameters

start = '2009-12-31'
end = datetime.today().strftime('%Y-%m-%d')


import pandas as pd 
time = pd.date_range(start=start, end=end, freq='7d')
print(time)
#np.array(times)
#>>> from datetime import datetime as date
#>>> date.today().strftime("%A")
#'Monday'

#time = DataFrame(times,columns=['date'])
print(time)
# Out:
# DatetimeIndex(['2009-12-31', '2010-01-07', '2010-01-14', '2010-01-21',
#                '2010-01-28', '2010-02-04', '2010-02-11', '2010-02-18',
#                '2010-02-25', '2010-03-04',
#                ...
#                '2021-08-12', '2021-08-19', '2021-08-26', '2021-09-02',
#                '2021-09-09', '2021-09-16', '2021-09-23', '2021-09-30',
#                '2021-10-07', '2021-10-14'],
#               dtype='datetime64[ns]', length=616, freq='7D')
# DatetimeIndex(['2009-12-31', '2010-01-07', '2010-01-14', '2010-01-21',
#                '2010-01-28', '2010-02-04', '2010-02-11', '2010-02-18',
#                '2010-02-25', '2010-03-04',
#                ...
#                '2021-08-12', '2021-08-19', '2021-08-26', '2021-09-02',
#                '2021-09-09', '2021-09-16', '2021-09-23', '2021-09-30',
#                '2021-10-07', '2021-10-14'],
#               dtype='datetime64[ns]', length=616, freq='7D')

# %%
#First only extract weekly CDS adn save it
      
#EXTRACT CDS DATA
#argentina_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.AR.5Y.LAST_PRICE', start_date=start).data()
#argentina_cds5y.columns=['argentina_cds5y']
##print(argentina_cds5y)
##argentina cds	mdp	dataquery		CDSI.AR.5Y.LAST_PRICE

####add taiwan

# %%
cds_db = pd.concat([philippines_cds5y,
                     czech_cds5y,
                     thailand_cds5y,
                     turkey_cds5y,
                     indonesia_cds5y,
                     poland_cds5y,
                     malaysia_cds5y,
                     korea_cds5y,
                     mexico_cds5y,
                     southafrica_cds5y,
                     israel_cds5y,
                     hungary_cds5y,
                     colombia_cds5y,
                     chile_cds5y,
                     brazil_cds5y,
                     china_cds5y,
                     russia_cds5y,
                     peru_cds5y], axis=1).fillna(method="ffill").dropna() 


cds_db.head()
cds_db['date'] = cds_db.index
#print(cds_db)
cds_rs=pd.merge(time, cds_db,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
cds_rs.to_csv (r'K:\2020_2431\q\sandbox\cds_rs.csv', index = False, header=True)
#cds_rs=cds_rs
print(cds_rs)

# initialize list of lists
#name_cds = [['argentina', 'CDSI.AR.5Y.LAST_PRICE'], 
#            ['philippines', 'CDSI.PH.5Y.LAST_PRICE'],
#            ['czech republic','CDSI.CZ.5Y.LAST_PRICE'],
#            ['thailand','CDSI.TH.5Y.LAST_PRICE'],
#            ['turkey','CDSI.TR.5Y.LAST_PRICE'],
#            ['indonesia','CDSI.ID.5Y.LAST_PRICE'],
#            ['poland','CDSI.PL.5Y.LAST_PRICE'],
#           ['malaysia','CDSI.MY.5Y.LAST_PRICE'],
##           ['korea','CDSI.KR.5Y.LAST_PRICE'],
#           ['mexico','CDSI.MX.5Y.LAST_PRICE'],
#           ['south africa','CDSI.ZA.5Y.LAST_PRICE'],
#           ['israel','CDSI.IL.5Y.LAST_PRICE'],
##          ['hungary','CDSI.HU.5Y.LAST_PRICE'],
#          ['colombia','CDSI.CO.5Y.LAST_PRICE'],
#          ['chile','CDSI.CL.5Y.LAST_PRICE'],
#         ['brazil','CDSI.BR.5Y.LAST_PRICE'],
##         ['china','CDSI.CN.5Y.LAST_PRICE'],
#         ['russia','CDSI.RU.5Y.LAST_PRICE'],
#         ['peru','CDSI.PE.5Y.LAST_PRICE']]


#cds_tmp.to_csv (r'K:\2020_2431\q\sandbox\cds_tmp.csv', index = True, header=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-0a169cc1e5aa> in <module>
#      22 cds_db['date'] = cds_db.index
#      23 #print(cds_db)
# ---> 24 cds_rs=pd.merge(time, cds_db,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
#      25 cds_rs.to_csv (r'K:\2020_2431\q\sandbox\cds_rs.csv', index = False, header=True)
#      26 #cds_rs=cds_rs
#
# C:\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ...

# %%
####inr?
#'FX.USD.INR.SPOT.LAST_PRICE',
#'FX_INR'
#FX.USD.BRL.SPOT.LAST_PRICE	bloomberg	BRL CMPN Curncy	LAST_PRICE	FX	fx
#FX.USD.BRL.SPOT.LAST_PRICE	bloomberg	BRL CMPN Curncy	LAST_PRICE	FX	fx	

#time stamp

symbols = ['FX.USD.BRL.SPOT.LAST_PRICE',
           'FX.USD.CLP.SPOT.LAST_PRICE',
           'FX.USD.CNH.SPOT.LAST_PRICE',
           'FX.USD.COP.SPOT.LAST_PRICE',
           'FX.USD.CZK.SPOT.LAST_PRICE',
           'FX.USD.IDR.SPOT.LAST_PRICE',
           'FX.USD.ILS.SPOT.LAST_PRICE',
           'FX.USD.INR.SPOT.LAST_PRICE',
           'FX.USD.KRW.SPOT.LAST_PRICE',
           'FX.USD.MXN.SPOT.LAST_PRICE',
           'FX.USD.PEN.SPOT.LAST_PRICE',
           'FX.USD.PLN.SPOT.LAST_PRICE',
           'FX.USD.RUB.SPOT.LAST_PRICE',
           'FX.USD.TRY.SPOT.LAST_PRICE',
           'FX.USD.ZAR.SPOT.LAST_PRICE',
           'FX.USD.THB.SPOT.LAST_PRICE',
           'FX.USD.TWD.SPOT.LAST_PRICE',
           'FX.USD.MYR.SPOT.LAST_PRICE',           
           'FX.USD.PHP.SPOT.LAST_PRICE'         
          ]

symbols = ['BBGTKR::BLOOMBERG::BRL CURNCY','BBGTKR::BLOOMBERG::CLP CURNCY',
          'BBGTKR::BLOOMBERG::CNH CURNCY','BBGTKR::BLOOMBERG::COP CURNCY',
          'BBGTKR::BLOOMBERG::CZK CURNCY','BBGTKR::BLOOMBERG::IDR CURNCY',
          'BBGTKR::BLOOMBERG::ILS CURNCY','BBGTKR::BLOOMBERG::INR CURNCY',
          'BBGTKR::BLOOMBERG::KRW CURNCY','BBGTKR::BLOOMBERG::MXN CURNCY',
          'BBGTKR::BLOOMBERG::PEN CURNCY','BBGTKR::BLOOMBERG::PLN CURNCY',
          'BBGTKR::BLOOMBERG::RUB CURNCY','BBGTKR::BLOOMBERG::HUF CURNCY',
          'BBGTKR::BLOOMBERG::ZAR CURNCY','BBGTKR::BLOOMBERG::THB CURNCY',
          'BBGTKR::BLOOMBERG::TWD CURNCY','BBGTKR::BLOOMBERG::MYR CURNCY',
          'BBGTKR::BLOOMBERG::PHP CURNCY','BBGTKR::BLOOMBERG::TRY CURNCY']


# # notice here we are retrieving data from dataquery and bloomberg using the bloomberg ticker

fx =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
fx.head()
fx=fx.fillna(method='bfill')
fx=pd.merge(time, fx,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
fx.to_csv (r'K:\2020_2431\q\sandbox\fx_tmp.csv', index = False, header=True)


#fx=fx.reset_index()
#fx.head()
#fx.columns==[['FX_BRL','FX_CLP','FX_CNH','FX_COP','FX_CZK','FX_IDR','FX_ILS','FX_INR','FX_KRW','FX_MXN', 'FX_PEN','FX_PLN','FX_RUB','FX_TRY','FX_ZAR','FX_THB','FX_TWD','FX_MYR','FX_PHP']]
#fx.head()
#ticker','date'

# %%
fx.tail()
#fx = MarketDataProvider(source='bloomberg', tickers=symbols, start_date=start).data()
#fx=fx.reset_index()
#fx=fx.reset_index(level=1, inplace=True)
#print(fx.Date)

#fx['date_1'] = fx.index

#print(fx.columns)
#print(fx)
#fx['date_1'] = fx.index
#print(fx)
#list(fx.columns)
#list(time.columns)
#fx=pd.merge(time, fx,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
#print(fx)
#cds_rs=cds_rs
#print(cds_rs)



#korea cds	mdp	dataquery		CDSI.KR.5Y.LAST_PRICE

# %%
#Equities MSCI INDEX EXTRACT
symbols = ['BBGTKR::BLOOMBERG::MXBR Index','BBGTKR::BLOOMBERG::MXCL Index',
          'BBGTKR::BLOOMBERG::MXCN Index','BBGTKR::BLOOMBERG::MXCO Index',
          'BBGTKR::BLOOMBERG::MXCZ Index','BBGTKR::BLOOMBERG::MXHU Index',
          'BBGTKR::BLOOMBERG::MXIL Index','BBGTKR::BLOOMBERG::MXIN Index',
          'BBGTKR::BLOOMBERG::MXKR Index','BBGTKR::BLOOMBERG::MXMX Index',
          'BBGTKR::BLOOMBERG::MXPE Index','BBGTKR::BLOOMBERG::MXPL Index',
          'BBGTKR::BLOOMBERG::MXRU Index','BBGTKR::BLOOMBERG::MXTR Index',
          'BBGTKR::BLOOMBERG::MXZA Index','BBGTKR::BLOOMBERG::MXTH Index',
          'BBGTKR::BLOOMBERG::TAMSCI Index','BBGTKR::BLOOMBERG::MXMY Index',
          'BBGTKR::BLOOMBERG::PHP CURNCY','BBGTKR::BLOOMBERG::MXID Index']



#MXBR Index 'EQIDX.BR_MSCI.USD.LAST_PRICE'
#MXCL Index 'EQIDX.CL_MSCI.USD.LAST_PRICE' 
#MXCN Index 'EQIDX.CN_MSCI.HKD.LAST_PRICE
#MXco Index 'EQIDX.CO_MSCI.USD.LAST_PRICE
#MXCZ Index 'EQIDX.CZ_MSCI.CZK.LAST_PRICE'
#MXHU Index EQIDX.HU_MSCI.HUF.LAST_PRICE
#MXID index EQIDX.ID_MSCI.IDR.LAST_PRICE
#MXIL index xxxxxxx
#MXIN index EQIDX.IN_MSCI.INR.LAST_PRICE
#MXKR index EQIDX.KR_MSCI.KRW.LAST_PRICE
#MXMX Index EQIDX.MX_MSCI.USD.LAST_PRICE
#MXPE index EQIDX.PE_MSCI.USD.LAST_PRICE
#MXPL index EQIDX.PL_MSCI.PLN.LAST_PRICE
#MXRU INDEX EQIDX.RU_MSCI.USD.LAST_PRICE
#MXTR Index EQIDX.TR_MSCI.TRY.LAST_PRICE
#MXZA Index EQIDX.ZA_MSCI.ZAR.LAST_PRICE
#MXTH Index EQIDX.TH_MSCI.THB.LAST_PRICE
#TAMSCI Index EQIDX.TAMSCI.TWD.LAST_PRICE
#MXMY index EQIDX.MY_MSCI.MYR.LAST_PRICE
#mxph

#msci local equity returns



#MXBR Index 'EQIDX.BR_MSCI.USD.LAST_PRICE'
#MXCL Index 'EQIDX.CL_MSCI.USD.LAST_PRICE' 
#MXCN Index 'EQIDX.CN_MSCI.HKD.LAST_PRICE
#MXco Index 'EQIDX.CO_MSCI.USD.LAST_PRICE
#MXCZ Index 'EQIDX.CZ_MSCI.CZK.LAST_PRICE'
#MXHU Index EQIDX.HU_MSCI.HUF.LAST_PRICE
#MXID index EQIDX.ID_MSCI.IDR.LAST_PRICE
#MXIL index xxxxxxx
#MXIN index EQIDX.IN_MSCI.INR.LAST_PRICE
#MXKR index EQIDX.KR_MSCI.KRW.LAST_PRICE
#MXMX Index EQIDX.MX_MSCI.USD.LAST_PRICE
#MXPE index EQIDX.PE_MSCI.USD.LAST_PRICE
#MXPL index EQIDX.PL_MSCI.PLN.LAST_PRICE
#MXRU INDEX EQIDX.RU_MSCI.USD.LAST_PRICE
#MXTR Index EQIDX.TR_MSCI.TRY.LAST_PRICE
#MXZA Index EQIDX.ZA_MSCI.ZAR.LAST_PRICE
#MXTH Index EQIDX.TH_MSCI.THB.LAST_PRICE
#TAMSCI Index EQIDX.TAMSCI.TWD.LAST_PRICE
#MXMY index EQIDX.MY_MSCI.MYR.LAST_PRICE


# # notice here we are retrieving data from dataquery and bloomberg using the bloomberg ticker

l_msci =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
l_msci.head()
l_msci=l_msci.fillna(method='bfill')
l_msci=pd.merge(time, l_msci,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
l_msci.to_csv (r'K:\2020_2431\q\sandbox\l_msci_tmp.csv', index = False, header=True)

# %%
#VOLUME

# %%
#Vix
vix =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::VIX INDEX'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
vix.head()
vix=vix.fillna(method='bfill')
vix=pd.merge(time, vix,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
vix.to_csv (r'K:\2020_2431\q\sandbox\vix_tmp.csv', index = False, header=True)

# %%
#s&p retunr
     ##   is stock sp500 weekly retunr#SP500 Weekly Returns	Global
msci_us =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::MXUS INDEX'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
msci_us.head()
msci_us=msci_us.fillna(method='bfill')
msci_us=pd.merge(time, msci_us,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
msci_us.to_csv (r'K:\2020_2431\q\sandbox\msci_us_tmp.csv', index = False, header=True)

# %%
# ust t bill yield weekly differnece
#TREASURY BILL ChANGE#TBILL Weekly difference	Global
#TREASURY BILL CANGE

ust =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::USGG10YR Index'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
ust.head()
ust=ust.fillna(method='bfill')
ust=pd.merge(time, ust,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
ust.to_csv (r'K:\2020_2431\q\sandbox\ust_tmp.csv', index = False, header=True)

    

#t bill
#US Generic Govt 10 Yr		#
#TREASURY BILL	
#TREASURY BILL
#USGG10YR Index		
#cb12 govt	
#gb12 govt

# %%
print("COmpelte ")
