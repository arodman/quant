# %%
#REGIME SWITCHING PRIOCESS


#CDS weekley time series,
#REGIONAL cds (the rest of the region cds average exlcuidng the variablee
    #CDS REGIONS: AVERAGE MREGIONAL CDES SPREASD EXCLUDIGN THE SUBJECT COUNTRY

#Local MSCI	Local
    #Local stock retnr, msci., retunr each week
    #Local stock retnr, msci
#aVERAGE RATING CHANGE. ,, manual, detect change in rating
#Exchange rate	Local
    #fx returns, change in fx

    
#vix weekly chage
    #   weekly vix percentage change#Vix weekly change	Global
#s&p retunr
     ##   is stock sp500 weekly retunr#SP500 Weekly Returns	Global
#   ust t bill yield weekly differnece
    #TREASURY BILL ChANGE#TBILL Weekly difference	Global


#residuals
 #   residual of r local regressed on glibal variables
 #   residual of change fx regressed on glboal varialbers

#Residual of local MSC	Local regresion of locall MSCI EXPLAINED BY  CHANGE IN VIX, SP500 AND ust10y
#Residual of Exchange rate	Local, change in lcoal fx EXPLAINED BY  CHANGE IN VIX, SP500 AND ust10y
#Residual Regional CDS	Local, change in reigonal CDS EXPLAINED BY  CHANGE IN VIX, SP500 AND ust10y


#cange cds			
#resisdual local stock marters			negative
#residuacl cahnge inexncechange rate			mostly positve
#change rating			mostly negative
#residual  of regional cds			positive
#retunr s&p market			negative
#change in vix			positive
#differece in treasury yield			negative


#of 11 representative emerging countries in four different geographic regions, namely Asia (China, Korea and Malaysia), Europe (Poland, Russia and Turkey), Latin America (Brazil, Colombia and Venezuela) and Middle East/Africa (Israel and South Africa)				
#Weekly data				
#In the regressions, we use the weekly changes of SCDS spreads as the dependent variabl				
#y is the weekly changes				
#a number of explanatory variables in the regressions including local financial variables, fundamental economic variables and global financial variables				
#local stock market return and the change in exchange rate against US Dollar (USD) are selected as the explanatory variables representing local market.				

	
#the changes in SCDS spreads tend to be associated with the changes in local financial variables such as local stock index and exchange rates				
#Local stock indices are denominated in local currency and exchange rates are quoted as local currency per USD				

#1				
#ocal stock market indicates good market condition that results in a tightening of SCDS spread				
#xpect the local stock market return and the change in SCDS spreads to move in opposite directions				

#1#ncreasing local currency exchange rate (as denoted by local currency value per USD), suggesting depreciating local currency value and deteriorating local economy, is expected to be related to an increase in SCDS spread				

#2
#the sovereign credit rating of the country as assigned by Standard & Poor’s (S&P’s) as another potential variable in explaining the variation of the country’s SCDS.				
#country’s sovereign rating is considered to be a measure of the fundamental economic and political outlook of the country. I				
#e expect an improvement in the credit rating (e.g., from A to AA) to be associated with a decrease in the country’s SCDS spread				

#3
#we use the US stock market return, change in US T-Bill yield and the change of VIX to proxy for the global financial market changes VIX is the CBOE volatility index defined as the forward-looking volatility of US stock market return				
#A higher return on the US stock market indicates good global market conditions so does an increase in the US T-Bill yield. We therefore expect increases of US stock market return and T-Bill yield lead to a tightening of the SCDS spreads.				
#On the other hand, increasing VIX means a worsening outlook of the global market hence leading to a widening of SCDS spreads for all countries.				
#####
#We include regional average SCDS as an explanatory variable to capture the regional effec				
#For each country, we calculate the regional SCDS spread change as the average SCDS spread change of the other countries in the same region.				
#To better capture the effect of regional influence, we consider both the raw average regional spread change and the residuals of the average regional spread changes after controlling for the global effects				
#The residual is obtained by running an ordinary least square (OLS) regression of the average regional spread changes against the above global variables (i.e., US stock market return, US T-Bill yield and VIX change).				
#We expect a country’s SCDS spread to move in the same direction as its regional SCDS spread.

# %%
#improt packages

import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from statsmodels.regression.rolling import RollingOLS
import matplotlib.pyplot as plt
import numpy as np # numerical python
import pandas as pd # pannel datasets
import matplotlib.pyplot as plt 
import seaborn as sns
from datetime import date

#stacked
import tkinter
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('TkAgg')
import pandas as pd

import pandas as pd 
import os

import PIL
from PIL import Image
#import os
from PyPDF2 import PdfFileMerger
from PyPDF2 import PdfFileMerger



######
####related to regim swithc plot 

import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import requests
from io import BytesIO

# NBER recessions
#from pandas_datareader.data import DataReader
from datetime import datetime

import matplotlib.pyplot as plt
import matplotlib.ticker as plticke
#print(df_rs)
import statsmodels.formula.api as smf
#import imgkit
#import wkhtmltopdf

import dataframe_image as dfi



import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt

import matplotlib.ticker as ticker
import matplotlib.ticker as plticker

from codetiming import Timer
timeclock = Timer(name="class")
timeclock.start()

# %%
#parameters

start = '2009-12-31'
end = datetime.today().strftime('%Y-%m-%d')



time = pd.date_range(start=start, end=end, freq='7d')
print(time)
#np.array(times)
#>>> from datetime import datetime as date
#>>> date.today().strftime("%A")
#'Monday'

time = DataFrame(time,columns=['date'])
print(time)
# Out:
# DatetimeIndex(['2009-12-31', '2010-01-07', '2010-01-14', '2010-01-21',
#                '2010-01-28', '2010-02-04', '2010-02-11', '2010-02-18',
#                '2010-02-25', '2010-03-04',
#                ...
#                '2021-06-03', '2021-06-10', '2021-06-17', '2021-06-24',
#                '2021-07-01', '2021-07-08', '2021-07-15', '2021-07-22',
#                '2021-07-29', '2021-08-05'],
#               dtype='datetime64[ns]', length=606, freq='7D')
#           date
# 0   2009-12-31
# 1   2010-01-07
# 2   2010-01-14
# 3   2010-01-21
# 4   2010-01-28
# ..         ...
# 601 2021-07-08
# 602 2021-07-15
# 603 2021-07-22
# 604 2021-07-29
# 605 2021-08-05
#
# [606 rows x 1 columns]

# %%
#load data base and then create weekly variatons
cds_rs = pd.read_csv (r'K:\2020_2431\q\sandbox\cds_rs.csv')
print(cds_rs.columns)


#brazil_cds5y
cds_rs['wv_brazil_cds5y']= ((cds_rs.brazil_cds5y.diff()) /(cds_rs.brazil_cds5y.shift())).round(6)
cds_rs['wd_brazil_cds5y']= ((cds_rs.brazil_cds5y.diff())).round(6)
#chile_cds5y
cds_rs['wv_chile_cds5y']= ((cds_rs.chile_cds5y.diff()) /(cds_rs.chile_cds5y.shift())).round(6)
cds_rs['wd_chile_cds5y']= ((cds_rs.chile_cds5y.diff())).round(6)
#china_cds5y
cds_rs['wv_china_cds5y']= ((cds_rs.china_cds5y.diff()) /(cds_rs.china_cds5y.shift())).round(6)
cds_rs['wd_china_cds5y']= ((cds_rs.china_cds5y.diff())).round(6)
#COP_reg_cds5y
cds_rs['wv_colombia_cds5y']= ((cds_rs.colombia_cds5y.diff()) /(cds_rs.colombia_cds5y.shift())).round(6)
cds_rs['wd_colombia_cds5y']= ((cds_rs.colombia_cds5y.diff())).round(6)
#FX_CZK
cds_rs['wv_czech_cds5y']= ((cds_rs.czech_cds5y.diff()) /(cds_rs.czech_cds5y.shift())).round(6)
cds_rs['wd_czech_cds5y']= ((cds_rs.czech_cds5y.diff())).round(6)
#FX_IDR
cds_rs['wv_indonesia_cds5y']= ((cds_rs.indonesia_cds5y.diff()) /(cds_rs.indonesia_cds5y.shift())).round(6)
cds_rs['wd_indonesia_cds5y']= ((cds_rs.indonesia_cds5y.diff())).round(6)
#FX_ILS
cds_rs['wv_israel_cds5y']= ((cds_rs.israel_cds5y.diff()) /(cds_rs.israel_cds5y.shift())).round(6)
cds_rs['wd_israel_cds5y']= ((cds_rs.israel_cds5y.diff())).round(6)
#FX_INR
#cds_rs['wv_FX_INR']= ((cds_rs.FX_INR.diff()) /(cds_rs.FX_INR.shift())).round(6)
#cds_rs['wd_FX_INR']= ((cds_rs.FX_INR.diff())).round(6)
#FX_KRW
cds_rs['wv_korea_cds5y']= ((cds_rs.korea_cds5y.diff()) /(cds_rs.korea_cds5y.shift())).round(6)
cds_rs['wd_korea_cds5y']= ((cds_rs.korea_cds5y.diff())).round(6)
#FMXN_reg_cds5y
cds_rs['wv_mexico_cds5y']= ((cds_rs.mexico_cds5y.diff()) /(cds_rs.mexico_cds5y.shift())).round(6)
cds_rs['wd_mexico_cds5y']= ((cds_rs.mexico_cds5y.diff())).round(6)
#peru_cds5y
cds_rs['wv_peru_cds5y']= ((cds_rs.peru_cds5y.diff()) /(cds_rs.peru_cds5y.shift())).round(6)
cds_rs['wd_peru_cds5y']= ((cds_rs.peru_cds5y.diff())).round(6)
#PLN_reg_cds5y
cds_rs['wv_poland_cds5y']= ((cds_rs.poland_cds5y.diff()) /(cds_rs.poland_cds5y.shift())).round(6)
cds_rs['wd_poland_cds5y']= ((cds_rs.poland_cds5y.diff())).round(6)
#russia_cds5y
cds_rs['wv_russia_cds5y']= ((cds_rs.russia_cds5y.diff()) /(cds_rs.russia_cds5y.shift())).round(6)
cds_rs['wd_russia_cds5y']= ((cds_rs.russia_cds5y.diff())).round(6)
#TRY_reg_cds5y
cds_rs['wv_turkey_cds5y']= ((cds_rs.turkey_cds5y.diff()) /(cds_rs.turkey_cds5y.shift())).round(6)
cds_rs['wd_turkey_cds5y']= ((cds_rs.turkey_cds5y.diff())).round(6)
#ZAR_reg_cds5y
cds_rs['wv_southafrica_cds5y']= ((cds_rs.southafrica_cds5y.diff()) /(cds_rs.southafrica_cds5y.shift())).round(6)
cds_rs['wd_southafrica_cds5y']= ((cds_rs.southafrica_cds5y.diff())).round(6)
#THB_reg_cds5y
cds_rs['wv_thailand_cds5y']= ((cds_rs.thailand_cds5y.diff()) /(cds_rs.thailand_cds5y.shift())).round(6)
cds_rs['wd_thailand_cds5y']= ((cds_rs.thailand_cds5y.diff())).round(6)
##FX_TWD
#cds_rs['wv_FX_TWD']= ((cds_rs.FX_TWD.diff()) /(cds_rs.FX_TWD.shift())).round(6)
#cds_rs['wd_FX_TWD']= ((cds_rs.FX_TWD.diff())).round(6)
#FX_MYR
cds_rs['wv_malaysia_cds5y']= ((cds_rs.malaysia_cds5y.diff()) /(cds_rs.malaysia_cds5y.shift())).round(6)
cds_rs['wd_malaysia_cds5y']= ((cds_rs.malaysia_cds5y.diff())).round(6)
#FX_PHP
cds_rs['wv_philippines_cds5y']= ((cds_rs.philippines_cds5y.diff()) /(cds_rs.philippines_cds5y.shift())).round(6)
cds_rs['wd_philippines_cds5y']= ((cds_rs.philippines_cds5y.diff())).round(6)
#FX_HUF
cds_rs['wv_hungary_cds5y']= ((cds_rs.hungary_cds5y.diff()) /(cds_rs.hungary_cds5y.shift())).round(6)
cds_rs['wd_hungary_cds5y']= ((cds_rs.hungary_cds5y.diff())).round(6)



#REGIONAL CDS

cds_rs['BRL_reg_cds5y']=cds_rs[['colombia_cds5y','mexico_cds5y','peru_cds5y','chile_cds5y']].mean(axis=1)
cds_rs['CLP_reg_cds5y']=cds_rs[['colombia_cds5y','mexico_cds5y','peru_cds5y','brazil_cds5y']].mean(axis=1)  
cds_rs['COP_reg_cds5y']=cds_rs[['chile_cds5y','mexico_cds5y','peru_cds5y','brazil_cds5y']].mean(axis=1)  
cds_rs['PEN_reg_cds5y']=cds_rs[['chile_cds5y','mexico_cds5y','colombia_cds5y','brazil_cds5y']].mean(axis=1) 
cds_rs['MXN_reg_cds5y']=cds_rs[['chile_cds5y','peru_cds5y','colombia_cds5y','brazil_cds5y']].mean(axis=1)    


cds_rs['CZK_reg_cds5y']=cds_rs[['hungary_cds5y','russia_cds5y','southafrica_cds5y',
                                'israel_cds5y','poland_cds5y','turkey_cds5y']].mean(axis=1)
cds_rs['HUF_reg_cds5y']=cds_rs[['czech_cds5y','russia_cds5y','southafrica_cds5y',
                                'israel_cds5y','poland_cds5y','turkey_cds5y']].mean(axis=1)
cds_rs['RUB_reg_cds5y']=cds_rs[['czech_cds5y','hungary_cds5y','southafrica_cds5y',
                                'israel_cds5y','poland_cds5y','turkey_cds5y']].mean(axis=1)
cds_rs['ZAR_reg_cds5y']=cds_rs[['czech_cds5y','hungary_cds5y','russia_cds5y',
                                'israel_cds5y','poland_cds5y','turkey_cds5y']].mean(axis=1)
cds_rs['PLN_reg_cds5y']=cds_rs[['czech_cds5y','hungary_cds5y','russia_cds5y',
                                'israel_cds5y','southafrica_cds5y','turkey_cds5y']].mean(axis=1)
cds_rs['ILS_reg_cds5y']=cds_rs[['czech_cds5y','hungary_cds5y','russia_cds5y',
                                'poland_cds5y','southafrica_cds5y','turkey_cds5y']].mean(axis=1) 
cds_rs['TRY_reg_cds5y']=cds_rs[['czech_cds5y','hungary_cds5y','russia_cds5y',
                                'poland_cds5y','southafrica_cds5y','israel_cds5y']].mean(axis=1) 
      
cds_rs['PHP_reg_cds5y']=cds_rs[['thailand_cds5y','china_cds5y',
                                'indonesia_cds5y','malaysia_cds5y','korea_cds5y']].mean(axis=1) 
cds_rs['THB_reg_cds5y']=cds_rs[['philippines_cds5y','china_cds5y',
                                'indonesia_cds5y','malaysia_cds5y','korea_cds5y']].mean(axis=1) 
cds_rs['CNH_reg_cds5y']=cds_rs[['thailand_cds5y','philippines_cds5y',
                                'indonesia_cds5y','malaysia_cds5y','korea_cds5y']].mean(axis=1) 
cds_rs['KRW_reg_cds5y']=cds_rs[['thailand_cds5y','china_cds5y',
                                'indonesia_cds5y','malaysia_cds5y','philippines_cds5y']].mean(axis=1) 
cds_rs['MYR_reg_cds5y']=cds_rs[['thailand_cds5y','china_cds5y',
                                'indonesia_cds5y','philippines_cds5y','korea_cds5y']].mean(axis=1) 
cds_rs['IDR_reg_cds5y']=cds_rs[['thailand_cds5y','china_cds5y',
                                'malaysia_cds5y','philippines_cds5y','korea_cds5y']].mean(axis=1) 

print(cds_rs.columns)



#BRL_reg_cds5y
cds_rs['wv_BRL_reg_cds5y']= ((cds_rs.BRL_reg_cds5y.diff()) /(cds_rs.BRL_reg_cds5y.shift())).round(6)
cds_rs['wd_BRL_reg_cds5y']= ((cds_rs.BRL_reg_cds5y.diff())).round(6)
#CLP_reg_cds5y
cds_rs['wv_CLP_reg_cds5y']= ((cds_rs.CLP_reg_cds5y.diff()) /(cds_rs.CLP_reg_cds5y.shift())).round(6)
cds_rs['wd_CLP_reg_cds5y']= ((cds_rs.CLP_reg_cds5y.diff())).round(6)
#CNH_reg_cds5y
cds_rs['wv_CNH_reg_cds5y']= ((cds_rs.CNH_reg_cds5y.diff()) /(cds_rs.CNH_reg_cds5y.shift())).round(6)
cds_rs['wd_CNH_reg_cds5y']= ((cds_rs.CNH_reg_cds5y.diff())).round(6)
#COP_reg_cds5y
cds_rs['wv_COP_reg_cds5y']= ((cds_rs.COP_reg_cds5y.diff()) /(cds_rs.COP_reg_cds5y.shift())).round(6)
cds_rs['wd_COP_reg_cds5y']= ((cds_rs.COP_reg_cds5y.diff())).round(6)
#FX_CZK
cds_rs['wv_CZK_reg_cds5y']= ((cds_rs.CZK_reg_cds5y.diff()) /(cds_rs.CZK_reg_cds5y.shift())).round(6)
cds_rs['wd_CZK_reg_cds5y']= ((cds_rs.CZK_reg_cds5y.diff())).round(6)
#FX_IDR
cds_rs['wv_IDR_reg_cds5y']= ((cds_rs.IDR_reg_cds5y.diff()) /(cds_rs.IDR_reg_cds5y.shift())).round(6)
cds_rs['wd_IDR_reg_cds5y']= ((cds_rs.IDR_reg_cds5y.diff())).round(6)
#FX_ILS
cds_rs['wv_ILS_reg_cds5y']= ((cds_rs.ILS_reg_cds5y.diff()) /(cds_rs.ILS_reg_cds5y.shift())).round(6)
cds_rs['wd_ILS_reg_cds5y']= ((cds_rs.ILS_reg_cds5y.diff())).round(6)
#FX_INR
#cds_rs['wv_FX_INR']= ((cds_rs.FX_INR.diff()) /(cds_rs.FX_INR.shift())).round(6)
#cds_rs['wd_FX_INR']= ((cds_rs.FX_INR.diff())).round(6)
#FX_KRW
cds_rs['wv_KRW_reg_cds5y']= ((cds_rs.KRW_reg_cds5y.diff()) /(cds_rs.KRW_reg_cds5y.shift())).round(6)
cds_rs['wd_KRW_reg_cds5y']= ((cds_rs.KRW_reg_cds5y.diff())).round(6)
#FMXN_reg_cds5y
cds_rs['wv_MXN_reg_cds5y']= ((cds_rs.MXN_reg_cds5y.diff()) /(cds_rs.MXN_reg_cds5y.shift())).round(6)
cds_rs['wd_MXN_reg_cds5y']= ((cds_rs.MXN_reg_cds5y.diff())).round(6)
#PEN_reg_cds5y
cds_rs['wv_PEN_reg_cds5y']= ((cds_rs.PEN_reg_cds5y.diff()) /(cds_rs.PEN_reg_cds5y.shift())).round(6)
cds_rs['wd_PEN_reg_cds5y']= ((cds_rs.PEN_reg_cds5y.diff())).round(6)
#PLN_reg_cds5y
cds_rs['wv_PLN_reg_cds5y']= ((cds_rs.PLN_reg_cds5y.diff()) /(cds_rs.PLN_reg_cds5y.shift())).round(6)
cds_rs['wd_PLN_reg_cds5y']= ((cds_rs.PLN_reg_cds5y.diff())).round(6)
#RUB_reg_cds5y
cds_rs['wv_RUB_reg_cds5y']= ((cds_rs.RUB_reg_cds5y.diff()) /(cds_rs.RUB_reg_cds5y.shift())).round(6)
cds_rs['wd_RUB_reg_cds5y']= ((cds_rs.RUB_reg_cds5y.diff())).round(6)
#TRY_reg_cds5y
cds_rs['wv_TRY_reg_cds5y']= ((cds_rs.TRY_reg_cds5y.diff()) /(cds_rs.TRY_reg_cds5y.shift())).round(6)
cds_rs['wd_TRY_reg_cds5y']= ((cds_rs.TRY_reg_cds5y.diff())).round(6)
#ZAR_reg_cds5y
cds_rs['wv_ZAR_reg_cds5y']= ((cds_rs.ZAR_reg_cds5y.diff()) /(cds_rs.ZAR_reg_cds5y.shift())).round(6)
cds_rs['wd_ZAR_reg_cds5y']= ((cds_rs.ZAR_reg_cds5y.diff())).round(6)
#THB_reg_cds5y
cds_rs['wv_THB_reg_cds5y']= ((cds_rs.THB_reg_cds5y.diff()) /(cds_rs.THB_reg_cds5y.shift())).round(6)
cds_rs['wd_THB_reg_cds5y']= ((cds_rs.THB_reg_cds5y.diff())).round(6)
##FX_TWD
#cds_rs['wv_FX_TWD']= ((cds_rs.FX_TWD.diff()) /(cds_rs.FX_TWD.shift())).round(6)
#cds_rs['wd_FX_TWD']= ((cds_rs.FX_TWD.diff())).round(6)
#FX_MYR
cds_rs['wv_MYR_reg_cds5y']= ((cds_rs.MYR_reg_cds5y.diff()) /(cds_rs.MYR_reg_cds5y.shift())).round(6)
cds_rs['wd_MYR_reg_cds5y']= ((cds_rs.MYR_reg_cds5y.diff())).round(6)
#FX_PHP
cds_rs['wv_PHP_reg_cds5y']= ((cds_rs.PHP_reg_cds5y.diff()) /(cds_rs.PHP_reg_cds5y.shift())).round(6)
cds_rs['wd_PHP_reg_cds5y']= ((cds_rs.PHP_reg_cds5y.diff())).round(6)
#FX_HUF
cds_rs['wv_HUF_reg_cds5y']= ((cds_rs.HUF_reg_cds5y.diff()) /(cds_rs.HUF_reg_cds5y.shift())).round(6)
cds_rs['wd_HUF_reg_cds5y']= ((cds_rs.HUF_reg_cds5y.diff())).round(6)


print(cds_rs.columns)
print(cds_rs)

cds_rs.to_csv (r'K:\2020_2431\q\sandbox\cds_rs_0.csv', index = False, header=True)
# Out:
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y', 'southafrica_cds5y', 'israel_cds5y',
#        'hungary_cds5y', 'colombia_cds5y', 'chile_cds5y', 'brazil_cds5y',
#        'china_cds5y', 'russia_cds5y', 'peru_cds5y'],
#       dtype='object')
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y', 'southafrica_cds5y', 'israel_cds5y',
#        'hungary_cds5y', 'colombia_cds5y', 'chile_cds5y', 'brazil_cds5y',
#        'china_cds5y', 'russia_cds5y', 'peru_cds5y', 'wv_brazil_cds5y',
#        'wd_brazil_cds5y', 'wv_chile_cds5y', 'wd_chile_cds5y', 'wv_china_cds5y',
#        'wd_china_cds5y', 'wv_colombia_cds5y', 'wd_colombia_cds5y',
#        'wv_czech_cds5y', 'wd_czech_cds5y', 'wv_indonesia_cds5y',
# ...

# %%
#load fx database and then create  variations
fx_rs = pd.read_csv (r'K:\2020_2431\q\sandbox\fx_tmp.csv')


#fx_rs.columns=['date','FX_BRL','FX_CLP','FX_CNH','FX_COP','FX_CZK','FX_IDR','FX_ILS','FX_INR','FX_KRW','FX_MXN',
#               'FX_PEN','FX_PLN','FX_RUB','FX_TRY','FX_ZAR','FX_THB','FX_TWD','FX_MYR','FX_PHP']




fx_rs.rename(columns={'BBGTKR::BLOOMBERG::BRL CURNCY':'FX_BRL'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::CLP CURNCY':'FX_CLP'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::CNH CURNCY':'FX_CNH'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::COP CURNCY':'FX_COP'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::CZK CURNCY':'FX_CZK'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::IDR CURNCY':'FX_IDR'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::ILS CURNCY':'FX_ILS'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::INR CURNCY':'FX_INR'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::KRW CURNCY':'FX_KRW'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::MXN CURNCY':'FX_MXN'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::PEN CURNCY':'FX_PEN'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::PLN CURNCY':'FX_PLN'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::RUB CURNCY':'FX_RUB'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::HUF CURNCY':'FX_HUF'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::ZAR CURNCY':'FX_ZAR'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::THB CURNCY':'FX_THB'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::TWD CURNCY':'FX_TWD'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::MYR CURNCY':'FX_MYR'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::PHP CURNCY':'FX_PHP'}, inplace=True)
fx_rs.rename(columns={'BBGTKR::BLOOMBERG::TRY CURNCY':'FX_TRY'}, inplace=True)

print(fx_rs.columns)

#FX_BRL
fx_rs['wv_FX_BRL']= ((fx_rs.FX_BRL.diff()) /(fx_rs.FX_BRL.shift())).round(6)
fx_rs['wd_FX_BRL']= ((fx_rs.FX_BRL.diff())).round(6)
#FX_CLP
fx_rs['wv_FX_CLP']= ((fx_rs.FX_CLP.diff()) /(fx_rs.FX_CLP.shift())).round(6)
fx_rs['wd_FX_CLP']= ((fx_rs.FX_CLP.diff())).round(6)
#FX_CNH
fx_rs['wv_FX_CNH']= ((fx_rs.FX_CNH.diff()) /(fx_rs.FX_CNH.shift())).round(6)
fx_rs['wd_FX_CNH']= ((fx_rs.FX_CNH.diff())).round(6)
#FX_COP
fx_rs['wv_FX_COP']= ((fx_rs.FX_COP.diff()) /(fx_rs.FX_COP.shift())).round(6)
fx_rs['wd_FX_COP']= ((fx_rs.FX_COP.diff())).round(6)
#FX_CZK
fx_rs['wv_FX_CZK']= ((fx_rs.FX_CZK.diff()) /(fx_rs.FX_CZK.shift())).round(6)
fx_rs['wd_FX_CZK']= ((fx_rs.FX_CZK.diff())).round(6)
#FX_IDR
fx_rs['wv_FX_IDR']= ((fx_rs.FX_IDR.diff()) /(fx_rs.FX_IDR.shift())).round(6)
fx_rs['wd_FX_IDR']= ((fx_rs.FX_IDR.diff())).round(6)
#FX_ILS
fx_rs['wv_FX_ILS']= ((fx_rs.FX_ILS.diff()) /(fx_rs.FX_ILS.shift())).round(6)
fx_rs['wd_FX_ILS']= ((fx_rs.FX_ILS.diff())).round(6)
#FX_INR
fx_rs['wv_FX_INR']= ((fx_rs.FX_INR.diff()) /(fx_rs.FX_INR.shift())).round(6)
fx_rs['wd_FX_INR']= ((fx_rs.FX_INR.diff())).round(6)
#FX_KRW
fx_rs['wv_FX_KRW']= ((fx_rs.FX_KRW.diff()) /(fx_rs.FX_KRW.shift())).round(6)
fx_rs['wd_FX_KRW']= ((fx_rs.FX_KRW.diff())).round(6)
#FX_MXN
fx_rs['wv_FX_MXN']= ((fx_rs.FX_MXN.diff()) /(fx_rs.FX_MXN.shift())).round(6)
fx_rs['wd_FX_MXN']= ((fx_rs.FX_MXN.diff())).round(6)
#FX_PEN
fx_rs['wv_FX_PEN']= ((fx_rs.FX_PEN.diff()) /(fx_rs.FX_PEN.shift())).round(6)
fx_rs['wd_FX_PEN']= ((fx_rs.FX_PEN.diff())).round(6)
#FX_PLN
fx_rs['wv_FX_PLN']= ((fx_rs.FX_PLN.diff()) /(fx_rs.FX_PLN.shift())).round(6)
fx_rs['wd_FX_PLN']= ((fx_rs.FX_PLN.diff())).round(6)
#FX_RUB
fx_rs['wv_FX_RUB']= ((fx_rs.FX_RUB.diff()) /(fx_rs.FX_RUB.shift())).round(6)
fx_rs['wd_FX_RUB']= ((fx_rs.FX_RUB.diff())).round(6)
#FX_TRY
fx_rs['wv_FX_TRY']= ((fx_rs.FX_TRY.diff()) /(fx_rs.FX_TRY.shift())).round(6)
fx_rs['wd_FX_TRY']= ((fx_rs.FX_TRY.diff())).round(6)
#FX_ZAR
fx_rs['wv_FX_ZAR']= ((fx_rs.FX_ZAR.diff()) /(fx_rs.FX_ZAR.shift())).round(6)
fx_rs['wd_FX_ZAR']= ((fx_rs.FX_ZAR.diff())).round(6)
#FX_THB
fx_rs['wv_FX_THB']= ((fx_rs.FX_THB.diff()) /(fx_rs.FX_THB.shift())).round(6)
fx_rs['wd_FX_THB']= ((fx_rs.FX_THB.diff())).round(6)
#FX_TWD
fx_rs['wv_FX_TWD']= ((fx_rs.FX_TWD.diff()) /(fx_rs.FX_TWD.shift())).round(6)
fx_rs['wd_FX_TWD']= ((fx_rs.FX_TWD.diff())).round(6)
#FX_MYR
fx_rs['wv_FX_MYR']= ((fx_rs.FX_MYR.diff()) /(fx_rs.FX_MYR.shift())).round(6)
fx_rs['wd_FX_MYR']= ((fx_rs.FX_MYR.diff())).round(6)
#FX_PHP
fx_rs['wv_FX_PHP']= ((fx_rs.FX_PHP.diff()) /(fx_rs.FX_PHP.shift())).round(6)
fx_rs['wd_FX_PHP']= ((fx_rs.FX_PHP.diff())).round(6)
#FX_HUF
fx_rs['wv_FX_HUF']= ((fx_rs.FX_HUF.diff()) /(fx_rs.FX_HUF.shift())).round(6)
fx_rs['wd_FX_HUF']= ((fx_rs.FX_HUF.diff())).round(6)

print(fx_rs)
# Out:
# Index(['date', 'FX_BRL', 'FX_CLP', 'FX_CNH', 'FX_COP', 'FX_CZK', 'FX_HUF',
#        'FX_IDR', 'FX_ILS', 'FX_INR', 'FX_KRW', 'FX_MXN', 'FX_MYR', 'FX_PEN',
#        'FX_PHP', 'FX_PLN', 'FX_RUB', 'FX_THB', 'FX_TRY', 'FX_TWD', 'FX_ZAR'],
#       dtype='object')
#            date  FX_BRL  FX_CLP  FX_CNH   FX_COP   FX_CZK  FX_HUF   FX_IDR  \
# 0    2010-01-01  1.7200  505.80  6.7250  2011.65  18.3865  188.39   9403.0
# 1    2010-01-08  1.7264  493.45  6.7250  1966.75  18.2430  185.84   9220.0
# 2    2010-01-15  1.7723  489.00  6.7250  1969.63  18.0480  186.64   9203.0
# 3    2010-01-22  1.8247  505.85  6.7250  1968.90  18.4495  191.93   9350.0
# 4    2010-01-29  1.8950  524.75  6.7250  1981.90  18.9258  195.71   9353.0
# ..          ...     ...     ...     ...      ...      ...     ...      ...
# 598  2021-06-18  5.0903  748.42  6.4616  3745.40  21.5567  299.88  14375.0
# 599  2021-06-25  4.9343  733.90  6.4612  3731.85  21.3515  294.29  14425.0
# ...

# %%
l_msci_rs = pd.read_csv (r'K:\2020_2431\q\sandbox\l_msci_tmp.csv')
l_msci_rs=l_msci_rs.fillna(method='bfill')
print(l_msci_rs.columns)
#l_msci_rs.columns=['date',
#                   'MSCI_BRL','MSCI_CLP','MSCI_CNH','MSCI_COP','MSCI_CZK','MSCI_HUF','MSCI_ILS',
#                   'MSCI_INR','MSCI_KRW','MSCI_MXN', 'MSCI_PEN','MSCI_PLN','MSCI_RUB','MSCI_TRY',
#                   'MSCI_ZAR','MSCI_THB','MSCI_TWD','MSCI_MYR','MSCI_PHP','MSCI_IDR']


l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXBR Index':'MSCI_BRL'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXCL Index':'MSCI_CLP'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXCN Index':'MSCI_CNH'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXCO Index':'MSCI_COP'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXCZ Index':'MSCI_CZK'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXIL Index':'MSCI_ILS'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXIN Index':'MSCI_INR'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXKR Index':'MSCI_KRW'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXMX Index':'MSCI_MXN'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXZA Index':'MSCI_ZAR'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXPE Index':'MSCI_PEN'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXRU Index':'MSCI_RUB'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXTR Index':'MSCI_TRY'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXPL Index':'MSCI_PLN'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXHU Index':'MSCI_HUF'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXID Index':'MSCI_IDR'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXTH Index':'MSCI_THB'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::TAMSCI Index':'MSCI_TWD'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXMY Index':'MSCI_MYR'}, inplace=True)
l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::PHP CURNCY':'MSCI_PHP'}, inplace=True)


print(l_msci_rs.columns)

#          'BBGTKR::BLOOMBERG::MXCN Index','BBGTKR::BLOOMBERG::MXCO Index',
#          'BBGTKR::BLOOMBERG::MXCZ Index','BBGTKR::BLOOMBERG::MXHU Index',
#          'BBGTKR::BLOOMBERG::MXIL Index','BBGTKR::BLOOMBERG::MXIN index',
#          'BBGTKR::BLOOMBERG::MXKR index','BBGTKR::BLOOMBERG::MXMX Index',
#          'BBGTKR::BLOOMBERG::MXPE index','BBGTKR::BLOOMBERG::MXPL index',
#          'BBGTKR::BLOOMBERG::MXRU INDEX','BBGTKR::BLOOMBERG::MXTR Index',
#          'BBGTKR::BLOOMBERG::MXZA Index','BBGTKR::BLOOMBERG::MXTH Index',
#          'BBGTKR::BLOOMBERG::TAMSCI Index','BBGTKR::BLOOMBERG::MXMY index',
#          'BBGTKR::BLOOMBERG::PHP CURNCY','BBGTKR::BLOOMBERG::MXID Index']
            
            


#MSCI_BRL
l_msci_rs['wv_MSCI_BRL']= ((l_msci_rs.MSCI_BRL.diff()) /(l_msci_rs.MSCI_BRL.shift())).round(6)
l_msci_rs['wd_MSCI_BRL']= ((l_msci_rs.MSCI_BRL.diff())).round(6)
#MSCI_CLP
l_msci_rs['wv_MSCI_CLP']= ((l_msci_rs.MSCI_CLP.diff()) /(l_msci_rs.MSCI_CLP.shift())).round(6)
l_msci_rs['wd_MSCI_CLP']= ((l_msci_rs.MSCI_CLP.diff())).round(6)
#MSCI_CNH
l_msci_rs['wv_MSCI_CNH']= ((l_msci_rs.MSCI_CNH.diff()) /(l_msci_rs.MSCI_CNH.shift())).round(6)
l_msci_rs['wd_MSCI_CNH']= ((l_msci_rs.MSCI_CNH.diff())).round(6)
#MSCI_COP
l_msci_rs['wv_MSCI_COP']= ((l_msci_rs.MSCI_COP.diff()) /(l_msci_rs.MSCI_COP.shift())).round(6)
l_msci_rs['wd_MSCI_COP']= ((l_msci_rs.MSCI_COP.diff())).round(6)
#MSCI_CZK
l_msci_rs['wv_MSCI_CZK']= ((l_msci_rs.MSCI_CZK.diff()) /(l_msci_rs.MSCI_CZK.shift())).round(6)
l_msci_rs['wd_MSCI_CZK']= ((l_msci_rs.MSCI_CZK.diff())).round(6)
#MSCI_ILS
l_msci_rs['wv_MSCI_ILS']= ((l_msci_rs.MSCI_ILS.diff()) /(l_msci_rs.MSCI_ILS.shift())).round(6)
l_msci_rs['wd_MSCI_ILS']= ((l_msci_rs.MSCI_ILS.diff())).round(6)
#MSCI_INR
l_msci_rs['wv_MSCI_INR']= ((l_msci_rs.MSCI_INR.diff()) /(l_msci_rs.MSCI_INR.shift())).round(6)
l_msci_rs['wd_MSCI_INR']= ((l_msci_rs.MSCI_INR.diff())).round(6)
#MSCI_KRW
l_msci_rs['wv_MSCI_KRW']= ((l_msci_rs.MSCI_KRW.diff()) /(l_msci_rs.MSCI_KRW.shift())).round(6)
l_msci_rs['wd_MSCI_KRW']= ((l_msci_rs.MSCI_KRW.diff())).round(6)
#MSCI_MXN
l_msci_rs['wv_MSCI_MXN']= ((l_msci_rs.MSCI_MXN.diff()) /(l_msci_rs.MSCI_MXN.shift())).round(6)
l_msci_rs['wd_MSCI_MXN']= ((l_msci_rs.MSCI_MXN.diff())).round(6)
#MSCI_ZAR
l_msci_rs['wv_MSCI_ZAR']= ((l_msci_rs.MSCI_ZAR.diff()) /(l_msci_rs.MSCI_ZAR.shift())).round(6)
l_msci_rs['wd_MSCI_ZAR']= ((l_msci_rs.MSCI_ZAR.diff())).round(6)
#MSCI_PEN
l_msci_rs['wv_MSCI_PEN']= ((l_msci_rs.MSCI_PEN.diff()) /(l_msci_rs.MSCI_PEN.shift())).round(6)
l_msci_rs['wd_MSCI_PEN']= ((l_msci_rs.MSCI_PEN.diff())).round(6)
#MSCI_RUB
l_msci_rs['wv_MSCI_RUB']= ((l_msci_rs.MSCI_RUB.diff()) /(l_msci_rs.MSCI_RUB.shift())).round(6)
l_msci_rs['wd_MSCI_RUB']= ((l_msci_rs.MSCI_RUB.diff())).round(6)
#MSCI_TRY
l_msci_rs['wv_MSCI_TRY']= ((l_msci_rs.MSCI_TRY.diff()) /(l_msci_rs.MSCI_TRY.shift())).round(6)
l_msci_rs['wd_MSCI_TRY']= ((l_msci_rs.MSCI_TRY.diff())).round(6)
#MSCI_TRY
l_msci_rs['wv_MSCI_PLN']= ((l_msci_rs.MSCI_PLN.diff()) /(l_msci_rs.MSCI_PLN.shift())).round(6)
l_msci_rs['wd_MSCI_PLN']= ((l_msci_rs.MSCI_PLN.diff())).round(6)
#MSCI_PHP
l_msci_rs['wv_MSCI_PHP']= ((l_msci_rs.MSCI_PHP.diff()) /(l_msci_rs.MSCI_PHP.shift())).round(6)
l_msci_rs['wd_MSCI_PHP']= ((l_msci_rs.MSCI_PHP.diff())).round(6)
#MSCI_HUF
l_msci_rs['wv_MSCI_HUF']= ((l_msci_rs.MSCI_HUF.diff()) /(l_msci_rs.MSCI_HUF.shift())).round(6)
l_msci_rs['wd_MSCI_HUF']= ((l_msci_rs.MSCI_HUF.diff())).round(6)
#MSCI_IDR
l_msci_rs['wv_MSCI_IDR']= ((l_msci_rs.MSCI_IDR.diff()) /(l_msci_rs.MSCI_IDR.shift())).round(6)
l_msci_rs['wd_MSCI_IDR']= ((l_msci_rs.MSCI_IDR.diff())).round(6)
#MSCI_THB
l_msci_rs['wv_MSCI_THB']= ((l_msci_rs.MSCI_THB.diff()) /(l_msci_rs.MSCI_THB.shift())).round(6)
l_msci_rs['wd_MSCI_THB']= ((l_msci_rs.MSCI_THB.diff())).round(6)
#MSCI_TWD
l_msci_rs['wv_MSCI_TWD']= ((l_msci_rs.MSCI_TWD.diff()) /(l_msci_rs.MSCI_TWD.shift())).round(6)
l_msci_rs['wd_MSCI_TWD']= ((l_msci_rs.MSCI_TWD.diff())).round(6)

#MSCI_myr
l_msci_rs['wv_MSCI_MYR']= ((l_msci_rs.MSCI_MYR.diff()) /(l_msci_rs.MSCI_MYR.shift())).round(6)
l_msci_rs['wd_MSCI_MYR']= ((l_msci_rs.MSCI_MYR.diff())).round(6)

print(l_msci_rs)
# Out:
# Index(['date', 'BBGTKR::BLOOMBERG::MXBR Index',
#        'BBGTKR::BLOOMBERG::MXCL Index', 'BBGTKR::BLOOMBERG::MXCN Index',
#        'BBGTKR::BLOOMBERG::MXCO Index', 'BBGTKR::BLOOMBERG::MXCZ Index',
#        'BBGTKR::BLOOMBERG::MXHU Index', 'BBGTKR::BLOOMBERG::MXID Index',
#        'BBGTKR::BLOOMBERG::MXIL Index', 'BBGTKR::BLOOMBERG::MXIN Index',
#        'BBGTKR::BLOOMBERG::MXKR Index', 'BBGTKR::BLOOMBERG::MXMX Index',
#        'BBGTKR::BLOOMBERG::MXMY Index', 'BBGTKR::BLOOMBERG::MXPE Index',
#        'BBGTKR::BLOOMBERG::MXPL Index', 'BBGTKR::BLOOMBERG::MXRU Index',
#        'BBGTKR::BLOOMBERG::MXTH Index', 'BBGTKR::BLOOMBERG::MXTR Index',
#        'BBGTKR::BLOOMBERG::MXZA Index', 'BBGTKR::BLOOMBERG::PHP CURNCY',
#        'BBGTKR::BLOOMBERG::TAMSCI Index'],
#       dtype='object')
# Index(['date', 'MSCI_BRL', 'MSCI_CLP', 'MSCI_CNH', 'MSCI_COP', 'MSCI_CZK',
#        'MSCI_HUF', 'MSCI_IDR', 'MSCI_ILS', 'MSCI_INR', 'MSCI_KRW', 'MSCI_MXN',
# ...

# %%
vix_rs = pd.read_csv (r'K:\2020_2431\q\sandbox\vix_tmp.csv')
vix_rs.columns=['date','vix']
vix_rs['wv_vix']= ((vix_rs.vix.diff()) /(vix_rs.vix.shift())).round(6)
vix_rs['wd_vix']= ((vix_rs.vix.diff())).round(6)
print(vix_rs)
# Out:
#            date    vix    wv_vix  wd_vix
# 0    2010-01-01  18.13       NaN     NaN
# 1    2010-01-08  18.13  0.000000    0.00
# 2    2010-01-15  17.91 -0.012135   -0.22
# 3    2010-01-22  27.31  0.524846    9.40
# 4    2010-01-29  24.62 -0.098499   -2.69
# ..          ...    ...       ...     ...
# 598  2021-06-18  20.70  0.322684    5.05
# 599  2021-06-25  15.62 -0.245411   -5.08
# 600  2021-07-02  15.07 -0.035211   -0.55
# 601  2021-07-09  16.18  0.073656    1.11
# 602  2021-07-16  18.45  0.140297    2.27
#
# [603 rows x 4 columns]

# %%
msci_us_rs = pd.read_csv (r'K:\2020_2431\q\sandbox\msci_us_tmp.csv')
msci_us_rs.columns=['date','msci_us']
msci_us_rs['wv_msci_us']= ((msci_us_rs.msci_us.diff()) /(msci_us_rs.msci_us.shift())).round(6)
msci_us_rs['wd_msci_us']= ((msci_us_rs.msci_us.diff())).round(6)
print(msci_us_rs)
# Out:
#            date  msci_us  wv_msci_us  wd_msci_us
# 0    2010-01-01  1090.03         NaN         NaN
# 1    2010-01-08  1090.03    0.000000        0.00
# 2    2010-01-15  1081.38   -0.007936       -8.65
# 3    2010-01-22  1040.64   -0.037674      -40.74
# 4    2010-01-29  1022.88   -0.017066      -17.76
# ..          ...      ...         ...         ...
# 598  2021-06-18  4053.83   -0.016839      -69.43
# 599  2021-06-25  4167.55    0.028052      113.72
# 600  2021-07-02  4234.03    0.015952       66.48
# 601  2021-07-09  4251.66    0.004164       17.63
# 602  2021-07-16  4206.00   -0.010739      -45.66
#
# [603 rows x 4 columns]

# %%
ust_rs = pd.read_csv (r'K:\2020_2431\q\sandbox\ust_tmp.csv')
ust_rs.columns=['date','ust']
ust_rs['wv_ust']= ((ust_rs.ust.diff()) /(ust_rs.ust.shift())).round(6)
ust_rs['wd_ust']= ((ust_rs.ust.diff())).round(6)
print(ust_rs)
# Out:
#            date     ust    wv_ust  wd_ust
# 0    2010-01-01  3.8350       NaN     NaN
# 1    2010-01-08  3.8297 -0.001382 -0.0053
# 2    2010-01-15  3.6744 -0.040551 -0.1553
# 3    2010-01-22  3.6071 -0.018316 -0.0673
# 4    2010-01-29  3.5844 -0.006293 -0.0227
# ..          ...     ...       ...     ...
# 598  2021-06-18  1.4381 -0.009437 -0.0137
# 599  2021-06-25  1.5241  0.059801  0.0860
# 600  2021-07-02  1.4238 -0.065809 -0.1003
# 601  2021-07-09  1.3595 -0.045161 -0.0643
# 602  2021-07-16  1.2903 -0.050901 -0.0692
#
# [603 rows x 4 columns]

# %%
#rating
rating = pd.read_csv (r'K:\2020_2431\q\rating\rating.csv' )
print(rating)
#chnge na ot rpevios variable
#'cahnge date time, 
#change name columns

#r=r.reset_index(drop=True)
#r.reset_index(level=0, inplace=True)
#r.columns = ['country','rating']
#r.columns = ['rating']
#r.rating = r.rating.round(2)
#r['country']=r['country'].str.lower()
# Out:
#             date    BRAZIL   COLOMBIA  MEXICO  CHILE       PERU    TURKEY  \
# 0     07/01/2000       NaN        NaN     NaN    NaN   9.666667  6.666667
# 1     14/01/2000       NaN        NaN     NaN    NaN        NaN       NaN
# 2     21/01/2000       NaN        NaN     NaN    NaN        NaN       NaN
# 3     28/01/2000       NaN        NaN     NaN    NaN   9.666667  6.666667
# 4     04/02/2000       NaN        NaN     NaN    NaN   9.666667  6.666667
# ...          ...       ...        ...     ...    ...        ...       ...
# 1120  25/06/2021  8.333333  11.000000    12.0   15.0  13.333333  7.000000
# 1121  02/07/2021  8.333333  10.666667    12.0   15.0  13.333333  7.000000
# 1122  09/07/2021  8.333333  10.666667    12.0   15.0  13.333333  7.000000
# 1123  16/07/2021  8.333333  10.666667    12.0   15.0  13.333333  7.000000
# 1124  23/07/2021  8.333333  10.666667    12.0   15.0  13.333333  7.000000
#
#          RUSSIA  SOUTH AFRICA     POLAND    HUNGARY     ISRAEL  \
# ...

# %%
#CONCATENATE ALL DATABASES

#cds_rs
#fx_rs
#l_msci_rs
#vix_rs
#msci_us_rs
#ust_rs

rs=pd.merge(cds_rs, fx_rs,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
print(rs.columns)
rs=pd.merge(rs, l_msci_rs,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
print(rs.columns)
rs=pd.merge(rs, vix_rs,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
print(rs.columns)
rs=pd.merge(rs, msci_us_rs,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
print(rs.columns)
rs=pd.merge(rs, ust_rs,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
print(rs.columns)
# Out:
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
#        ...
#        'wv_FX_THB', 'wd_FX_THB', 'wv_FX_TWD', 'wd_FX_TWD', 'wv_FX_MYR',
#        'wd_FX_MYR', 'wv_FX_PHP', 'wd_FX_PHP', 'wv_FX_HUF', 'wd_FX_HUF'],
#       dtype='object', length=169)
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
#        ...
#        'wv_MSCI_HUF', 'wd_MSCI_HUF', 'wv_MSCI_IDR', 'wd_MSCI_IDR',
#        'wv_MSCI_THB', 'wd_MSCI_THB', 'wv_MSCI_TWD', 'wd_MSCI_TWD',
#        'wv_MSCI_MYR', 'wd_MSCI_MYR'],
#       dtype='object', length=229)
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
# ...

# %%
#Residual Parameters
#Residual local MSCI
#residul local fx return
#residual regional CDS


df=rs
df['const'] = 1
df['X1']=df['wv_vix']
df['X2']=df['wv_ust']
df['X3']=df['wv_msci_us']
exog=df[['const','X1','X2','X3']]
#rolling window 12
w=12

# %%
#Run regressiosn of the residual 
#Residual local MSCI

#MSCI_BRL
name_text=str("wv_MSCI_BRL")
df['Y']=df["wv_MSCI_BRL"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#MSCI_CLP
name_text=str("wv_MSCI_CLP")
df['Y']=df["wv_MSCI_CLP"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#MSCI_CNH
name_text=str("wv_MSCI_CNH")
df['Y']=df["wv_MSCI_CNH"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#MSCI_COP
name_text=str("wv_MSCI_COP")
df['Y']=df["wv_MSCI_COP"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#MSCI_CZK
name_text=str("wv_MSCI_CZK")
df['Y']=df["wv_MSCI_CZK"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#MSCI_ILS
name_text=str("wv_MSCI_ILS")
df['Y']=df["wv_MSCI_ILS"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#wv_MSCI_INR
name_text=str("wv_MSCI_INR")
df['Y']=df["wv_MSCI_INR"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#MSCI_KRW
name_text=str("wv_MSCI_KRW")
df['Y']=df["wv_MSCI_KRW"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#MSCI_MXN
name_text=str("wv_MSCI_MXN")
df['Y']=df["wv_MSCI_MXN"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#MSCI_ZAR
name_text=str("wv_MSCI_ZAR")
df['Y']=df["wv_MSCI_ZAR"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#MSCI_PEN
name_text=str("wv_MSCI_PEN")
df['Y']=df["wv_MSCI_PEN"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#MSCI_RUB
name_text=str("wv_MSCI_RUB")
df['Y']=df["wv_MSCI_RUB"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#MSCI_TRY
name_text=str("wv_MSCI_TRY")
df['Y']=df["wv_MSCI_TRY"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#MSCI_PLN
name_text=str("wv_MSCI_PLN")
df['Y']=df["wv_MSCI_PLN"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#MSCI_HUF
name_text=str("wv_MSCI_HUF")
df['Y']=df["wv_MSCI_HUF"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#MSCI_IDR
name_text=str("wv_MSCI_IDR")
df['Y']=df["wv_MSCI_IDR"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#MSCI_THB
name_text=str("wv_MSCI_THB")
df['Y']=df["wv_MSCI_THB"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#MSCI_TWD
name_text=str("wv_MSCI_TWD")
df['Y']=df["wv_MSCI_TWD"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#MSCI_MYR
name_text=str("wv_MSCI_MYR")
df['Y']=df["wv_MSCI_MYR"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#MSCI_PHP
name_text=str("wv_MSCI_PHP")
df['Y']=df["wv_MSCI_PHP"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

del name_text
# Out:
# res_wv_MSCI_BRL
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
#        ...
#        'ust', 'wv_ust', 'wd_ust', 'const', 'X1', 'X2', 'X3', 'Y', 'pred',
#        'res_wv_MSCI_BRL'],
#       dtype='object', length=245)
# res_wv_MSCI_CLP
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
#        ...
#        'wv_ust', 'wd_ust', 'const', 'X1', 'X2', 'X3', 'Y', 'pred',
#        'res_wv_MSCI_BRL', 'res_wv_MSCI_CLP'],
#       dtype='object', length=246)
# res_wv_MSCI_CNH
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
#        ...
# ...

# %%
#run regresison to find residual of fx model
#residul local fx return



#FX_BRL
name_text=str("wv_FX_BRL")
df['Y']=df["wv_FX_BRL"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#FX_CLP
name_text=str("wv_FX_CLP")
df['Y']=df["wv_FX_CLP"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#FX_CNH
name_text=str("wv_FX_CNH")
df['Y']=df["wv_FX_CNH"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#FX_COP
name_text=str("wv_FX_COP")
df['Y']=df["wv_FX_COP"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#FX CZK
name_text=str("wv_FX_CZK")
df['Y']=df["wv_FX_CZK"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#FX_ILS
name_text=str("wv_FX_ILS")
df['Y']=df["wv_FX_ILS"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#wFX_INR
name_text=str("wv_FX_INR")
df['Y']=df["wv_FX_INR"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#FX_KRW
name_text=str("wv_FX_KRW")
df['Y']=df["wv_FX_KRW"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#FX_MXN
name_text=str("wv_FX_MXN")
df['Y']=df["wv_FX_MXN"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#FX_ZAR
name_text=str("wv_FX_ZAR")
df['Y']=df["wv_FX_ZAR"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#FXPEN
name_text=str("wv_FX_PEN")
df['Y']=df["wv_FX_PEN"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#FX_RUB
name_text=str("wv_FX_RUB")
df['Y']=df["wv_FX_RUB"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#FX_TRY
name_text=str("wv_FX_TRY")
df['Y']=df["wv_FX_TRY"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#FXPLN
name_text=str("wv_FX_PLN")
df['Y']=df["wv_FX_PLN"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#FX_HUF
name_text=str("wv_FX_HUF")
df['Y']=df["wv_FX_HUF"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#FX_IDR
name_text=str("wv_FX_IDR")
df['Y']=df["wv_FX_IDR"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#FX_THB
name_text=str("wv_FX_THB")
df['Y']=df["wv_FX_THB"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#FX_TWD
name_text=str("wv_FX_TWD")
df['Y']=df["wv_FX_TWD"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#FX_MYR
name_text=str("wv_FX_MYR")
df['Y']=df["wv_FX_MYR"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#FX_PHP
name_text=str("wv_FX_PHP")
df['Y']=df["wv_FX_PHP"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


del name_text
# Out:
# res_wv_FX_BRL
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
#        ...
#        'res_wv_MSCI_RUB', 'res_wv_MSCI_TRY', 'res_wv_MSCI_PLN',
#        'res_wv_MSCI_HUF', 'res_wv_MSCI_IDR', 'res_wv_MSCI_THB',
#        'res_wv_MSCI_TWD', 'res_wv_MSCI_MYR', 'res_wv_MSCI_PHP',
#        'res_wv_FX_BRL'],
#       dtype='object', length=265)
# res_wv_FX_CLP
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
#        ...
#        'res_wv_MSCI_TRY', 'res_wv_MSCI_PLN', 'res_wv_MSCI_HUF',
#        'res_wv_MSCI_IDR', 'res_wv_MSCI_THB', 'res_wv_MSCI_TWD',
#        'res_wv_MSCI_MYR', 'res_wv_MSCI_PHP', 'res_wv_FX_BRL', 'res_wv_FX_CLP'],
#       dtype='object', length=266)
# res_wv_FX_CNH
# ...

# %%
#residual regional CDS
  

#wv_BRL_reg_cds5y
name_text=str("wv_BRL_reg_cds5y")
df['Y']=df["wv_BRL_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#wv_CLP_reg_cds5y
name_text=str("wv_CLP_reg_cds5y")
df['Y']=df["wv_CLP_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#wv_CNH_reg_cds5y
name_text=str("wv_CNH_reg_cds5y")
df['Y']=df["wv_CNH_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#wv_COP_reg_cds5y
name_text=str("wv_COP_reg_cds5y")
df['Y']=df["wv_COP_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

#wv_CZK_reg_cds5y
name_text=str("wv_CZK_reg_cds5y")
df['Y']=df["wv_CZK_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#wv_ILS_reg_cds5y
name_text=str("wv_ILS_reg_cds5y")
df['Y']=df["wv_ILS_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#wFX_INR


#wv_KRW_reg_cds5y
name_text=str("wv_KRW_reg_cds5y")
df['Y']=df["wv_KRW_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#wv_MXN_reg_cds5y
name_text=str("wv_MXN_reg_cds5y")
df['Y']=df["wv_MXN_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


        
        
#wv_ZAR_reg_cds5y
name_text=str("wv_ZAR_reg_cds5y")
df['Y']=df["wv_ZAR_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#wv_PEN_reg_cds5y
name_text=str("wv_PEN_reg_cds5y")
df['Y']=df["wv_PEN_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)







#wv_RUB_reg_cds5y
name_text=str("wv_RUB_reg_cds5y")
df['Y']=df["wv_RUB_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#wv_TRY_reg_cds5y
name_text=str("wv_TRY_reg_cds5y")
df['Y']=df["wv_TRY_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


        

#PLN_reg_cds5y
name_text=str("wv_PLN_reg_cds5y")
df['Y']=df["wv_PLN_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#wv_HUF_reg_cds5y
name_text=str("wv_HUF_reg_cds5y")
df['Y']=df["wv_HUF_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



        
        
#wv_IDR_reg_cds5y
name_text=str("wv_IDR_reg_cds5y")
df['Y']=df["wv_IDR_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#wv_THB_reg_cds5y
name_text=str("wv_THB_reg_cds5y")
df['Y']=df["wv_THB_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)



#FX_TWD


#wv_MYR_reg_cds5y
name_text=str("wv_MYR_reg_cds5y")
df['Y']=df["wv_MYR_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)


#wv_PHP_reg_cds5y
name_text=str("wv_PHP_reg_cds5y")
df['Y']=df["wv_PHP_reg_cds5y"]
name_text="res_"+name_text
print(name_text)
endog=df['Y']
model = RollingOLS(endog =endog, exog=exog,window=w)
rres = model.fit()
params = rres.params
df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
df['res']=(df['Y']-df['pred'])
df.rename(columns={'res':str(name_text)}, inplace=True)
print(df.columns)

del name_text
# Out:
# res_wv_BRL_reg_cds5y
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
#        ...
#        'res_wv_FX_RUB', 'res_wv_FX_TRY', 'res_wv_FX_PLN', 'res_wv_FX_HUF',
#        'res_wv_FX_IDR', 'res_wv_FX_THB', 'res_wv_FX_TWD', 'res_wv_FX_MYR',
#        'res_wv_FX_PHP', 'res_wv_BRL_reg_cds5y'],
#       dtype='object', length=285)
# res_wv_CLP_reg_cds5y
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
#        ...
#        'res_wv_FX_TRY', 'res_wv_FX_PLN', 'res_wv_FX_HUF', 'res_wv_FX_IDR',
#        'res_wv_FX_THB', 'res_wv_FX_TWD', 'res_wv_FX_MYR', 'res_wv_FX_PHP',
#        'res_wv_BRL_reg_cds5y', 'res_wv_CLP_reg_cds5y'],
#       dtype='object', length=286)
# res_wv_CNH_reg_cds5y
# ...

# %%
# now we can do regime swtich analysys
df_rs=df
df_rs.to_csv (r'K:\2020_2431\q\sandbox\cds_rs_1.csv', index = False, header=True)

# %%
#file location
location_first= ("K:\\2020_2431\\q\\cds_report\\images\\rs\\")
today = str(date.today())+"_"
location_last = '_fig.jpg'

#title_graph="EM CDS - Rating Fit Model "
#x_label="Average Rating [S&P, Ftch, and Mdys]"
#y_label="CDS Value"

dateTimeObj = str(datetime.now())
print(dateTimeObj)


today = str(date.today())
print(today)
#time stamp
end = str(today)

title0="EMCDS// Pre Regime Switch Model: Sov CDS explained by "
# Out:
# 2021-08-05 10:17:30.038821
# 2021-08-05

# %%
#Sovereign CDS weekly change explained by
#Res Local MSCI return 
#Res FX Exchange rate change
#Change in Rating
#Residual change in Regional SCDS
#Return SPX
#Change VIX
#Difference Treasury Yield

#rolling regression with a constantn
#make abosluties of all variables,
#then sum
#then estimate the percentage of each variable effect. 

df=df_rs
df['const'] = 1
df['X1']=df['wv_vix']
df['X2']=df['wd_ust']
df['X3']=df['wv_msci_us']

name_text_const='idiosyncratic'
name_text_X1="vix"
name_text_X2="ust"
name_text_X3="msci_us"
name_text_X4="regional_cds"
name_text_X5="local_fx"
name_text_X6="local_msci"

#rolling window 
w=30
r=30
#parameter
parameter_t=15

#https://datascienceanywhere.medium.com/visualizing-time-series-data-in-python-e49fa5d10ea
#https://www.geeksforgeeks.org/create-a-stacked-bar-plot-in-matplotlib/

z=df.head()
z.to_clipboard()

# %%
#wv_
####update!!!!
#del location

lst = ['BRL','COP','MXN','CLP','PEN','CZK','HUF','PLN','RUB','ILS','ZAR','TRY','IDR','THB','MYR','KRW','PHP']
lst2 = ['brazil','colombia','mexico','chile','peru','czech','hungary','poland','russia','israel','southafrica',
       'turkey','indonesia','thailand','malaysia','korea','philippines']

    
#list_im = ["fig_c_BRL4.jpg","fig_c_BRL5.jpg"]

for x in range(len(lst)):      
    country1=str(lst[x])  
    print(country1)
    country2=str(lst2[x]) 
    print(country2)   
    
    name_text=str(country2)
    df['Y']=df["wv_"+str(country2)+"_cds5y"]
    df['X4']=df["res_wv_"+str(country1)+"_reg_cds5y"]
    df['X5']=df["res_wv_FX_"+str(country1)]
    df['X6']=df["res_wv_MSCI_"+str(country1)]
    
    location_first= ("K:\\2020_2431\\q\\cds_report\\images\\rs\\")
    today = str(date.today())+"_"
    location_last = '_fig.jpg'




    name_text_res="res_reg"+name_text
    name_text_reg="pred_reg"+name_text
    print(name_text)
    endog=df['Y']
    exog=df[['const','X1','X2','X3','X4','X5','X6']]
    model = RollingOLS(endog =endog, exog=exog,window=w)
    rres = model.fit()
    params = rres.params
    df['pred']=params.const +(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)+(df.X4*params.X4)+(df.X5*params.X5)+(df.X6*params.X6)
    df['res']=(df['Y']-df['pred'])
    df.rename(columns={'res':str(name_text_res)}, inplace=True)
    df.rename(columns={'pred':str(name_text_reg)}, inplace=True)
    print(df.columns)

    df['abs_const']=abs(params.const) 
    df['abs_X1']=abs(df.X1*params.X1) 
    df['abs_X2']=abs(df.X2*params.X2) 
    df['abs_X3']=abs(df.X3*params.X3) 
    df['abs_X4']=abs(df.X4*params.X4) 
    df['abs_X5']=abs(df.X5*params.X5) 
    df['abs_X6']=abs(df.X6*params.X6) 

    df['sum_abs']=df[['abs_const','abs_X1','abs_X2','abs_X3','abs_X4','abs_X5','abs_X6']].sum(axis=1)
    df['p_abs_const']= (df['abs_const'] / df['sum_abs'])
    df['p_abs_X1']= (df['abs_X1'] / df['sum_abs'])
    df['p_abs_X2']= (df['abs_X2'] / df['sum_abs'])
    df['p_abs_X3']= (df['abs_X3'] / df['sum_abs'])
    df['p_abs_X4']= (df['abs_X4'] / df['sum_abs'])
    df['p_abs_X5']= (df['abs_X5'] / df['sum_abs'])
    df['p_abs_X6']= (df['abs_X6'] / df['sum_abs'])

    df['avg_p_abs_const']=df['p_abs_const'].rolling(r).mean()        
    df['avg_p_abs_X1']=df['p_abs_X1'].rolling(r).mean()
    df['avg_p_abs_X2']=df['p_abs_X2'].rolling(r).mean()
    df['avg_p_abs_X3']=df['p_abs_X3'].rolling(r).mean()
    df['avg_p_abs_X4']=df['p_abs_X4'].rolling(r).mean()
    df['avg_p_abs_X5']=df['p_abs_X5'].rolling(r).mean()
    df['avg_p_abs_X6']=df['p_abs_X6'].rolling(r).mean()

    #modify names
    name_text_g=name_text+" reg expl by "
    name_text_const_g= name_text+" "+name_text_const
    name_text_X1_g=name_text+" "+name_text_X1
    name_text_X2_g=name_text+" "+name_text_X2
    name_text_X3_g=name_text+" "+name_text_X3
    name_text_X4_g=name_text+" "+name_text_X4
    name_text_X5_g=name_text+" "+name_text_X5
    name_text_X6_g=name_text+" "+name_text_X6

    #create nerw columsna nd then rename
    df['avg_p_abs_const_g']=df['avg_p_abs_const']
    df['avg_p_abs_X1_g']=df['avg_p_abs_X1']
    df['avg_p_abs_X2_g']=df['avg_p_abs_X2']
    df['avg_p_abs_X3_g']=df['avg_p_abs_X3']
    df['avg_p_abs_X4_g']=df['avg_p_abs_X4']
    df['avg_p_abs_X5_g']=df['avg_p_abs_X5']
    df['avg_p_abs_X6_g']=df['avg_p_abs_X6']

    #rename for finalt table
    df.rename(columns={'avg_p_abs_const':str(name_text_const_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X1':str(name_text_X1_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X2':str(name_text_X2_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X3':str(name_text_X3_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X4':str(name_text_X4_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X5':str(name_text_X5_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X6':str(name_text_X6_g)}, inplace=True)

    #stached bar 
    title=title0+name_text_g+end
    y_label="Percentage"
    x_label=" time series "+" "+end
    location1=location_first+name_text_g+location_last
    print(location1)
    g=df[['date','avg_p_abs_const_g','avg_p_abs_X1_g','avg_p_abs_X2_g','avg_p_abs_X3_g','avg_p_abs_X4_g','avg_p_abs_X5_g','avg_p_abs_X6_g']]
    fig,ax = plt.subplots(figsize=(15,6))
    df1 = g.set_index('date')
    df1.plot(kind='area',ax=ax,stacked=True,color=['grey','orange','blue','green',"yellow","black","brown"])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=20)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(location1, bbox_inches='tight')
    del location1

    ##varaible1
    title=title0+name_text_X1_g+end
    y_label="Percentage"
    x_label=name_text_X1+" time series"+" "+end
    name0=name_text_X1_g
    locationx1=location_first+name0+location_last
    print(locationx1)

    g=df[['date','avg_p_abs_X1_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['orange'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=20)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx1, bbox_inches='tight')
    del locationx1
    del name0

    ##varaible2 (/4)
    title=title0+name_text_X2_g+end
    y_label="Percentage"
    x_label=name_text_X2+" time series"+" "+end
    name0=name_text_X2_g
    locationx2=location_first+name0+location_last
    print(locationx2)
    g=df[['date','avg_p_abs_X2_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['blue'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=20)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx2, bbox_inches='tight')
    del locationx2
    del name0

    ##varaible3 (/4)
    title=title0+name_text_X3_g+end
    y_label="Percentage"
    x_label=name_text_X3+" time series"+" "+end
    name0=name_text_X3_g
    locationx3=location_first+name0+location_last
    print(locationx3)
    g=df[['date','avg_p_abs_X3_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['green'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=20)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx3, bbox_inches='tight')
    del locationx3
    del name0

    ##varaible4 (/4)
    title=title0+name_text_X4_g+end
    y_label="Percentage"
    x_label=name_text_X4+" time series"+" "+end
    name0=name_text_X4_g
    locationx4=location_first+name0+location_last
    print(locationx4)
    g=df[['date','avg_p_abs_X4_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['yellow'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=20)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx4, bbox_inches='tight')
    del locationx4
    del name0

    ##varaible5 (/4)
    title=title0+name_text_X5_g+end
    y_label="Percentage"
    x_label=name_text_X5+" time series"+" "+end
    name0=name_text_X5_g
    locationx5=location_first+name0+location_last
    print(locationx5)
    g=df[['date','avg_p_abs_X5_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['black'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=20)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx5, bbox_inches='tight')
    del locationx5
    del name0

    ##varaible6 (/4)
    title=title0+name_text_X6_g+end
    y_label="Percentage"
    x_label=name_text_X6+" time series"+" "+end
    name0=name_text_X6_g
    locationx6=location_first+name0+location_last
    print(locationx6)
    g=df[['date','avg_p_abs_X6_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['brown'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=20)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx6, bbox_inches='tight')
    del locationx6
    del name0   
    del country1
    del country2
    del name_text

print("Complete")
# Out:
# BRL
# brazil
# brazil
# Index(['date', 'philippines_cds5y', 'czech_cds5y', 'thailand_cds5y',
#        'turkey_cds5y', 'indonesia_cds5y', 'poland_cds5y', 'malaysia_cds5y',
#        'korea_cds5y', 'mexico_cds5y',
#        ...
#        'res_wv_PLN_reg_cds5y', 'res_wv_HUF_reg_cds5y', 'res_wv_IDR_reg_cds5y',
#        'res_wv_THB_reg_cds5y', 'res_wv_MYR_reg_cds5y', 'res_wv_PHP_reg_cds5y',
#        'X4', 'X5', 'X6', 'res_regbrazil'],
#       dtype='object', length=306)
# K:\2020_2431\q\cds_report\images\rs\brazil reg expl by _fig.jpg
# K:\2020_2431\q\cds_report\images\rs\brazil vix_fig.jpg
# K:\2020_2431\q\cds_report\images\rs\brazil ust_fig.jpg
# K:\2020_2431\q\cds_report\images\rs\brazil msci_us_fig.jpg
# K:\2020_2431\q\cds_report\images\rs\brazil regional_cds_fig.jpg
# K:\2020_2431\q\cds_report\images\rs\brazil local_fx_fig.jpg
# K:\2020_2431\q\cds_report\images\rs\brazil local_msci_fig.jpg
# COP
# colombia
# colombia
# ...

# %%
###https://stackoverflow.com/questions/30227466/combine-several-images-horizontally-with-python
#part 3 pdf ALL COUNTRUES
os.chdir('K:/2020_2431/q/cds_report/images/rs')
print(os.getcwd())


    
final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\rs\\report_f\\001")
final_location_last = '.pdf'


lst = ['brazil','colombia','mexico','chile','peru','czech','hungary','poland','russia','israel','southafrica',
       'turkey','indonesia','thailand','malaysia','korea','philippines']

    
#list_im = ["fig_c_BRL4.jpg","fig_c_BRL5.jpg"]

for x in range(len(lst)):      
    country=str(lst[x])  

    
    fig0=str(country)+" reg expl by _fig.jpg"
    fig1=str(country)+" ust_fig.jpg"
    fig2=str(country)+" vix_fig.jpg"
    fig3=str(country)+" msci_us_fig.jpg"
    fig4=str(country)+" regional_cds_fig.jpg"
    fig5=str(country)+" local_msci_fig.jpg"
    fig6=str(country)+" local_fx_fig.jpg"
    fig7=str(country)+"_1.jpg"
    fig8=str(country)+"_2.jpg"
    fig9=str(country)+"_3.jpg"
    fig10=str(country)+"_f.jpg"


    #cds
    #######
    list_im = [str(fig1),str(fig2),str(fig3)]
    imgs    = [ PIL.Image.open(i) for i in list_im ]
    # pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
    min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
    imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

    # save that beautiful picture
    imgs_comb = np.vstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( str(fig7) )    


    #######
    list_im = [str(fig4),str(fig5),str(fig6)]
    imgs    = [ PIL.Image.open(i) for i in list_im ]
    # pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
    min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
    imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

    # save that beautiful picture
    imgs_comb = np.vstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( str(fig8) )   

    ######

    list_im = [str(fig7),str(fig8)]
    imgs    = [ PIL.Image.open(i) for i in list_im ]
    # pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
    min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
    imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

    # save that beautiful picture
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( str(fig9) ) 
    
    #######
    list_im = [str(fig0),str(fig9)]
    imgs    = [ PIL.Image.open(i) for i in list_im ]
    # pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
    min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
    imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

    # save that beautiful picture
    imgs_comb = np.vstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( str(fig10) )  
    imgs_comb.save( str(final_location_first+country+final_location_last) ) 
    

    
    
    
    
    
    
    

print("Complete")  


#df.to_csv (r'K:\2020_2431\q\sandbox\cds_rs_2.csv', index = False, header=True)
    
#asbo of all variables, 
#summ all absoletes
#and then dividend
#take out the residual, rename it as idyosunceratic
#then make an average



#print(endog.head())
#print(endog.tail())
#print(exog.head())
#print(exog.tail())
#model = pd.stats.ols.MovingOLS(y=df.Y, x=df[['X1', 'X2', 'X3']],window_type='rolling', window=100, intercept=True)
#df['Y_hat'] = model.y_predict
#print(df.head())
#print(df.tail())
#print(df)
#df=rs[['wv_MSCI_BRL','wv_vix','wv_ust','wv_msci_us']]
#>>> from statsmodels.regression.rolling import RollingOLS
#>>> from statsmodels.datasets import longley
#>>> data = longley.load(as_pandas=False)
#>>> exog = add_constant(data.exog, prepend=False)
#>>> mod = RollingOLS(data.endog, exog)
#>>> rolling_res = mod.fit(reset=50)
# Out:
# K:\2020_2431\q\cds_report\images\rs
# <ipython-input-20-6eee9908e603>:41: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
# <ipython-input-20-6eee9908e603>:44: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   imgs_comb = np.vstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
# <ipython-input-20-6eee9908e603>:54: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
# ...

# %%
#del location
#del name_text
#print(location)
#print(location_first)
#print(name_text)
#print(location_last)

# %%
#pip install main

# %%
#https://www.statsmodels.org/devel/examples/notebooks/generated/markov_regression.html
#https://matplotlib.org/2.0.2/examples/pylab_examples/fill_between_demo.html
  
# Specifically, in the good state, the weekly SCDS spread changes are mainly determined by local,
#regional and fundamental factors; whereas global variables have a stronger influence in the
#bad regime#

#In particular, US market returns play a dominant role in influencing the SCDS spread
#change in the bad state suggesting loss aversion and flight–to–quality behavior of investors.


#Ammer and Cai [2] examine the
#relationship between SCDS spreads and bond yields for nine emerging market sovereigns and find that
#these two measures of credit risk deviate significantly in the short run with the former leading the later in
#price discovery. They attribute such deviation to the higher liquidity in trading of SCDS.


#The good state is defined as
#the market condition that is characterized by tightening SCDS spreads (negative changes) and low
#volatility, while the bad state is the market condition with widening SCDS spreads (positive changes)
#and high volatility



#Si icnorpaor intereceptieopsn 
# es una regreison de markiov escondidad
#X1'res_wv_BRL_reg_cds5y',------RES REGIONAL +  (POSITIVE)
#X2'res_wv_FX_BRL',------RES FX + POSTIVE (POSITIVE)
#X3'res_wv_MSCI_BRL',----RES LOCAL MSCI -NEGATIVE 
#X4'wv_vix',------VIX +(MIXED IN PAPER REGRESSION)
#X5'wd_ust',-------UST + (MOSTLY NEGATIVE)
#X6'wv_msci_us']]-----SPX - NEGATIVE

os.chdir('K:/2020_2431/q/cds_report/images/rs/report_f')

#name="Brazil"
limit0= 100
theta = 0.1
interval = 50.0


lst = ['BRL','COP','MXN','CLP','PEN','CZK','HUF','PLN','RUB','ILS','ZAR','TRY','IDR','THB','MYR','KRW','PHP']
lst2 = ['brazil','colombia','mexico','chile','peru','czech','hungary','poland','russia','israel','southafrica',
       'turkey','indonesia','thailand','malaysia','korea','philippines']

    
#list_im = ["fig_c_BRL4.jpg","fig_c_BRL5.jpg"]

for x in range(len(lst)):      
    country1=str(lst[x])  
    print(country1)
    country2=str(lst2[x]) 
    print(country2)   
    a=df_rs[['date',str("wv_"+country2+"_cds5y")]]
    b=df_rs[['date',str("res_wv_"+country1+"_reg_cds5y"),
                        str("res_wv_FX_"+country1),
                        str("res_wv_MSCI_"+country1),'wv_vix','wd_ust','wv_msci_us']]
    a=a.set_index('date')
    b=b.set_index('date')
    limit_a=len(a.index)
    limit_b=len(b.index)
    a = a.iloc[limit0:len(a.index),] 
    b = b.iloc[limit0:len(b.index),]
    b= sm.add_constant(b)
    x=a.index
    #regime switch 
    mod = sm.tsa.MarkovRegression(a, k_regimes=2, exog=b)
    res = mod.fit()
    summary=res.summary()

    ########start plotting
    fig, axes = plt.subplots(3, figsize=(10, 7))

    y=res.smoothed_marginal_probabilities[0]
    ax = axes[0]
    ax.plot(res.smoothed_marginal_probabilities[0],color="green")
    ax.set(title=str("Smoothed probability of a status quo regime - ")+country2)
    ax.axhline(theta*5, color='black', lw=1, alpha=0.8)
    ax.fill_between(x, 0, 1, where= y < (1 - theta), facecolor='gray', alpha=0.5,interpolate=True)
    loc = plticker.MultipleLocator(base=interval) # this locator puts ticks at regular intervals
    ax.xaxis.set_major_locator(loc)

    ax = axes[1]
    y1=res.smoothed_marginal_probabilities[1]
    ax.plot(res.smoothed_marginal_probabilities[1],color="red")
    ax.set(title=str("Smoothed probability of a risk off regime - ")+country2)
    ax.axhline(theta*5, color='black', lw=1, alpha=0.8)
    ax.fill_between(x, 0, 1, where=y1 > theta, facecolor='gray', alpha=0.5,interpolate=True)
    loc = plticker.MultipleLocator(base=interval) # this locator puts ticks at regular intervals
    ax.xaxis.set_major_locator(loc)

    ax = axes[2]
    y=a[[str("wv_"+country2+"_cds5y")]]
    ax.plot(y,color="black")
    ax.set(title=str("Weekly variation of the 5Y CDS - ")+country2)
    ax.axhline(theta*1, color='red', lw=1, alpha=0.1)
    ax.axhline(theta*2, color='red', lw=1, alpha=0.2)
    ax.axhline(theta*3, color='red', lw=1, alpha=0.3)
    ax.axhline(theta*4, color='red', lw=1, alpha=0.4)
    ax.axhline(theta*5, color='red', lw=1, alpha=0.5)
    ax.axhline(theta*6, color='red', lw=1, alpha=0.6)
    ax.axhline(0, color='black', lw=1, alpha=0.5)
    ax.fill_between(x, 0, 1, where=y1 > theta, facecolor='gray', alpha=0.2,interpolate=True)
    loc = plticker.MultipleLocator(base=interval) # this locator puts ticks at regular intervals
    ax.xaxis.set_major_locator(loc)

    fig.tight_layout()
    plt.savefig(str("001"+country2+"rs_plot.pdf"), bbox_inches='tight')

print("Complete")
# Out:
# BRL
# brazil
# C:\Anaconda_2020.11\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-FRI will be used.
#   warnings.warn('No frequency information was'
# COP
# colombia
# C:\Anaconda_2020.11\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-FRI will be used.
#   warnings.warn('No frequency information was'
# MXN
# mexico
# C:\Anaconda_2020.11\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-FRI will be used.
#   warnings.warn('No frequency information was'
# C:\Anaconda_2020.11\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# CLP
# chile
# ...

# %%
source_dir = 'K:/2020_2431/q/cds_report/images/rs/report_f/'
source_dir2 = 'K:/2020_2431/q/cds_report/images/rs/report_f2/'

merger = PdfFileMerger()
for item in os.listdir(source_dir):
    if item.endswith('pdf'):
        #print(item)
        merger.append(source_dir + item)

merger.write(source_dir2 + 'EMCDS_0005_Regimeswitch_Complete.pdf')       
merger.close()
print("Complete!!!!")
# Out:
# Complete!!!!

# %%
#source_dir2 = 'K:/2020_2431/q/cds_report/images/rs/report_f2/'
#os.chdir('K:/2020_2431/q/cds_report/images/rs/report_f')
#os.chdir('K:/2020_2431/q/cds_report/images/rs')
#final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\rs\\report_f\\001")
#cds_rs.to_csv (r'K:\2020_2431\q\sandbox\cds_rs_0.csv', index = False, header=True)

#location_first= ("K:\\2020_2431\\q\\cds_report\\images\\rs\\")


#res.summary()
#print(res_filardo)
# Note that tables is a list. The table at index 1 is the "core" table. Additionally, read_html puts dfs in a list, so we want index 0
#results_as_html = summary.tables[1].as_html()
#pd.read_html(results_as_html, header=0, index_col=0)[0]#
#results_as_html1 = summary.tables[0].as_html()
#pd.read_html(results_as_html1, header=0, index_col=0)[0]
#dfi.export(results_as_html1, 'df_styled.png')
#summary=summary.as_latex() 
#summary1=summary.as_latex_tabular
#summary.generate_pdf('basic_maketitle2', clean_tex=False)

# %%
#ax.fill_between(a.index, 0, 1,  color="gray", alpha=0.9)
#ax.fill_between(x, 0, 1, where=y.values, color="k", alpha=0.1)
#ax.fill_between(usrec.index, 0, 1, where=usrec["USREC"].values, color="k", alpha=0.1)
#ax.fill_between(x, 0, y, where=y<-0.1, color="k")
#ax.fill_between(x, 0, 1, where=y<-0.1, facecolor='red', alpha=0.5)
#ax.axhline(-theta, color='green', lw=1, alpha=0.8)

# %%
#mod_filardo = sm.tsa.MarkovAutoregression(a,k_regimes=2,order=1,switching_ar=False,exog_tvtp=b,)
##np.random.seed(12345)
#res_filardo = mod_filardo.fit(search_reps=20)
##res_filardo.summary()
#fig, ax = plt.subplots(figsize=(12, 3))
#ax.plot(res_filardo.smoothed_marginal_probabilities[0])
##ax.fill_between(usrec.index, 0, 1, where=usrec["USREC"].values, color="gray", alpha=0.2)
##ax.set_xlim(dta_filardo.index[6], dta_filardo.index[-1])
#ax.set(title="Smoothed probability of a xxx state")
#plt.savefig("asd1.jpg", bbox_inches='tight')
## Fit the 2-regime model
#mod_fedfunds3 = sm.tsa.MarkovRegression(dta_fedfunds.iloc[4:], k_regimes=2, exog=exog)
#res_fedfunds3 = mod_fedfunds3.fit()

# %%
# Do something
timeclock.stop()
#Elapsed time: 397.8075 seconds
#Elapsed time: 398.0356 seconds
# Out:
# Elapsed time: 398.0356 seconds
# 398.0355824
