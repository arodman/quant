# %%
    
import pandas
import pandas as pd

import pandas
import pandas as pd
print("Complete")
# Out:
# Complete

# %%
#Exppor ij,, brazil exports of soybeans as a % of all brazil commodity exporpts
#varaible brazl soybeans exports to woerld (base type 1)
#variable brazil totoal exports to world (base type 1)

#=====exports country, commodoyt
## exports country

####export t o china i j, brazil erxports of soybeas  to chines
#variable brazil soybean exports to china (base type 2)

### imports of Chine of commoditgy i
####iports of that commoditiy in th ewhole market

###varaibles: china imports of comody xxxx in year xxx, independednt of partner (base type 3)
### varaibles all imports of that comododity in year .  (base type 4)

# %%
##detail by commodity

#URL='http://comtrade.un.org/api/get?max=5000&type=C&freq=A&px=HS&ps=2020&r=76&p=156&rg=all&cc=ALL&fmt=csv'
#URL='http://comtrade.un.org/api/get?max=500000&type=C&freq=A&px=HS&ps=2020%2C2019%2C2018&r=76&p=156&rg=all&cc=TOTAL&fmt=csv'
##'only improts from brazil to china
#URL='http://comtrade.un.org/api/get?max=5000&type=C&freq=A&px=HS&ps=2020&r=76&p=156&rg=1&cc=ALL&fmt=csv'
#4784
## exports
#URL='http://comtrade.un.org/api/get?max=5000&type=C&freq=A&px=HS&ps=2020&r=76&p=156&rg=2&cc=ALL&fmt=csv'

#calsisifcacion h2 , exports and improts, year 2020 de brazil a china 
# in case of brazil commoodty code 26
#/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=76&p=156&rg=all&cc=AG2
#/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=76&p=156&rg=all&cc=AG2
#URL='http://comtrade.un.org/api/get?max=5000&type=C&freq=A&px=HS&ps=2020&r=76&p=156&rg=all&cc=AG2&fmt=csv'

# %%
#c_list=["32","36","76","170","360","392","458","643","682","710","842","68","124","152","484","457","604","608","634","792","704"]
list_country1=["32","36","76","170","360"]
list_country2=["392","458","643","682","710","842"]
list_country3=["68","124","152","484","457"]
list_country4=["604","608","634","792","704"]
list_comm=["9","10","12","17","25","27","44","47","71","72","73","74","75","76","79","81","83"]
list_comm1=["9","10","12","17","25","27","44","47"]
list_comm2=["71","72","73","74","75","76","79","81","83"]

y="2020"


c_list=list_country1+list_country2+list_country3+list_country4
print(c_list)
# Out:
# ['32', '36', '76', '170', '360', '392', '458', '643', '682', '710', '842', '68', '124', '152', '484', '457', '604', '608', '634', '792', '704']

# %%
#Exppor ij,, brazil exports of soybeans as a % of all brazil commodity exporpts
#varaible brazl soybeans exports to woerld (base type 0)
#base type 1
#goods
#annual
#year 2020
#all  countries ------ country one by one th eloop
# partner world
#export

#commodiite ode ------cmmdodoty opne by one



#total 
#list_country=["32","36","76","170","360","392","458","643","682","710"]
#list_country=["32","36","76","170","360","392","458","643","682","710"],"842"]
#list_comm=["9","10","12","17","27","71","72","73","74","83"]


list_columns=["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity","Trade Value (US$)"]
base0=pd.DataFrame(columns=list_columns)
print(base0)


base0=pd.DataFrame(columns=list_columns)
print(base0)

#URL0="http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r="
URL01="http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps="
URL03="&r="
URL0=str(URL01)+str(y)+str(URL03)
print(URL0)
URL2="&p=0&rg=2&cc="
URL4="&fmt=csv"



loop_list1=list_country1
loop_list2=list_comm1
for x in range(len(loop_list1)): 
    print(x)
    URL1=str(loop_list1[x])
    print(URL1)
    for y in range(len(loop_list2)): 
        print(y)
        URL3=str(loop_list2[y])
        print(URL3) 
        URL=str(URL0)+str(URL1)+str(URL2)+str(URL3)+str(URL4)
        print(URL)   
        df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
        df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
        df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
        print(df)
        #df.columns = df.columns.droplevel(0)
        #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
        print(df)
        #df.to_clipboard()
        base0=base0.append(df, ignore_index=True)
        print(base0)
        del df
        del URL

loop_list1=list_country1
loop_list2=list_comm2
for x in range(len(loop_list1)): 
    print(x)
    URL1=str(loop_list1[x])
    print(URL1)
    for y in range(len(loop_list2)): 
        print(y)
        URL3=str(loop_list2[y])
        print(URL3) 
        URL=str(URL0)+str(URL1)+str(URL2)+str(URL3)+str(URL4)
        print(URL)   
        df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
        df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
        df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
        print(df)
        #df.columns = df.columns.droplevel(0)
        #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
        print(df)
        #df.to_clipboard()
        base0=base0.append(df, ignore_index=True)
        print(base0)
        del df
        del URL
        

base0.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t0_'+str(y)+'p.csv', index = True, header=True)
print("Complete1")
# Out:
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=
# 0
# 32
# 0
# 9
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=32&p=0&rg=2&cc=9&fmt=csv
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# 1
# 10
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=32&p=0&rg=2&cc=10&fmt=csv
# ...

# %%
###base type 0 part 2
base_t0= pd.read_csv (r'K:\2020_2431\q\sandbox_china_comm\base_t0_'+str(y)+'p.csv')



loop_list1=list_country2
loop_list2=list_comm1
for x in range(len(loop_list1)): 
    print(x)
    URL1=str(loop_list1[x])
    print(URL1)
    for y in range(len(loop_list2)): 
        print(y)
        URL3=str(loop_list2[y])
        print(URL3) 
        URL=str(URL0)+str(URL1)+str(URL2)+str(URL3)+str(URL4)
        print(URL)   
        df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
        df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
        df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
        print(df)
        #df.columns = df.columns.droplevel(0)
        #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
        print(df)
        #df.to_clipboard()
        base0=base0.append(df, ignore_index=True)
        print(base0)
        del df
        del URL
        
loop_list1=list_country2
loop_list2=list_comm2
for x in range(len(loop_list1)): 
    print(x)
    URL1=str(loop_list1[x])
    print(URL1)
    for y in range(len(loop_list2)): 
        print(y)
        URL3=str(loop_list2[y])
        print(URL3) 
        URL=str(URL0)+str(URL1)+str(URL2)+str(URL3)+str(URL4)
        print(URL)   
        df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
        df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
        df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
        print(df)
        #df.columns = df.columns.droplevel(0)
        #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
        print(df)
        #df.to_clipboard()
        base0=base0.append(df, ignore_index=True)
        print(base0)
        del df
        del URL
                
base0.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t0_'+str(y)+'p.csv', index = True, header=True)        
print("Complete2")
# Out:
# 0
# 458
# 0
# 9
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=458&p=0&rg=2&cc=9&fmt=csv
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-52-4eb6efc8180d> in <module>
#      12         URL=str(URL0)+str(URL1)+str(URL2)+str(URL3)+str(URL4)
#      13         print(URL)
# ---> 14         df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
#      15         df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
#      16         df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
#
# ...

# %%
###base type 0 part 3
base_t0= pd.read_csv (r'K:\2020_2431\q\sandbox_china_comm\base_t0_'+str(y)+'p.csv')



loop_list1=list_country3
loop_list2=list_comm1
for x in range(len(loop_list1)): 
    print(x)
    URL1=str(loop_list1[x])
    print(URL1)
    for y in range(len(loop_list2)): 
        print(y)
        URL3=str(loop_list2[y])
        print(URL3) 
        URL=str(URL0)+str(URL1)+str(URL2)+str(URL3)+str(URL4)
        print(URL)   
        df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
        df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
        df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
        print(df)
        #df.columns = df.columns.droplevel(0)
        #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
        print(df)
        #df.to_clipboard()
        base0=base0.append(df, ignore_index=True)
        print(base0)
        del df
        del URL
        
loop_list1=list_country3
loop_list2=list_comm2
for x in range(len(loop_list1)): 
    print(x)
    URL1=str(loop_list1[x])
    print(URL1)
    for y in range(len(loop_list2)): 
        print(y)
        URL3=str(loop_list2[y])
        print(URL3) 
        URL=str(URL0)+str(URL1)+str(URL2)+str(URL3)+str(URL4)
        print(URL)   
        df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
        df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
        df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
        print(df)
        #df.columns = df.columns.droplevel(0)
        #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
        print(df)
        #df.to_clipboard()
        base0=base0.append(df, ignore_index=True)
        print(base0)
        del df
        del URL
        
        
base0.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t0_'+str(y)+'p.csv', index = True, header=True)       
print("Complete3")
# Out:
# 0
# 68
# 0
# 9
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=0&r=68&p=0&rg=2&cc=9&fmt=csv
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-32-94fa2193c2a0> in <module>
#      12         URL=str(URL0)+str(URL1)+str(URL2)+str(URL3)+str(URL4)
#      13         print(URL)
# ---> 14         df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
#      15         df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
#      16         df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
#
# ...

# %%
###base type 0 part 4
base_t0= pd.read_csv (r'K:\2020_2431\q\sandbox_china_comm\base_t0_'+str(y)+'p.csv')


loop_list1=list_country4
loop_list2=list_comm1
for x in range(len(loop_list1)): 
    print(x)
    URL1=str(loop_list1[x])
    print(URL1)
    for y in range(len(loop_list2)): 
        print(y)
        URL3=str(loop_list2[y])
        print(URL3) 
        URL=str(URL0)+str(URL1)+str(URL2)+str(URL3)+str(URL4)
        print(URL)   
        df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
        df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
        df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
        print(df)
        #df.columns = df.columns.droplevel(0)
        #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
        print(df)
        #df.to_clipboard()
        base0=base0.append(df, ignore_index=True)
        print(base0)
        del df
        del URL
        
        
        
loop_list1=list_country4
loop_list2=list_comm2
for x in range(len(loop_list1)): 
    print(x)
    URL1=str(loop_list1[x])
    print(URL1)
    for y in range(len(loop_list2)): 
        print(y)
        URL3=str(loop_list2[y])
        print(URL3) 
        URL=str(URL0)+str(URL1)+str(URL2)+str(URL3)+str(URL4)
        print(URL)   
        df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
        df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
        df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
        print(df)
        #df.columns = df.columns.droplevel(0)
        #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
        print(df)
        #df.to_clipboard()
        base0=base0.append(df, ignore_index=True)
        print(base0)
        del df
        del URL
                
print("Complete4")

print(len(base0))
base0.drop_duplicates(keep=False, inplace=True)
print(len(base0))

base0.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t0_'+str(y)+'.csv', index = True, header=True)
del base0

#/api/get/plus?max=502&type=C&freq=A&px=HS&ps=2020&r=76&p=0&rg=2&cc=12
# Out:
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=
# 0
# 32
# 0
# 9
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=32&p=0&rg=2&cc=9&fmt=csv
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# 1
# 10
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=32&p=0&rg=2&cc=10&fmt=csv
# ...

# %% [markdown]
# # base type 1

# %%
#variable brazil totoal exports to world (base type 1)

import pandas as pd

#base type 1
#goods
#annual
#year 2020
#all  countries ------ country one by one th eloop
# partner world
#export

#total 
#list_country=["32","36","76","170","360","392","458","643","682","710","842"]
list_columns=["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity","Trade Value (US$)"]
base0=pd.DataFrame(columns=list_columns)
print(base0)


#URL0="http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r="
URL01="http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps="
URL03="&r="
URL0=str(URL01)+str(y)+str(URL03)
print(URL0)
URL2="&p=0&rg=2&cc=TOTAL&fmt=csv"



loop_list=list_country1
for x in range(len(loop_list)): 
    print(x)
    URL1=str(loop_list[x])
    print(URL1)
    URL=str(URL0)+str(URL1)+str(URL2)
    print(URL)   
    df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
    df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
    df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
    print(df)
    #df.columns = df.columns.droplevel(0)
    #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
    print(df)
    #df.to_clipboard()
    base0=base0.append(df, ignore_index=True)
    print(base0)
    del df
    del URL
    

print("Complete1")
# Out:
# Empty DataFrame
# Columns: [Year, Trade Flow, Reporter Code, Reporter, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=
# 0
# 32
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=32&p=0&rg=2&cc=TOTAL&fmt=csv
#    Year Trade Flow Reporter Code   Reporter Commodity Code        Commodity  \
# 0  2020     Export            32  Argentina          TOTAL  All Commodities
#
#    Trade Value (US$)
# 0        54883822445
#    Year Trade Flow Reporter Code   Reporter Commodity Code        Commodity  \
# 0  2020     Export            32  Argentina          TOTAL  All Commodities
#
#    Trade Value (US$)
# 0        54883822445
#    Year Trade Flow Reporter Code   Reporter Commodity Code        Commodity  \
# 0  2020     Export            32  Argentina          TOTAL  All Commodities
#
#   Trade Value (US$)
# 0       54883822445
# 1
# 36
# ...

# %%
loop_list=list_country2
for x in range(len(loop_list)): 
    print(x)
    URL1=str(loop_list[x])
    print(URL1)
    URL=str(URL0)+str(URL1)+str(URL2)
    print(URL)   
    df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
    df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
    df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
    print(df)
    #df.columns = df.columns.droplevel(0)
    #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
    print(df)
    #df.to_clipboard()
    base0=base0.append(df, ignore_index=True)
    print(base0)
    del df
    del URL
    
    
print("Complete2")
# Out:
# 0
# 458
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=458&p=0&rg=2&cc=TOTAL&fmt=csv
#    Year Trade Flow Reporter Code  Reporter Commodity Code        Commodity  \
# 0  2020     Export           458  Malaysia          TOTAL  All Commodities
#
#    Trade Value (US$)
# 0       233930987123
#    Year Trade Flow Reporter Code  Reporter Commodity Code        Commodity  \
# 0  2020     Export           458  Malaysia          TOTAL  All Commodities
#
#    Trade Value (US$)
# 0       233930987123
#    Year Trade Flow Reporter Code   Reporter Commodity Code        Commodity  \
# 0  2020     Export            32  Argentina          TOTAL  All Commodities
# 1  2020     Export            36  Australia          TOTAL  All Commodities
# 2  2020     Export            76     Brazil          TOTAL  All Commodities
# 3  2020     Export           170   Colombia          TOTAL  All Commodities
# 4  2020     Export           360  Indonesia          TOTAL  All Commodities
# ...

# %%
loop_list=list_country3
for x in range(len(loop_list)): 
    print(x)
    URL1=str(loop_list[x])
    print(URL1)
    URL=str(URL0)+str(URL1)+str(URL2)
    print(URL)   
    df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
    df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
    df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
    print(df)
    #df.columns = df.columns.droplevel(0)
    #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
    print(df)
    #df.to_clipboard()
    base0=base0.append(df, ignore_index=True)
    print(base0)
    del df
    del URL
    
    
print("Complete3")
# Out:
# 0
# 68
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=68&p=0&rg=2&cc=TOTAL&fmt=csv
#    Year Trade Flow Reporter Code                          Reporter  \
# 0  2020     Export            68  Bolivia (Plurinational State of)
#
#   Commodity Code        Commodity  Trade Value (US$)
# 0          TOTAL  All Commodities         7032764187
#    Year Trade Flow Reporter Code                          Reporter  \
# 0  2020     Export            68  Bolivia (Plurinational State of)
#
#   Commodity Code        Commodity  Trade Value (US$)
# 0          TOTAL  All Commodities         7032764187
#     Year Trade Flow Reporter Code                          Reporter  \
# 0   2020     Export            32                         Argentina
# 1   2020     Export            36                         Australia
# 2   2020     Export            76                            Brazil
# 3   2020     Export           170                          Colombia
# ...

# %%
loop_list=list_country4
for x in range(len(loop_list)): 
    print(x)
    URL1=str(loop_list[x])
    print(URL1)
    URL=str(URL0)+str(URL1)+str(URL2)
    print(URL)   
    df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
    df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
    df=df.groupby(["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity"],as_index=False).sum()
    print(df)
    #df.columns = df.columns.droplevel(0)
    #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
    print(df)
    #df.to_clipboard()
    base0=base0.append(df, ignore_index=True)
    print(base0)
    del df
    del URL
    
    
print("Complete4")

print(len(base0))
base0.drop_duplicates(keep=False, inplace=True)
print(len(base0))

base0.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t1_'+str(y)+'.csv', index = True, header=True)

del base0
# Out:
# 0
# 604
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=604&p=0&rg=2&cc=TOTAL&fmt=csv
#    Year Trade Flow Reporter Code Reporter Commodity Code        Commodity  \
# 0  2020     Export           604     Peru          TOTAL  All Commodities
#
#    Trade Value (US$)
# 0        38757234044
#    Year Trade Flow Reporter Code Reporter Commodity Code        Commodity  \
# 0  2020     Export           604     Peru          TOTAL  All Commodities
#
#    Trade Value (US$)
# 0        38757234044
#     Year Trade Flow Reporter Code                          Reporter  \
# 0   2020     Export            32                         Argentina
# 1   2020     Export            36                         Australia
# 2   2020     Export            76                            Brazil
# 3   2020     Export           170                          Colombia
# 4   2020     Export           360                         Indonesia
# ...

# %% [markdown]
# # base type  2

# %%
#####base tyope  2



import pandas as pd

####export t o china i j, brazil erxports of soybeas  to chines
#variable brazil soybean exports to china (base type 2)
#variable country j comodity i export to China

#base type 2
#goods
#annual
#period 2020
#reporters all
#partners china
#trade flow exports
#ag2


URL='http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=all&p=156&rg=2&cc=AG2&fmt=csv'
df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
#df=pd.read_csv(URL)
print("Complete")
df=df[["Year","Period","Period Desc.","Trade Flow","Reporter Code","Reporter","Reporter ISO",
       "Partner Code","Partner","Partner ISO","Commodity Code","Commodity", 
       "Trade Value (US$)"]]

#32	Argentina	1
#36	Australia	1
#76	Brazil	1
#170	Colombia	1
#360	Indonesia	1
#392	Japan	1
#458	Malaysia	1
#643	Russian Federation	1
#682	Saudi Arabia	1
#710	South Africa	1
#842	USA	1

#c_list=["32","36","76","170","360","392","458","643","682","710","842"]
#fitler in list
print(c_list)
df=df[df['Reporter Code'].isin(c_list)]
df = df.reset_index(drop=True)
print(df)



df.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t2_'+str(y)+'.csv', index = True, header=True)
# Out:
# Complete
# ['32', '36', '76', '170', '360', '392', '458', '643', '682', '710', '842', '68', '124', '152', '484', '457', '604', '608', '634', '792', '704']
#       Year  Period  Period Desc. Trade Flow Reporter Code      Reporter  \
# 0     2020    2020          2020     Export            32     Argentina
# 1     2020    2020          2020     Export            32     Argentina
# 2     2020    2020          2020     Export            32     Argentina
# 3     2020    2020          2020     Export            32     Argentina
# 4     2020    2020          2020     Export            32     Argentina
# 5     2020    2020          2020     Export            32     Argentina
# 6     2020    2020          2020     Export            32     Argentina
# 7     2020    2020          2020     Export            32     Argentina
# 8     2020    2020          2020     Export            32     Argentina
# 9     2020    2020          2020     Export            32     Argentina
# ...

# %% [markdown]
# # (base type 3)

# %%
# (base type 3)

####only china

## imports of Chine of commoditgy i
####iports of that commoditiy in th ewhole market

###varaibles: china imports of comody xxxx in year xxx, independednt of partner (base type 3)
import pandas as pd


#goods
#annual
#year 2020
# china
#world
#import
#ag2

URL='http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=156&p=0&rg=1&cc=AG2&fmt=csv'
df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
#df=pd.read_csv(URL)
print("Complete")
df=df[["Year","Period","Period Desc.","Trade Flow","Reporter Code","Reporter","Reporter ISO",
       "Partner Code","Partner","Partner ISO","Commodity Code","Commodity", 
       "Trade Value (US$)"]]
print(df)
#df.to_clipboard()


df.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t3_'+str(y)+'.csv', index = True, header=True)
del df
# Out:
# Complete
#     Year  Period  Period Desc. Trade Flow Reporter Code Reporter Reporter ISO  \
# 0   2020    2020          2020     Import           156    China          CHN
# 1   2020    2020          2020     Import           156    China          CHN
# 2   2020    2020          2020     Import           156    China          CHN
# 3   2020    2020          2020     Import           156    China          CHN
# 4   2020    2020          2020     Import           156    China          CHN
# 5   2020    2020          2020     Import           156    China          CHN
# 6   2020    2020          2020     Import           156    China          CHN
# 7   2020    2020          2020     Import           156    China          CHN
# 8   2020    2020          2020     Import           156    China          CHN
# 9   2020    2020          2020     Import           156    China          CHN
# 10  2020    2020          2020     Import           156    China          CHN
# ...

# %% [markdown]
# # (base type 4)

# %%
### varaibles all imports of that comododity in year .  (base type 4)
#part 1
###lsit of commodiites
import pandas as pd
#goods
#annual
#year 2020
# all
#world
#import
#HS-------DO IT BY PORDUC
#74 COPPPER


#Commodity Code	Commodity	F
#9	Coffee, tea, mate and spices	1
#10	Cereals	1
#12	Oil seeds and oleaginous fruits; miscellaneous grains, seeds and fruit, industrial or medicinal plants; straw and fodder	1
#17	Sugars and sugar confectionery	1
#27	Mineral fuels, mineral oils and products of their distillation; bituminous substances; mineral waxes	1
#71	Natural, cultured pearls; precious, semi-precious stones; precious metals, metals clad with precious metal, and articles thereof; imitation jewellery; coin	1
#72	Iron and steel	1
#73	Iron or steel articles	1
#74	Copper and articles thereof	1
#83	Metal; miscellaneous products of base metal	1

#list_comm=["9","10","12","17","27","71","72","73","74","83"]


list_columns=["Year","Trade Flow","Commodity Code","Commodity","Trade Value (US$)"]
base0=pd.DataFrame(columns=list_columns)
print(base0)


###dynamic year
#URL='http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=1&cc=74&fmt=csv'
#URL='http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=1&cc=74&fmt=csv'
URL01="http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps="
URL03="&r="
URL0=str(URL01)+str(y)
print(URL0)
URL2="&r=all&p=0&rg=1&cc="
#74
URL4="&fmt=csv"

loop_list=list_comm1
for x in range(len(loop_list)): 
    print(x)
    URL3=str(loop_list[x])
    URL=str(URL0)+str(URL2)+str(URL3)+str(URL4)
    print(URL)   
    df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
    df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
    df=df.groupby(["Year","Trade Flow","Commodity Code","Commodity"],as_index=False).sum()
    print(df)
    #df.columns = df.columns.droplevel(0)
    #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
    print(df)
    #df.to_clipboard()
    base0=base0.append(df, ignore_index=True)
    print(base0)
    del df
    del URL
# Out:
# Empty DataFrame
# Columns: [Year, Trade Flow, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020
# 0
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=1&cc=9&fmt=csv
# Empty DataFrame
# Columns: [Year, Trade Flow, Commodity Code, Commodity, Reporter, Trade Value (US$)]
# Index: []
# Empty DataFrame
# Columns: [Year, Trade Flow, Commodity Code, Commodity, Reporter, Trade Value (US$)]
# Index: []
# Empty DataFrame
# Columns: [Commodity, Commodity Code, Reporter, Trade Flow, Trade Value (US$), Year]
# Index: []
# 1
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=1&cc=10&fmt=csv
#    Year Trade Flow Commodity Code Commodity  Trade Value (US$)
# 0  2020     Import             10   Cereals        99093663273
#    Year Trade Flow Commodity Code Commodity  Trade Value (US$)
# 0  2020     Import             10   Cereals        99093663273
# ...

# %%
### varaibles all imports of that comododity in year .  (base type 4)   
##part 2

loop_list=list_comm2
for x in range(len(loop_list)): 
    print(x)
    URL3=str(loop_list[x])
    URL=str(URL0)+str(URL2)+str(URL3)+str(URL4)
    print(URL)   
    df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
    df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
    df=df.groupby(["Year","Trade Flow","Commodity Code","Commodity"],as_index=False).sum()
    print(df)
    #df.columns = df.columns.droplevel(0)
    #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
    print(df)
    #df.to_clipboard()
    base0=base0.append(df, ignore_index=True)
    print(base0)
    del df
    del URL    
        
    
    
    
base0.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t4_'+str(y)+'.csv', index = True, header=True)
del base0



#print(df)
#df.to_clipboard()
print("COMPLETE")

#http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=1&cc=74&fmt=csv'
#http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=1&cc=9&fmt=csv
#http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020                   99&fmt=csv
# Out:
# 0
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=1&cc=71&fmt=csv
#    Year Trade Flow Commodity Code  \
# 0  2020     Import             71
#
#                                            Commodity  Trade Value (US$)
# 0  Natural, cultured pearls; precious, semi-preci...       656364588532
#    Year Trade Flow Commodity Code  \
# 0  2020     Import             71
#
#                                            Commodity  Trade Value (US$)
# 0  Natural, cultured pearls; precious, semi-preci...       656364588532
#                                            Commodity Commodity Code  Reporter  \
# 0                                            Cereals             10       NaN
# 1  Oil seeds and oleaginous fruits; miscellaneous...             12       NaN
# 2                     Sugars and sugar confectionery             17       NaN
# 3  Salt; sulphur; earths, stone; plastering mater...             25       NaN
# ...

# %% [markdown]
# # (base type 5)

# %%
### varaibles all exports of that comododity in year .  (base type 5)
#/api/get/plus?max=502                   &type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=2&cc=74



#list_comm=["9","10","12","17","27","71","72","73","74","83"]
#y="2020"


list_columns=["Year","Trade Flow","Commodity Code","Commodity","Trade Value (US$)"]
base0=pd.DataFrame(columns=list_columns)
print(base0)




URL01="http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps="
URL03="&r="
URL0=str(URL01)+str(y)
print(URL0)
URL2="&r=all&p=0&rg=2&cc="
#74
URL4="&fmt=csv"

loop_list=list_comm
for x in range(len(loop_list)): 
    print(x)
    URL3=str(loop_list[x])
    URL=str(URL0)+str(URL2)+str(URL3)+str(URL4)
    print(URL)   
    df=pd.read_csv(URL, dtype={'Commodity Code':str, 'Reporter Code':str})
    df=df[["Year","Trade Flow","Reporter Code","Reporter","Commodity Code","Commodity", "Trade Value (US$)"]]
    df=df.groupby(["Year","Trade Flow","Commodity Code","Commodity"],as_index=False).sum()
    print(df)
    #df.columns = df.columns.droplevel(0)
    #df=df[["Year","Trade Flow","Reporter","Commodity Code","Commodity","Trade Value (US$)"]]
    print(df)
    #df.to_clipboard()
    base0=base0.append(df, ignore_index=True)
    print(base0)
    del df
    del URL    
    
base0.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t5_'+str(y)+'.csv', index = True, header=True)
del base0



#print(df)
#df.to_clipboard()
print("COMPLETE")
# Out:
# Empty DataFrame
# Columns: [Year, Trade Flow, Commodity Code, Commodity, Trade Value (US$)]
# Index: []
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020
# 0
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=2&cc=9&fmt=csv
# Empty DataFrame
# Columns: [Year, Trade Flow, Commodity Code, Commodity, Reporter, Trade Value (US$)]
# Index: []
# Empty DataFrame
# Columns: [Year, Trade Flow, Commodity Code, Commodity, Reporter, Trade Value (US$)]
# Index: []
# Empty DataFrame
# Columns: [Commodity, Commodity Code, Reporter, Trade Flow, Trade Value (US$), Year]
# Index: []
# 1
# http://comtrade.un.org/api/get?max=9000&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=2&cc=10&fmt=csv
#    Year Trade Flow Commodity Code Commodity  Trade Value (US$)
# 0  2020     Export             10   Cereals       117094590112
#    Year Trade Flow Commodity Code Commodity  Trade Value (US$)
# 0  2020     Export             10   Cereals       117094590112
# ...

# %%
#base0.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t5.csv', index = True, header=True)

#base0.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t4.csv', index = True, header=True)

# %%
#read csv dynamic year

base_t0= pd.read_csv (r'K:\2020_2431\q\sandbox_china_comm\base_t0_'+str(y)+'.csv')
base_t1= pd.read_csv (r'K:\2020_2431\q\sandbox_china_comm\base_t1_'+str(y)+'.csv')
base_t2= pd.read_csv (r'K:\2020_2431\q\sandbox_china_comm\base_t2_'+str(y)+'.csv')
base_t3= pd.read_csv (r'K:\2020_2431\q\sandbox_china_comm\base_t3_'+str(y)+'.csv')
base_t4= pd.read_csv (r'K:\2020_2431\q\sandbox_china_comm\base_t4_'+str(y)+'.csv')
base_t5= pd.read_csv (r'K:\2020_2431\q\sandbox_china_comm\base_t5_'+str(y)+'.csv')

#print(base_t0)
print(base_t0.columns)

#print(base_t1)
print(base_t1.columns)

#print(base_t2)
print(base_t2.columns)

#print(base_t3)
print(base_t3.columns)


#print(base_t4)
print(base_t4.columns)


base_t0.rename(columns={'Trade Value (US$)':'reporter_comm_i_exp_world'}, inplace=True)
base_t1.rename(columns={'Trade Value (US$)':'reporter_exp_world'}, inplace=True)
base_t2.rename(columns={'Trade Value (US$)':'reporter_comm_i_exp_china'}, inplace=True)
base_t3.rename(columns={'Trade Value (US$)':'china_imp_comm_i'}, inplace=True)
base_t4.rename(columns={'Trade Value (US$)':'world_imp_comm_i'}, inplace=True)
base_t5.rename(columns={'Trade Value (US$)':'world_exp_comm_i'}, inplace=True)

base_t0=base_t0[["Year", "Trade Flow", "Reporter Code", "Reporter","Commodity Code", "Commodity","reporter_comm_i_exp_world"]]
data=base_t0

base_t1=base_t1[["Year","Reporter","reporter_exp_world"]]
data=pd.merge(data, base_t1,  how='left', left_on=["Year","Reporter"], right_on = ["Year","Reporter"])

base_t2=base_t2[["Year","Reporter","Commodity Code","reporter_comm_i_exp_china"]]
data=pd.merge(data, base_t2,  how='left', left_on=["Year","Reporter","Commodity Code"], right_on = ["Year","Reporter","Commodity Code"])

base_t3=base_t3[["Year","Commodity Code","china_imp_comm_i"]]
data=pd.merge(data, base_t3,  how='left', left_on=["Year","Commodity Code"], right_on = ["Year","Commodity Code"])

base_t4=base_t4[["Year","Commodity Code","world_imp_comm_i"]]
data=pd.merge(data, base_t4,  how='left', left_on=["Year","Commodity Code"], right_on = ["Year","Commodity Code"])

base_t5=base_t5[["Year","Commodity Code","world_exp_comm_i"]]
data=pd.merge(data, base_t5,  how='left', left_on=["Year","Commodity Code"], right_on = ["Year","Commodity Code"])




data.to_csv(r'K:\2020_2431\q\sandbox_china_comm\base_t6_'+str(y)+'.csv', index = True, header=True)
# Out:
# Index(['Unnamed: 0', 'Year', 'Trade Flow', 'Reporter Code', 'Reporter',
#        'Commodity Code', 'Commodity', 'Trade Value (US$)'],
#       dtype='object')
# Index(['Unnamed: 0', 'Year', 'Trade Flow', 'Reporter Code', 'Reporter',
#        'Commodity Code', 'Commodity', 'Trade Value (US$)'],
#       dtype='object')
# Index(['Unnamed: 0', 'Year', 'Period', 'Period Desc.', 'Trade Flow',
#        'Reporter Code', 'Reporter', 'Reporter ISO', 'Partner Code', 'Partner',
#        'Partner ISO', 'Commodity Code', 'Commodity', 'Trade Value (US$)'],
#       dtype='object')
# Index(['Unnamed: 0', 'Year', 'Period', 'Period Desc.', 'Trade Flow',
#        'Reporter Code', 'Reporter', 'Reporter ISO', 'Partner Code', 'Partner',
#        'Partner ISO', 'Commodity Code', 'Commodity', 'Trade Value (US$)'],
#       dtype='object')
# Index(['Unnamed: 0', 'Commodity', 'Commodity Code', 'Reporter', 'Trade Flow',
#        'Trade Value (US$)', 'Year'],
#       dtype='object')

# %%
#reporter_comm_i_exp_world	reporter_exp_world	reporter_comm_i_exp_china	china_imp_comm_i	world_imp_comm_i


data["Index_0"]= (data.reporter_comm_i_exp_world/data.reporter_exp_world)
data["Index_1"]= (data.reporter_comm_i_exp_china/data.reporter_comm_i_exp_world)
data["Index_2"]= (data.china_imp_comm_i/data.world_imp_comm_i)+(1-(data.reporter_comm_i_exp_world/data.world_exp_comm_i))/2
data["Index_DC"]=data["Index_0"]*data["Index_1"]*data["Index_2"]
data["Index_DC"]=data["Index_DC"]**(1./3.)


print(data)
data.to_clipboard()
# Out:
#     Year Trade Flow  Reporter Code            Reporter  Commodity Code  \
# 0   2020     Export             32           Argentina              10
# 1   2020     Export             32           Argentina              12
# 2   2020     Export             32           Argentina              17
# 3   2020     Export             32           Argentina              27
# 4   2020     Export             32           Argentina              71
# 5   2020     Export             32           Argentina              72
# 6   2020     Export             32           Argentina              73
# 7   2020     Export             32           Argentina              74
# 8   2020     Export             32           Argentina              83
# 9   2020     Export             36           Australia              10
# 10  2020     Export             36           Australia              12
# 11  2020     Export             36           Australia              17
# ...

# %%
#chart with personal filter
#cahrt by H2 commodity group
#replicates charts
data_g=data

comm="10"
data_g[data_g['Commodity Code']==int(comm)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-4c1782e752f9> in <module>
#       5
#       6 comm="10"
# ----> 7 data_g[data_g['Commodity Code']==str(comm)]
#
# C:\Anaconda\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# C:\Anaconda\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1167                     result = method(y)
#    1168                 if result is NotImplemented:
# -> 1169                     raise TypeError("invalid type comparison")
#    1170             else:
#    1171                 result = op(x, y)
#
# TypeError: invalid type comparison

# %%
import numpy as np
import matplotlib.pyplot as plt


#lables
#name correctilu
#tuitels


parameter_y=15
parameter_x=15
parameter_z=15
parameter_f1=15    
parameter_f2=8   
parameter_t=10

import os
os.chdir('K:/2020_2431/q/china_comm')
#os.chdir('K:/2020_2431/q/cds_report/images/cross_eco/report')
print(os.getcwd())

########update!--------------
name='modelA0003_'
methodology="EM CDS Cross Sectional Regression (Residual)"
variable_text='latest CDS market value'
#filter_text ="No filter"
#expectation_text="H.Expect"
name_text=str("[ "+name+" ]")
comparison="XCountry Comparison"
p_parameter=2
title_graph="EM CDS - Rating Fit Model "
c_label="Country - Source: Comtrade, EGM-LDN"
y_label="Exports dependency to China index"

fig_name="cross economic res"
met="(0 no dependency - 1 absolute dependency)"
########---------------------



data_g=data
n=0
#loop_list=list_comm
loop_list=["10"]
for x in range(len(loop_list)): 
    n=n+1
    comm=str(loop_list[x])   
    print(comm)
    graph_input= data_g[data_g['Commodity Code']==int(comm)]
    
    
    tittle = graph_input["Commodity"].unique()

    print(tittle)
    
    #aaaaa
    chart=graph_input[["Reporter","Index_DC"]]
    chart = chart.sort_values(["Index_DC"], ascending=[False])

    tittle=str(y_label)+"    Commodity: "+str(tittle)+"  Index:"+str(met)
    
    
    #large and height
    plt.figure(figsize=(20,10))
    # We prepare the plot  
    #fig, ax = plt.subplots()

    # We change the fontsize of minor ticks label 
    #ax.tick_params(axis='both', which='major', labelsize=10)
    #ax.tick_params(axis='both', which='minor', labelsize=10)
    # Create bars
    plt.bar(chart["Reporter"], chart["Index_DC"])
    plt.ylim(0, 0.7)
    
    #ax = plt.gca()
    #ax.set_xlim([xmin, xmax])
    #plt.set_ylim([0, 0.5])
    # Create names on the x-axis
    #plt.xticks(x_pos, bars, color='orange')
    #plt.yticks(color='orange')
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(c_label), size=12)
    plt.title(str(tittle), size=20,
              loc='center')
              #weight='bold',
              #color='darkblue')
    #plt.suptitle(str(supt),size=10)
    #plt.rc('xtick',labelsize=9)
    #plt.rc('ytick',labelsize=9)
    #plt.savefig(location, bbox_inches='tight')
    plt.savefig("China_comm_"+str(n)+".jpg", bbox_inches='tight')
    plt.show()
    plt.close()
    plt.close('all')
    plt.clf()
    plt.cla()
# Out:
# K:\2020_2431\q\china_comm
# 10
# ['Cereals']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-26689e070960> in <module>
#     100
#     101
# --> 102     for p in splot.patches:
#     103         splot.annotate(format(p.get_height(), '.0f'),
#     104                    (p.get_x() + p.get_width() / 2., p.get_height()),
#
# NameError: name 'splot' is not defined

# %%
table_f= pd.read_csv (r'K:\2020_2431\q\sandbox_china_comm\table_f.csv')
print (table_f)
table_f = pd.DataFrame(table_f,columns=["Reporter Code","Commodity Code"])
table_f_r=table_f["Reporter Code"]
table_f_r.column=["Reporter Code"]
print(table_f_r)
table_f_c=table_f["Commodity Code"]
table_f_r.column=["Commodity Code"]
print(range(len(table_f)))
# Out:
#     Reporter Code  Commodity Code
# 0              36              10
# 1              36              74
# 2             392              74
# 3             360              72
# 4             392              72
# 5             710              72
# 6             392              73
# 7              36              27
# 8              76              27
# 9             170              27
# 10            360              27
# 11            458              27
# 12            643              27
# 13            643              71
# 14             76              12
# 15             76              17
# 0      36
# 1      36
# 2     392
# 3     360
# 4     392
# 5     710
# 6     392
# 7      36
# 8      76
# 9     170
# 10    360
# 11    458
# 12    643
# 13    643
# 14     76
# 15     76
# Name: Reporter Code, dtype: int64
# range(0, 16)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
os.chdir('K:/2020_2431/q/china_comm')
#os.chdir('K:/2020_2431/q/cds_report/images/cross_eco/report')
print(os.getcwd())


data_g2=data[["Year","Reporter Code","Reporter","Commodity Code","Commodity","Index_DC"]]
 
list_columns=["Year","Reporter Code","Reporter","Commodity Code","Commodity","Index_DC"]
base_g0=pd.DataFrame(columns=list_columns)
print(base_g0)


table_f = pd.DataFrame(table_f,columns=["Reporter Code","Commodity Code"])




for x in range(len(table_f)): 
    print(x)
    rep = table_f_r.get_value(table_f_r.index[x],'VALUE')
    print(rep)
    comm = table_f_c.get_value(table_f_c.index[x],'VALUE')
    print(comm)
    base_g1 = data_g2[(data_g2["Reporter Code"]==int(rep)) & (data_g2["Commodity Code"]==int(comm))]
    base_g0=base_g0.append(base_g1, ignore_index=True)
    del base_g1


#print(base_g0)
#base_g0.to_clipboard()

base_g0=base_g0[["Reporter", "Commodity","Index_DC"]]
base_g0['Reporter'] = base_g0['Reporter'].str[0:9]
base_g0['Commodity'] = base_g0['Commodity'].str[0:7]
base_g0['Reporter'] = base_g0['Reporter'] + " " + base_g0['Commodity']
base_g0=base_g0[["Reporter","Index_DC"]]
print(base_g0)



c_label="Country - Source: Comtrade, EGM-LDN"
y_label="Exports dependency to China index"

fig_name="cross economic res"
met="(0 no dependency - 1 absolute dependency)"
########---------------------



chart = base_g0
chart = chart.sort_values(["Index_DC"], ascending=[False])
tittle="Commodity Exports dependency to China   -  Index: (0 no dependency - 1 absolute dependency)"
########---------------------


#large and height
plt.figure(figsize=(20,10))
# We prepare the plot  
#fig, ax = plt.subplots()

# We change the fontsize of minor ticks label 
#ax.tick_params(axis='both', which='major', labelsize=10)
#ax.tick_params(axis='both', which='minor', labelsize=10)
# Create bars
plt.bar(chart["Reporter"], chart["Index_DC"])
plt.ylim(0, 0.5)
plt.xticks(fontsize=16,rotation = 70)
plt.yticks(fontsize=16)
plt.ylabel(str(y_label), size=20)
plt.xlabel(str(c_label), size=12)
plt.title(str(tittle), size=20,loc='center')
plt.savefig("China_comm_.jpg", bbox_inches='tight')
plt.savefig("China_comm_.pdf", bbox_inches='tight')
plt.show()
plt.close()
plt.close('all')
plt.clf()
plt.cla()
    
import subprocess



src=r'K:\2020_2431\q\china_comm\China_comm_.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\china_comm\China_comm_.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


print("Complete")
# Out:
# K:\2020_2431\q\china_comm
# Empty DataFrame
# Columns: [Year, Reporter Code, Reporter, Commodity Code, Commodity, Index_DC]
# Index: []
# 0
# 36
# 10
# 1
# 36
# 74
# 2
# 392
# 74
# 3
# 360
# 72
# 4
# 392
# 72
# 5
# 710
# 72
# 6
# 392
# 73
# 7
# 36
# 27
# 8
# 76
# 27
# 9
# 170
# 27
# 10
# 360
# 27
# 11
# 458
# 27
# 12
# 643
# 27
# 13
# 643
# 71
# 14
# 76
# 12
# 15
# 76
# 17
#              Reporter  Index_DC
# 0   Australia Cereals  0.130657
# 1   Australia Copper   0.166428
# 2       Japan Copper   0.164571
# 3   Indonesia Iron an  0.302508
# 4       Japan Iron an  0.156297
# 5   South Afr Iron an  0.190400
# 6       Japan Iron or  0.114272
# 7   Australia Mineral  0.261906
# 8      Brazil Mineral  0.331019
# 9    Colombia Mineral  0.368493
# 10  Indonesia Mineral  0.306329
# 11   Malaysia Mineral  0.231618
# 12  Russian F Mineral  0.376288
# 13  Russian F Natural  0.046781
# 14     Brazil Oil see  0.426743
# 15     Brazil Sugars   0.141978
# ...

# %%
slect variables 
save with otehr names and with the yuear label


redo with another H4 AGGREGATE CATEGORY






#data=pd.merge(data, df2,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')

#country comoduty code commodiites, 
#[variable 0 comoodity i exports to world]  
#reporter_comm_i_exp_world
#[variable 1 country all exports to world] 
#reporter_exp_world
#[variable 2 country  comoddity i exports  tochina ]
#reporter_comm_i_exp_china
#[variable 3 china imports of comodity i ] 
#china_imp_comm_i
#[variable 4 all  imports of comodity i ] 
#world_imp_comm_i

#Exppor ij,, brazil exports of soybeans as a % of all brazil commodity exporpts
#varaible brazl soybeans exports to woerld (base type 0)
#base type 1
#variable brazil totoal exports to world (base type 1)
####export t o china i j, brazil erxports of soybeas  to chines
#variable brazil soybean exports to china (base type 2)
#variable country j comodity i export to China
###varaibles: china imports of comody xxxx in year xxx, independednt of partner (base type 3)

### varaibles all imports of that comododity in year .  (base type 4)
# Out:
# Index(['Classification', 'Year', 'Period', 'Period Desc.', 'Aggregate Level',
#        'Is Leaf Code', 'Trade Flow Code', 'Trade Flow', 'Reporter Code',
#        'Reporter', 'Reporter ISO', 'Partner Code', 'Partner', 'Partner ISO',
#        '2nd Partner Code', '2nd Partner', '2nd Partner ISO',
#        'Customs Proc. Code', 'Customs', 'Mode of Transport Code',
#        'Mode of Transport', 'Commodity Code', 'Commodity', 'Qty Unit Code',
#        'Qty Unit', 'Qty', 'Alt Qty Unit Code', 'Alt Qty Unit', 'Alt Qty',
#        'Netweight (kg)', 'Gross weight (kg)', 'Trade Value (US$)',
#        'CIF Trade Value (US$)', 'FOB Trade Value (US$)', 'Flag'],
#       dtype='object')
# ...
