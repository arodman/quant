# %%
jupyter kernelspec list
# Out:
#   File "<ipython-input-2-68dcfb427789>", line 1
#     jupyter kernelspec list
#             ^
# SyntaxError: invalid syntax

# %%
# Run proces

#First loda data


# %run 

\AppData\Local\conda\conda\envs\anaconda_2020.11 environment\python.exe EMCDS_0001_rating1.py

C:\Users\amanrique\AppData\Local\conda\conda\envs\base\python.exe EMCDS_0000_data_load_economic.ipynb
    
    
C:\Users\amanrique\
    
AppData\Local\conda\conda\envs\base\python.exe EMCDS_0000_data_load_economic.py
    
jupyter nbconvert --to notebook --execute mynotebook.ipynb

C:\Users\amanrique\AppData\Local\conda\conda\envs\base\python.exe EMCDS_0000_data_load_economic.ipynb
    
    
conda activate base && jupyter nbconvert --to notebook --execute EMCDS_0000_data_load_economic.ipynb 
24th Aug 2021 5:40:34 pm Alan Rodriguez Manrique: 
C:\Users\amanrique\AppData\Local\conda\conda\envs\base\python.exe EMCDS_0000_data_load_economic.ipynb

    

C:\Users\amanrique>conda env list
    
    

#anaconda_2018.12
EMCDS_0000_data_load_economic.ipynb
########wb2.to_csv (r'K:\2020_2431\q\sandbox\gov1.csv', index = False, header=True)




#anaconda_2020.11 environment
EMCDS_0001_rating1
###########rating_table = pd.read_csv (r'K:\2020_2431\q\sandbox\rating_translation.csv')
###base001 = pd.read_csv (r'K:\2020_2431\q\sandbox\data_rating_fit.csv')
####location_first= ("K:\\2020_2431\\q\\cds_report\\images\\rating_fit\\")
#######os.chdir('K:/2020_2431/q/cds_report/images/rating_fit') 
###########final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\rating_fit\\report_m\\002")





#anaconda_2020.11 environment
EMCDS_0002_pca governance
######cds_tmp = pd.read_csv (r'K:\2020_2431\q\sandbox\cds_tmp.csv')
### gov = pd.read_csv (r'K:\2020_2431\q\sandbox\gov1.csv')
###os.chdir('K:/2020_2431/q/cds_report/images/pca/report_c')
#final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\pca\\report\\")
#os.chdir('K:/2020_2431/q/cds_report/images/pca/report_c')
#final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\pca\\report\\")
#final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\pca\\report\\")
#final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\pca\\report_m\\")
#os.chdir('K:/2020_2431/q/cds_report/images/pca')
#final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\\pca\\report\\")
#source_dir = 'K:/2020_2431/q/cds_report/images/pca/report/'
#source_dir2 = 'K:/2020_2431/q/cds_report/images/pca/report_f/'
#output002.to_csv (r'K:\2020_2431\q\cds_report\output\output002.csv', index = False, header=True)





#anaconda_2020.11 environment
EMCDS_0003_CrossEconomic
#os.chdir('K:/2020_2431/q/cds_report/images/cross_eco/report')
#final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\cross_eco\\report_f\\")
##file location
#location_first= ("K:\\2020_2431\\q\\cds_report\\images\\cross_eco\\")
#os.chdir('K:/2020_2431/q/cds_report/images/cross_eco/report')
#print(os.getcwd())
#final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\cross_eco\\report_f\\")
#os.chdir('K:/2020_2431/q/cds_report/images/cross_eco/report')
#os.chdir('K:/2020_2431/q/cds_report/images/cross_eco/scatterplot')
#output003.to_csv (r'K:\2020_2431\q\cds_report\output\output003.csv', index = False, header=True)


#anaconda_2020.11 environment
EMCDS_0004_decisiontree
#base = pd.read_csv (r'K:\2020_2431\cds\decision_tree\cds_data3.csv')
#Loop create decision treess graphs 
#os.chdir('K:/2020_2431/q/cds_report/images/tree/report_m')
#os.chdir('K:/2020_2431/q/cds_report/images/tree/report')
#print(os.getcwd())
#final_location_first = "K:\\2020_2431\\q\\cds_report\\images\\tree\\report_m\\"
#os.chdir('K:/2020_2431/q/cds_report/images/tree/report')
##output004.to_csv (r'K:\2020_2431\q\cds_report\output\output004.csv',


#anaconda_2018.12
###this has fx data
EMCDS_0000_data_load_regimeswitch




##anaconda_2020.11 environment
###this has fx data
EMCDS_0005_regimeswitch




#anaconda_2020.11 environment
###this has fx data
EMCDS_0006_RNN



#anaconda_2020.11 environment
######this has fx data

EMCDS_0001_Technical_Complete
###m = pd.read_csv (r'K:\2020_2431\q\sandbox\summary_table.csv')
#final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\tc\\report_f\\")
#location_first= ("K:\\2020_2431\\q\\cds_report\\images\\tc\\")
#os.chdir('K:/2020_2431/q/cds_report/images/tc/report')


#anaconda_2020.11 environment
EMCDS_F000_files




#%run ./called_notebook.ipynb
#foo()
#%run my_other_notebook.ipynb


from codetiming import Timer
timeclock = Timer(name="class")
timeclock.start()
# Do something
timeclock.stop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Documents\EMCDS_0000_data_load_economic.ipynb in <module>
#       5 matplotlib.use('Agg')
#       6 import pandas as pd
# ----> 7 from alphasuite.providers import MarketDataProvider
#       8 from alphasuite.market import market_data_upload
#       9
#
# ModuleNotFoundError: No module named 'alphasuite'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-62dd35cb8899> in <module>
#       4
#       5
# ----> 6 get_ipython().run_line_magic('run', 'EMCDS_0000_data_load_economic.ipynb')
#       7
#       8 #EMCDS_0001_rating
#
# C:\Anaconda_2020.11\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
# ...
