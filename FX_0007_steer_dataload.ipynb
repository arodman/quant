# %%
#GTCHF3M Govt




#eview techncialk everythign al right
#data is update iwth the lastest
#back test of te strategy
#grpahs better
#acompare last week score with this week scores
#techncaiol talbe
#show thios weeks changes onlym#
#dd comoditites data
#add jpm data c
#tot
#add 
#scatter plot biggest changes toda vs 1 week
#todas vs 2 week 
#todasy vs 1 month 
#biggest hcanges in fx variasotn 
#####backtest for straegyu
###hacer backtest, agregado y mejros estrategies
#graph macro indicators
#graph each time series
#and copy paste pdf
#and coonnects to each pdf. 
#hsitorico de macroindicators
#grafciar series del macroindicatos
#connecxion macro indicatrs copiar pegar
###########################################################


#Valuation Difference	REER (Broad CPI Based) 10yr Avg	3M	6M
#BEER	REER Deviation from 10yr Avg	Idiosyncratic Value proxy 3M	Idiosyncratic Value proxy 6M
#Valuation Conviction ranking
#Avg of Fair Value (Over/Undervaluation)
#Carry (Swap 6M)	VRP 6M	Momentum (1W)	IRP 6M	IRP 3M	Equity Driven (3M)	Aggregated Technical Conviction Score
#Score	Aggregated Technical Conviction Score

#MacroIndicator_Overall	MacroIndicator_External (+)	Macro Ranking	Macro Indicators Conviction Ranking
#MacroIndicator (Monthly update)	MacroIndicator (Monthly update)



#####quesitons

# COmmodities is an index
##### levesl???

# %%
################
#model x independnet variables



                 
 
                 
#BBGTKR::BLOOMBERG::BASPTDSP Index
#BBGTKR::BLOOMBERG::CO1 Comdty
#BBGTKR::BLOOMBERG::COA Comdty
#BBGTKR::BLOOMBERG::DAX Index
#BBGTKR::BLOOMBERG::HG1 Comdty
#BGTKR::BLOOMBERG::HGA Comdty
#BBGTKR::BLOOMBERG::MOODCAAA Index
#BBGTKR::BLOOMBERG::MOODCBAA Index
#BBGTKR::BLOOMBERG::UKX Index
#BBGTKR::BLOOMBERG::US0003M Index
#BBGTKR::BLOOMBERG::USGG10YR Index
#BBGTKR::BLOOMBERG::USGG2YR Index
#BBGTKR::BLOOMBERG::USGG3M Index
#BBGTKR::BLOOMBERG::USGG5YR Index
#BBGTKR::BLOOMBERG::USGG7YR Index
#BBGTKR::BLOOMBERG::USGGBE05 Index
#BBGTKR::BLOOMBERG::USGGBE10 Index
#BBGTKR::BLOOMBERG::XAG Curncy
#BBGTKR::BLOOMBERG::XAU Curncy
        

#msci 
#carry
#volatiltiy risk premiua
# momentum
#idyosyncratics



#fx valuaiton
#ididysyncratics
#reer jpm
#adne beer


#macroidnicators
#real
#monetary
#fiscal
#extertla
#overall

# %%
#IMPORT PACKAGES 
import datetime as dt
from datetime import date
import pandas as pd 
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas
import pandas as pd
from datetime import date
from datetime import datetime
from mdng_client import OTReader
#####CHANGE UAT TO PROD
reader = OTReader(tz='America/New_York', env='PROD') # the timezone for start/end and returned timestamps


import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas as pd

import pandas
from datetime import datetime
from mdng_client import OTReader
reader = OTReader(tz='America/New_York', env='PROD')


import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas as pd

import pandas
from datetime import datetime
from mdng_client import OTReader
reader = OTReader(tz='America/New_York', env='PROD')


from datetime import datetime

# %%
#parameters
start = '2009-12-31'
end = datetime.today().strftime('%Y-%m-%d')
print(end)
time = pd.date_range(start=start, end=end, freq='7d')
print(time)
#np.array(times)
#>>> from datetime import datetime as date
#>>> date.today().strftime("%A")
#'Monday'

#time = DataFrame(times,columns=['date'])
#print(time)
# Out:
# 2021-11-24
# DatetimeIndex(['2009-12-31', '2010-01-07', '2010-01-14', '2010-01-21',
#                '2010-01-28', '2010-02-04', '2010-02-11', '2010-02-18',
#                '2010-02-25', '2010-03-04',
#                ...
#                '2021-09-16', '2021-09-23', '2021-09-30', '2021-10-07',
#                '2021-10-14', '2021-10-21', '2021-10-28', '2021-11-04',
#                '2021-11-11', '2021-11-18'],
#               dtype='datetime64[ns]', length=621, freq='7D')

# %%
#IMPORT PACKAGES 
import datetime as dt
from datetime import date
import pandas as pd 
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas
import pandas as pd
from datetime import date
from datetime import datetime
from mdng_client import OTReader
#####CHANGE UAT TO PROD
reader = OTReader(tz='America/New_York', env='PROD')

# the timezone for start/end and returned timestamps

from mdng_client.utils import format_to_melted_df
from mdng_client import OTReader
import onetick.query as otq
from datetime import datetime, timedelta
import numpy as np

reader = OTReader(tz='America/New_York', env='PROD')
reader = OTReader(tz='America/New_York', env='PROD')

import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas as pd

import pandas
from datetime import datetime
from mdng_client import OTReader
reader = OTReader(tz='America/New_York', env='PROD')

import datetime as datetime

# %%
now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# Y 2021 / M 11 / D 24 /// H 9 : M 14 : S 39

# %%
def from_name_source_as_of_time(names, source, as_of_time, is_eod):
    # need some logic to determine if they are querying EOD or intradaY
    if is_eod:
        tick_type = 'DAY' # change as needed for object
    else:
        tick_type = 'TRD'
        
    symbols = ['BBGTKR::BLOOMBERG::' + name.upper() for name in names]
    graph = otq.Graph(
            otq.Chainlet(
                otq.Passthrough().tick_type(tick_type),
                otq.WhereClause(discard_on_match=False, where="SOURCE='{}'".format(source.upper()))
            )
    )
    # interval is [start, end)
    start = as_of_time - timedelta(days=10000)
    end = as_of_time

    result = reader.run_generic_query(
        graph_or_otq=graph,
        symbols=symbols,
        start=start,
        end=end,
        symbol_date=as_of_time,
    )
    return format_to_melted_df(symbols=symbols, result=result)
########

# %% [markdown]
# usdeur
# usdgbp
# usdjpy
# usdaud
# usdnzd
# usdcad
# usdchf
# usdnok
# usdsek
# eurgbp
# eurjpy
# euraud
# eurnzd
# eurcad
# eurchf
# eurnok
# eursek
# gbpjpy
# gbpaud
# gbpnzd
# gbpcad
# gbpchf
# gbpnok
# gbpsek
# jpyaud
# jpynzd
# jpycad
# jpychf
# jpynok
# jpysek
# audnzd
# audcad
# audchf
# audnok
# audsek
# nzdcad
# nzdchf
# nzdnok
# nzdsek
# cadchf
# cadnok
# cadsek
# chfnok
# chfsek
# noksek

# %% [markdown]
# #"BBGTKR::BLOOMBERG_PARENT::EURSEK CURNCY",
# as_of_date = datetime.datetime.today()
#
# symbols = ["BBGTKR::BLOOMBERG_PARENT::EURUSD CURNCY","BBGTKR::BLOOMBERG_PARENT::GBPUSD CURNCY",
#            "BBGTKR::BLOOMBERG_PARENT::EURNOK CURNCY",
#            "BBGTKR::BLOOMBERG_PARENT::AUDUSD CURNCY","BBGTKR::BLOOMBERG_PARENT::NZDUSD CURNCY",
#            "BBGTKR::BLOOMBERG_PARENT::USDCAD CURNCY","BBGTKR::BLOOMBERG_PARENT::USDJPY CURNCY",
#            "BBGTKR::BLOOMBERG_PARENT::EURCHF CURNCY"]
#
#
# #'EUR CURNCY','GBP CURNCY','JPY CURNCY' ,'NZD CURNCY','AUD CURNCY', 'CHF CURNCY','NOK CURNCY','CAD CURNCY']
#
# test00001 = from_name_source_as_of_time(symbols, 'BGN', as_of_date, True)
# test00001.drop_duplicates()
# test00001 = test00001.reset_index()
# test00001["TIME"]=test00001["TIME"].dt.strftime("%Y-%m-%d")
# test00001=test00001[['TIME','PX_LAST','TICKER']]
# #test00001.drop_duplicates()
# #test00001['TIME']=str(test00001['TIME'])
# #test00001['year'] = pd.DatetimeIndex(test00001['TIME']).year
# #test00001['month'] = str(pd.DatetimeIndex(test00001['TIME']).month)
# #test00001['day'] = str(pd.DatetimeIndex(test00001['TIME']).day)
# #df['Dates'] = pd.to_datetime(df['Dates'], format='%y%m%d')
#
# test00002=pd.pivot_table(test00001,index=["TIME"],values=["PX_LAST"], columns=["TICKER"],aggfunc=[np.sum])
# test00002=test00002.fillna(method='bfill')
# test00002=test00002.fillna(method='bfill')
# #remove amount
# test00002.columns = test00002.columns.droplevel(0)
# test00002.columns = test00002.columns.droplevel(0)
#
# test00002 = test00002.reset_index()
# test00002=test00002.set_index('TIME')
# #test00002['date'] = test00002['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
#
#
# test00002=test00002.replace(to_replace=0, method='ffill')
#
# test00002.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\fx_tmp.csv', index = True, header=True)
# print("Complete!!!!")
# now = datetime.datetime.now()
# print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)

# %%
#"BBGTKR::BLOOMBERG_PARENT::EURSEK CURNCY",


symbols = ["BBGTKR::BLOOMBERG_PARENT::EURUSD CURNCY","BBGTKR::BLOOMBERG_PARENT::GBPUSD CURNCY",
           "BBGTKR::BLOOMBERG_PARENT::EURNOK CURNCY",
           "BBGTKR::BLOOMBERG_PARENT::AUDUSD CURNCY","BBGTKR::BLOOMBERG_PARENT::NZDUSD CURNCY",
           "BBGTKR::BLOOMBERG_PARENT::USDCAD CURNCY","BBGTKR::BLOOMBERG_PARENT::USDJPY CURNCY",
           "BBGTKR::BLOOMBERG_PARENT::EURCHF CURNCY"]

# # notice here we are retrieving data from dataquery and bloomberg using the bloomberg ticker

l_msci =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
l_msci.head()
l_msci=l_msci.fillna(method='bfill')
#l_msci=pd.merge(time, l_msci,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
l_msci.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\fx_tmp.csv', index = True, header=True)

now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# Y 2021 / M 11 / D 24 /// H 9 : M 14 : S 44

# %% [markdown]
# # Equities

# %%
#AUD	MXAU INDEX
#CAD	MXCA Index
#CHF	MXCH Index
#EUR	MXEU Index
#GBP	MXGB Index
#JPY	MXJP INDEX
#NOK	MXNO Index
#NZD	MXNZ Index
#SEK	MXSE Index
#USD	MXUS INDEX


#Equities MSCI INDEX EXTRACT
#symbols = ['BBGTKR::BLOOMBERG_PARENT::MXAU Index','BBGTKR::BLOOMBERG_PARENT::MXCA Index',
#           'BBGTKR::BLOOMBERG_PARENT::MXCH Index','BBGTKR::BLOOMBERG_PARENT::MXEU Index',
#           'BBGTKR::BLOOMBERG_PARENT::MXGB Index','BBGTKR::BLOOMBERG_PARENT::MXJP Index',
#           'BBGTKR::BLOOMBERG_PARENT::MXNO Index','BBGTKR::BLOOMBERG_PARENT::MXNZ Index',
#           'BBGTKR::BLOOMBERG_PARENT::MXSE Index','BBGTKR::BLOOMBERG_PARENT::MXWD Index',
#           'BBGTKR::BLOOMBERG_PARENT::MXWO Index']



symbols = ['BBGTKR::BLOOMBERG_PARENT::CCMP INDEX',
           'BBGTKR::BLOOMBERG_PARENT::DAX INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MCX INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXAU INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXCA INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXCH INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXCL INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXCN INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXCZ INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXEU INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXGB INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXHU INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXID INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXIL INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXIN INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXJP INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXKR INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXMX INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXNO INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXNZ INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXPE INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXPH INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXPL INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXRU INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXSE INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXTH INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXTR INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXUS INDEX',
           'BBGTKR::BLOOMBERG_PARENT::MXWO COMDTY',
           'BBGTKR::BLOOMBERG_PARENT::MXZA INDEX',
           'BBGTKR::BLOOMBERG_PARENT::OMX INDEX',
           'BBGTKR::BLOOMBERG_PARENT::SPX INDEX']

#BBGTKR::BLOOMBERG_PARENT::MXWD INDEX',
#'BBGTKR::BLOOMBERG_PARENT::MXBR INDEX',
# # notice here we are retrieving data from dataquery and bloomberg using the bloomberg ticker

l_msci =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PX_LAST',
                        )
l_msci.head()
l_msci=l_msci.fillna(method='bfill')
#l_msci=pd.merge(time, l_msci,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
l_msci.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\ols_l_msci_tmp.csv', index = True, header=True)

now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)
# Out:
# You can set SHOW_STACK_INFO = 1 in config.py file in order to see stack information in the exception
# or you can set SHOW_STACK_WARNING = 0 to disable this message.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-4de1d5ead62a> in <module>
#      61                         start=start,
#      62                         end=end,
# ---> 63                         fields='PX_LAST',
#      64                         )
#      65 l_msci.head()
#
# C:\Anaconda\lib\site-packages\mdng_client\utils\validation.py in wrapped(cls, *args, **kwargs)
#      23         if args:
#      24             raise ValueError(f"All arguments for {func.__name__} must be passed as keyword args")
# ---> 25         return func(cls, **kwargs)
#      26
#      27     return wrapped
#
# C:\Anaconda\lib\site-packages\mdng_client\utils\validation.py in wrapped(cls, **kwargs)
# ...

# %%
#s&p retunr
     ##   is stock sp500 weekly retunr#SP500 Weekly Returns	Global
msci_us =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::MXUS INDEX'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
msci_us.head()
msci_us=msci_us.fillna(method='bfill')
#msci_us=pd.merge(time, msci_us,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
msci_us.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\msci_us_tmp.csv', index = True, header=True)


    
# ust t bill yield weekly differnece
#TREASURY BILL ChANGE#TBILL Weekly difference	Global
#TREASURY BILL CANGE

ust =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::USGG10YR Index'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
ust.head()
ust=ust.fillna(method='bfill')
#ust=pd.merge(time, ust,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
ust.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\ust_tmp.csv', index = True, header=True)


us_y =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::H15T10Y Index'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
us_y.head()
us_y=us_y.fillna(method='bfill')
#us_y=pd.merge(time, us_y,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
us_y.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\us_y_tmp.csv', index = True, header=True)


carry_index =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::MSCBFCAE Index'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
carry_index.head()
carry_index=carry_index.fillna(method='bfill')
#carry_index=pd.merge(time, carry_index,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
carry_index.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\carry_index_tmp.csv', index = True, header=True)


#Vix
vix =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::VIX INDEX'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
vix.head()
vix=vix.fillna(method='bfill')
#vix=pd.merge(time, vix,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
vix.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\vix_tmp.csv', index = True, header=True)



#CL1 COMDTY
#
oil =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG_PARENT::CL1 COMDTY'],
                        start=start,
                        end=end,
                        fields='PX_LAST',
                        )
oil.head()
oil=oil.fillna(method='bfill')
#vix=pd.merge(time, vix,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
oil.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\oil_tmp.csv', index = True, header=True)




print("COmplete")
now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)

# %%
#us_6m


symbols=['BBGTKR::BLOOMBERG::GTCHF10Y GOVT',
         'BBGTKR::BLOOMBERG::GTCHF2Y GOVT',
         'BBGTKR::BLOOMBERG::GTCHF3M GOVT',
         'BBGTKR::BLOOMBERG::GTJPY10Y GOVT',
         'BBGTKR::BLOOMBERG::GTJPY2Y GOVT',
         'BBGTKR::BLOOMBERG::GTJPY3M GOVT',
         'BBGTKR::BLOOMBERG::GTDEM10Y GOVT',
         'BBGTKR::BLOOMBERG::GTDEM2Y GOVT',
         'BBGTKR::BLOOMBERG::GTDEM3M GOVT',
         'BBGTKR::BLOOMBERG::GUKG10 INDEX',
         'BBGTKR::BLOOMBERG::GUKG2 INDEX',
         'BBGTKR::BLOOMBERG::GUKG3M INDEX',
         'BBGTKR::BLOOMBERG::GTNOK10Y GOVT',
         'BBGTKR::BLOOMBERG::GTNOK2Y GOVT',
         'BBGTKR::BLOOMBERG::GTNOK3M GOVT',
         'BBGTKR::BLOOMBERG::GTAUD10Y GOVT',
         'BBGTKR::BLOOMBERG::GTAUD2Y GOVT',
         'BBGTKR::BLOOMBERG::GTAUD3M GOVT',
         'BBGTKR::BLOOMBERG::GNZGB10 INDEX',
         'BBGTKR::BLOOMBERG::GNZGB2 INDEX',
         'BBGTKR::BLOOMBERG::GTNZD10Y GOVT',
         'BBGTKR::BLOOMBERG::GTNZD2Y GOVT',
         'BBGTKR::BLOOMBERG::GTNZD3M GOVT',
         'BBGTKR::BLOOMBERG::GCAN10YR INDEX',
         'BBGTKR::BLOOMBERG::GCAN2YR INDEX',
         'BBGTKR::BLOOMBERG::GNOR10YR INDEX',
         'BBGTKR::BLOOMBERG::GNOR2YR INDEX',

         'BBGTKR::BLOOMBERG::GTCAD10Y GOVT',
         'BBGTKR::BLOOMBERG::GTCAD2Y GOVT',
         'BBGTKR::BLOOMBERG::GTCAD3M GOVT',
         'BBGTKR::BLOOMBERG::GSGB2YR INDEX',
         'BBGTKR::BLOOMBERG::GSGB10YR INDEX',
         'BBGTKR::BLOOMBERG::GTSEK10Y GOVT',
         'BBGTKR::BLOOMBERG::GTSEK2Y GOVT',
         'BBGTKR::BLOOMBERG::GTSEK3M GOVT',
         'BBGTKR::BLOOMBERG::USGG10YR INDEX',
         'BBGTKR::BLOOMBERG::USGG2YR INDEX',
         'BBGTKR::BLOOMBERG::USGG3M INDEX',
         
         'BBGTKR::BLOOMBERG::GTCHF1Y GOVT',
         'BBGTKR::BLOOMBERG::GTJPY1Y GOVT',
         'BBGTKR::BLOOMBERG::GTDEM6M GOVT',
         'BBGTKR::BLOOMBERG::GUKG1 INDEX',
         'BBGTKR::BLOOMBERG::GUKG6M INDEX',
         'BBGTKR::BLOOMBERG::GTNOK1Y GOVT',
         'BBGTKR::BLOOMBERG::GTNOK6M GOVT',
         'BBGTKR::BLOOMBERG::GTAUD1Y GOVT',
         'BBGTKR::BLOOMBERG::GSGB1YR INDEX',
         'BBGTKR::BLOOMBERG::GTSEK6M GOVT',
         'BBGTKR::BLOOMBERG::GTSEK1Y GOVT',
         'BBGTKR::BLOOMBERG::GTCAD1Y GOVT',
         'BBGTKR::BLOOMBERG::GTCAD6M GOVT',
         'BBGTKR::BLOOMBERG::USGG1YR INDEX',
         'BBGTKR::BLOOMBERG::USGG6M INDEX',
         'BBGTKR::BLOOMBERG::GTNZD1Y GOVT']


us_6m =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PX_LAST',
                        )
us_6m.head()
us_6m=us_6m.fillna(method='bfill')
#vix=pd.merge(time, vix,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
us_6m.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\y_tmp.csv', index = True, header=True)


#GSGB2YR Index
#GSGB10YR Index
#GNZGB10 Index
#GNZGB2 Index

print("COmplete")
now = datetime.datetime.now()
print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)

# %%
#us_6m
us_6m =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::US0006M INDEX'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
us_6m.head()
us_6m=us_6m.fillna(method='bfill')
#vix=pd.merge(time, vix,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
us_6m.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\us6m_tmp.csv', index = True, header=True)

# %%
symbols=['BBGTKR::BLOOMBERG::BRERAT Index',
         'BBGTKR::BLOOMBERG::BRERAU Index',
         'BBGTKR::BLOOMBERG::BRERBE Index',
         'BBGTKR::BLOOMBERG::BRERBR Index',
         'BBGTKR::BLOOMBERG::BRERCA Index',
         'BBGTKR::BLOOMBERG::BRERCH Index',
         'BBGTKR::BLOOMBERG::BRERCL Index',
         'BBGTKR::BLOOMBERG::BRERCN Index',
         'BBGTKR::BLOOMBERG::BRERCO Index',
         'BBGTKR::BLOOMBERG::BRERCZ Index',
         'BBGTKR::BLOOMBERG::BRERDE Index',
         'BBGTKR::BLOOMBERG::BRERDK Index',
         'BBGTKR::BLOOMBERG::BRERER Index',
         'BBGTKR::BLOOMBERG::BRERES Index',
         'BBGTKR::BLOOMBERG::BRERFI Index',
         'BBGTKR::BLOOMBERG::BRERFR Index',
         'BBGTKR::BLOOMBERG::BRERGB Index',
         'BBGTKR::BLOOMBERG::BRERGR Index',
         'BBGTKR::BLOOMBERG::BRERHU Index',
         'BBGTKR::BLOOMBERG::BRERID Index',
         'BBGTKR::BLOOMBERG::BRERIE Index',
         'BBGTKR::BLOOMBERG::BRERIN Index',
         'BBGTKR::BLOOMBERG::BRERIT Index',
         'BBGTKR::BLOOMBERG::BRERJP Index',
         'BBGTKR::BLOOMBERG::BRERKR Index',
         'BBGTKR::BLOOMBERG::BRERMX Index',
         'BBGTKR::BLOOMBERG::BRERMY Index',
         'BBGTKR::BLOOMBERG::BRERNL Index',
         'BBGTKR::BLOOMBERG::BRERNO Index',
         'BBGTKR::BLOOMBERG::BRERNZ Index',
         'BBGTKR::BLOOMBERG::BRERPE Index',
         'BBGTKR::BLOOMBERG::BRERPH Index',
         'BBGTKR::BLOOMBERG::BRERPL Index',
         'BBGTKR::BLOOMBERG::BRERPT Index',
         'BBGTKR::BLOOMBERG::BRERRU Index',
         'BBGTKR::BLOOMBERG::BRERSE Index',
         'BBGTKR::BLOOMBERG::BRERTH Index',
         'BBGTKR::BLOOMBERG::BRERTR Index',
         'BBGTKR::BLOOMBERG::BRERUS Index',
         'BBGTKR::BLOOMBERG::BRERZA Index']


#Bloomberg Economics US Real Effective Exchange Rate CPI

fx_r =reader.get_daily_ticks(symbols=symbols,
                        start='2019-12-31',
                        end=end,
                        fields='PX_LAST',
                        )
fx_r.head()
fx_r=fx_r.fillna(method='bfill')
#fx_r.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\citi_reer.csv', index = True, header=True)


#GSGB2YR Index
#GSGB10YR Index
#GNZGB10 Index
#GNZGB2 Index

print("COmplete")
#now = datetime.datetime.now()
#print("Y",now.year,"/ M", now.month,"/ D", now.day, "/// H",now.hour,": M", now.minute,": S", now.second)

# %%
symbols=['BBGTKR::BLOOMBERG::CTTWBAED Index',
         'BBGTKR::BLOOMBERG::CTTWBARS Index',
         'BBGTKR::BLOOMBERG::CTTWBAUD Index',
         'BBGTKR::BLOOMBERG::CTTWBBGN Index',
         'BBGTKR::BLOOMBERG::CTTWBBHD Index',
         'BBGTKR::BLOOMBERG::CTTWBBRL Index',
         'BBGTKR::BLOOMBERG::CTTWBCAD Index',
         'BBGTKR::BLOOMBERG::CTTWBCHF Index',
         'BBGTKR::BLOOMBERG::CTTWBCLP Index',
         'BBGTKR::BLOOMBERG::CTTWBCNH Index',
         'BBGTKR::BLOOMBERG::CTTWBCOP Index',
         'BBGTKR::BLOOMBERG::CTTWBCRC Index',
         'BBGTKR::BLOOMBERG::CTTWBCZK Index',
         'BBGTKR::BLOOMBERG::CTTWBDKK Index',
         'BBGTKR::BLOOMBERG::CTTWBEUR Index',
         'BBGTKR::BLOOMBERG::CTTWBGBP Index',
         'BBGTKR::BLOOMBERG::CTTWBGHS Index',
         'BBGTKR::BLOOMBERG::CTTWBGTQ Index',
         'BBGTKR::BLOOMBERG::CTTWBHKD Index',
         'BBGTKR::BLOOMBERG::CTTWBHRK Index',
         'BBGTKR::BLOOMBERG::CTTWBHUF Index',
         'BBGTKR::BLOOMBERG::CTTWBIDR Index',
         'BBGTKR::BLOOMBERG::CTTWBILS Index',
         'BBGTKR::BLOOMBERG::CTTWBINR Index',
         'BBGTKR::BLOOMBERG::CTTWBJPY Index',
         'BBGTKR::BLOOMBERG::CTTWBKES Index',
         'BBGTKR::BLOOMBERG::CTTWBKRW Index',
         'BBGTKR::BLOOMBERG::CTTWBKWD Index',
         'BBGTKR::BLOOMBERG::CTTWBMAD Index',
         'BBGTKR::BLOOMBERG::CTTWBMXN Index',
         'BBGTKR::BLOOMBERG::CTTWBMYR Index',
         'BBGTKR::BLOOMBERG::CTTWBNGN Index',
         'BBGTKR::BLOOMBERG::CTTWBNOK Index',
         'BBGTKR::BLOOMBERG::CTTWBNZD Index',
         'BBGTKR::BLOOMBERG::CTTWBOMR Index',
         'BBGTKR::BLOOMBERG::CTTWBPEN Index',
         'BBGTKR::BLOOMBERG::CTTWBPHP Index',
         'BBGTKR::BLOOMBERG::CTTWBPLN Index',
         'BBGTKR::BLOOMBERG::CTTWBQAR Index',
         'BBGTKR::BLOOMBERG::CTTWBRAE Index',
         'BBGTKR::BLOOMBERG::CTTWBRAR Index',
         'BBGTKR::BLOOMBERG::CTTWBRAU Index',
         'BBGTKR::BLOOMBERG::CTTWBRBG Index',
         'BBGTKR::BLOOMBERG::CTTWBRBH Index',
         'BBGTKR::BLOOMBERG::CTTWBRBR Index',
         'BBGTKR::BLOOMBERG::CTTWBRCA Index',
         'BBGTKR::BLOOMBERG::CTTWBRCH Index',
         'BBGTKR::BLOOMBERG::CTTWBRCL Index',
         'BBGTKR::BLOOMBERG::CTTWBRCN Index',
         'BBGTKR::BLOOMBERG::CTTWBRCO Index',
         'BBGTKR::BLOOMBERG::CTTWBRCR Index',
         'BBGTKR::BLOOMBERG::CTTWBRCZ Index',
         'BBGTKR::BLOOMBERG::CTTWBRDK Index',
         'BBGTKR::BLOOMBERG::CTTWBREU Index',
         'BBGTKR::BLOOMBERG::CTTWBRGB Index',
         'BBGTKR::BLOOMBERG::CTTWBRGH Index',
         'BBGTKR::BLOOMBERG::CTTWBRGT Index',
         'BBGTKR::BLOOMBERG::CTTWBRHK Index',
         'BBGTKR::BLOOMBERG::CTTWBRHR Index',
         'BBGTKR::BLOOMBERG::CTTWBRHU Index',
         'BBGTKR::BLOOMBERG::CTTWBRID Index',
         'BBGTKR::BLOOMBERG::CTTWBRIL Index',
         'BBGTKR::BLOOMBERG::CTTWBRIN Index',
         'BBGTKR::BLOOMBERG::CTTWBRJP Index',
         'BBGTKR::BLOOMBERG::CTTWBRKE Index',
         'BBGTKR::BLOOMBERG::CTTWBRKR Index',
         'BBGTKR::BLOOMBERG::CTTWBRKW Index',
         'BBGTKR::BLOOMBERG::CTTWBRMA Index',
         'BBGTKR::BLOOMBERG::CTTWBRMX Index',
         'BBGTKR::BLOOMBERG::CTTWBRMY Index',
         'BBGTKR::BLOOMBERG::CTTWBRNG Index',
         'BBGTKR::BLOOMBERG::CTTWBRNO Index',
         'BBGTKR::BLOOMBERG::CTTWBRNZ Index',
         'BBGTKR::BLOOMBERG::CTTWBROM Index',
         'BBGTKR::BLOOMBERG::CTTWBRON Index',
         'BBGTKR::BLOOMBERG::CTTWBRPE Index',
         'BBGTKR::BLOOMBERG::CTTWBRPH Index',
         'BBGTKR::BLOOMBERG::CTTWBRPL Index',
         'BBGTKR::BLOOMBERG::CTTWBRQA Index',
         'BBGTKR::BLOOMBERG::CTTWBRRO Index',
         'BBGTKR::BLOOMBERG::CTTWBRRS Index',
         'BBGTKR::BLOOMBERG::CTTWBRRU Index',
         'BBGTKR::BLOOMBERG::CTTWBRSA Index',
         'BBGTKR::BLOOMBERG::CTTWBRSD Index',
         'BBGTKR::BLOOMBERG::CTTWBRSE Index',
         'BBGTKR::BLOOMBERG::CTTWBRSG Index',
         'BBGTKR::BLOOMBERG::CTTWBRTH Index',
         'BBGTKR::BLOOMBERG::CTTWBRTN Index',
         'BBGTKR::BLOOMBERG::CTTWBRTR Index',
         'BBGTKR::BLOOMBERG::CTTWBRTW Index',
         'BBGTKR::BLOOMBERG::CTTWBRUA Index',
         'BBGTKR::BLOOMBERG::CTTWBRUB Index',
         'BBGTKR::BLOOMBERG::CTTWBRUL Index',
         'BBGTKR::BLOOMBERG::CTTWBRUS Index',
         'BBGTKR::BLOOMBERG::CTTWBRUY Index',
         'BBGTKR::BLOOMBERG::CTTWBRVN Index',
         'BBGTKR::BLOOMBERG::CTTWBRZA Index',
         'BBGTKR::BLOOMBERG::CTTWBSAR Index',
         'BBGTKR::BLOOMBERG::CTTWBSEK Index',
         'BBGTKR::BLOOMBERG::CTTWBSGD Index',
         'BBGTKR::BLOOMBERG::CTTWBTHB Index',
         'BBGTKR::BLOOMBERG::CTTWBTND Index',
         'BBGTKR::BLOOMBERG::CTTWBTRY Index',
         'BBGTKR::BLOOMBERG::CTTWBTWD Index',
         'BBGTKR::BLOOMBERG::CTTWBUSD Index',
         'BBGTKR::BLOOMBERG::CTTWBUYU Index',
         'BBGTKR::BLOOMBERG::CTTWBVND Index',
         'BBGTKR::BLOOMBERG::CTTWBZAR Index',
         'BBGTKR::BLOOMBERG::CTTWNAED Index',
         'BBGTKR::BLOOMBERG::CTTWNARS Index',
         'BBGTKR::BLOOMBERG::CTTWNAUD Index',
         'BBGTKR::BLOOMBERG::CTTWNBGN Index',
         'BBGTKR::BLOOMBERG::CTTWNBHD Index',
         'BBGTKR::BLOOMBERG::CTTWNBRL Index',
         'BBGTKR::BLOOMBERG::CTTWNCAD Index',
         'BBGTKR::BLOOMBERG::CTTWNCHF Index',
         'BBGTKR::BLOOMBERG::CTTWNCLP Index',
         'BBGTKR::BLOOMBERG::CTTWNCNH Index',
         'BBGTKR::BLOOMBERG::CTTWNCOP Index',
         'BBGTKR::BLOOMBERG::CTTWNCRC Index',
         'BBGTKR::BLOOMBERG::CTTWNCZK Index',
         'BBGTKR::BLOOMBERG::CTTWNDKK Index',
         'BBGTKR::BLOOMBERG::CTTWNEUR Index',
         'BBGTKR::BLOOMBERG::CTTWNGBP Index',
         'BBGTKR::BLOOMBERG::CTTWNGHS Index',
         'BBGTKR::BLOOMBERG::CTTWNGTQ Index',
         'BBGTKR::BLOOMBERG::CTTWNHKD Index',
         'BBGTKR::BLOOMBERG::CTTWNHRK Index',
         'BBGTKR::BLOOMBERG::CTTWNHUF Index',
         'BBGTKR::BLOOMBERG::CTTWNIDR Index',
         'BBGTKR::BLOOMBERG::CTTWNILS Index',
         'BBGTKR::BLOOMBERG::CTTWNINR Index',
         'BBGTKR::BLOOMBERG::CTTWNJPY Index',
         'BBGTKR::BLOOMBERG::CTTWNKES Index',
         'BBGTKR::BLOOMBERG::CTTWNKRW Index',
         'BBGTKR::BLOOMBERG::CTTWNKWD Index',
         'BBGTKR::BLOOMBERG::CTTWNMAD Index',
         'BBGTKR::BLOOMBERG::CTTWNMXN Index',
         'BBGTKR::BLOOMBERG::CTTWNMYR Index',
         'BBGTKR::BLOOMBERG::CTTWNNGN Index',
         'BBGTKR::BLOOMBERG::CTTWNNOK Index',
         'BBGTKR::BLOOMBERG::CTTWNNZD Index',
         'BBGTKR::BLOOMBERG::CTTWNOMR Index',
         'BBGTKR::BLOOMBERG::CTTWNPEN Index',
         'BBGTKR::BLOOMBERG::CTTWNPHP Index',
         'BBGTKR::BLOOMBERG::CTTWNPLN Index',
         'BBGTKR::BLOOMBERG::CTTWNQAR Index',
         'BBGTKR::BLOOMBERG::CTTWNRAE Index',
         'BBGTKR::BLOOMBERG::CTTWNRAR Index',
         'BBGTKR::BLOOMBERG::CTTWNRAU Index',
         'BBGTKR::BLOOMBERG::CTTWNRBG Index',
         'BBGTKR::BLOOMBERG::CTTWNRBH Index',
         'BBGTKR::BLOOMBERG::CTTWNRBR Index',
         'BBGTKR::BLOOMBERG::CTTWNRCA Index',
         'BBGTKR::BLOOMBERG::CTTWNRCH Index',
         'BBGTKR::BLOOMBERG::CTTWNRCL Index',
         'BBGTKR::BLOOMBERG::CTTWNRCN Index',
         'BBGTKR::BLOOMBERG::CTTWNRCO Index',
         'BBGTKR::BLOOMBERG::CTTWNRCR Index',
         'BBGTKR::BLOOMBERG::CTTWNRCZ Index',
         'BBGTKR::BLOOMBERG::CTTWNRDK Index',
         'BBGTKR::BLOOMBERG::CTTWNREU Index',
         'BBGTKR::BLOOMBERG::CTTWNRGB Index',
         'BBGTKR::BLOOMBERG::CTTWNRGH Index',
         'BBGTKR::BLOOMBERG::CTTWNRGT Index',
         'BBGTKR::BLOOMBERG::CTTWNRHK Index',
         'BBGTKR::BLOOMBERG::CTTWNRHR Index',
         'BBGTKR::BLOOMBERG::CTTWNRHU Index',
         'BBGTKR::BLOOMBERG::CTTWNRID Index',
         'BBGTKR::BLOOMBERG::CTTWNRIL Index',
         'BBGTKR::BLOOMBERG::CTTWNRIN Index',
         'BBGTKR::BLOOMBERG::CTTWNRJP Index',
         'BBGTKR::BLOOMBERG::CTTWNRKE Index',
         'BBGTKR::BLOOMBERG::CTTWNRKR Index',
         'BBGTKR::BLOOMBERG::CTTWNRKW Index',
         'BBGTKR::BLOOMBERG::CTTWNRMA Index',
         'BBGTKR::BLOOMBERG::CTTWNRMX Index',
         'BBGTKR::BLOOMBERG::CTTWNRMY Index',
         'BBGTKR::BLOOMBERG::CTTWNRNG Index',
         'BBGTKR::BLOOMBERG::CTTWNRNO Index',
         'BBGTKR::BLOOMBERG::CTTWNRNZ Index',
         'BBGTKR::BLOOMBERG::CTTWNROM Index',
         'BBGTKR::BLOOMBERG::CTTWNRON Index',
         'BBGTKR::BLOOMBERG::CTTWNRPE Index',
         'BBGTKR::BLOOMBERG::CTTWNRPH Index',
         'BBGTKR::BLOOMBERG::CTTWNRPL Index',
         'BBGTKR::BLOOMBERG::CTTWNRQA Index',
         'BBGTKR::BLOOMBERG::CTTWNRRO Index',
         'BBGTKR::BLOOMBERG::CTTWNRRS Index',
         'BBGTKR::BLOOMBERG::CTTWNRRU Index',
         'BBGTKR::BLOOMBERG::CTTWNRSA Index',
         'BBGTKR::BLOOMBERG::CTTWNRSD Index',
         'BBGTKR::BLOOMBERG::CTTWNRSE Index',
         'BBGTKR::BLOOMBERG::CTTWNRSG Index',
         'BBGTKR::BLOOMBERG::CTTWNRTH Index',
         'BBGTKR::BLOOMBERG::CTTWNRTN Index',
         'BBGTKR::BLOOMBERG::CTTWNRTR Index',
         'BBGTKR::BLOOMBERG::CTTWNRTW Index',
         'BBGTKR::BLOOMBERG::CTTWNRUB Index',
         'BBGTKR::BLOOMBERG::CTTWNRUS Index',
         'BBGTKR::BLOOMBERG::CTTWNRUY Index',
         'BBGTKR::BLOOMBERG::CTTWNRVN Index',
         'BBGTKR::BLOOMBERG::CTTWNRZA Index',
         'BBGTKR::BLOOMBERG::CTTWNSAR Index',
         'BBGTKR::BLOOMBERG::CTTWNSEK Index',
         'BBGTKR::BLOOMBERG::CTTWNTHB Index',
         'BBGTKR::BLOOMBERG::CTTWNTND Index',
         'BBGTKR::BLOOMBERG::CTTWNTRY Index',
         'BBGTKR::BLOOMBERG::CTTWNTWD Index',
         'BBGTKR::BLOOMBERG::CTTWNUSD Index',
         'BBGTKR::BLOOMBERG::CTTWNUYU Index',
         'BBGTKR::BLOOMBERG::CTTWNVND Index',
         'BBGTKR::BLOOMBERG::CTTWNZAR Index']
            
fx_r =reader.get_daily_ticks(symbols=symbols,
                        start='2019-12-31',
                        end=end,
                        fields='PX_LAST',
                        )
fx_r.head()
fx_r=fx_r.fillna(method='bfill')
fx_r.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\citi_reer.csv', index = True, header=True)

# %%
            
            
            
            MXWD Index
MXWD Index


EURUSD
GBPUSD
EURNOK
EURSEK
AUDUSD
NZDUSD
USDCAD
USDJPY
EURCHF




#Interest rate differential	2Y rate	
#Relative yield curve steepness	10Y rate	10Y - 3m spread

price
GTDEM10Y Govt
GTDEM2Y Govt
GTDEM3M Govt

GUKG10 index
GUKG2 index
GUKG3m index




opx last? yield
px_last

GTJPY10Y GOVT
GTJPY2Y govt
GTJPY3M GOVT
#nok

GUKG10 index
GUKG2 index
GUKG3m index

GTNOK10Y Govt
GTNOK2Y Govt
GTNOK3M Govt

##
USGG10YR INDEX
USGG2YR INDEX
USGG3M INDEX

###
GTSEK3M Govt


GTNZD3m Govt

###
##AUD

AUD	GTAUD10Y GOVT	yld_cnv_last
AUD	gtaud2y govt	yld_cnv_last
AUD	GTAUD3M GOVT	yld_cnv_last


##CHF
CHF	GTCHF10Y Govt	yld_cnv_last
CHF	GTCHF2Y Govt	yld_cnv_last
CHF	GTCHF3M Govt	yld_cnv_last

GTCHF10Y Govt
GTCHF2Y Govt
GTCHF3M Govt

yld_cnv_last


print("Compelte")

#g10 fx


usdeur curncy
usdgbp curncy
usdjpy curncy
usdaud curncy
usdnzd curncy
usdcad curncy
usdchf curncy
usdnok curncy
usdsek curncy
eurgbp curncy
eurjpy curncy
euraud curncy
eurnzd curncy
eurcad curncy
eurchf curncy
eurnok curncy
eursek curncy
gbpjpy curncy
gbpaud curncy
gbpnzd curncy
gbpcad curncy
gbpchf curncy
gbpnok curncy
gbpsek curncy
jpyaud curncy
jpynzd curncy
jpycad curncy
jpychf curncy
jpynok curncy
jpysek curncy
audnzd curncy
audcad curncy
audchf curncy
audnok curncy
audsek curncy
nzdcad curncy
nzdchf curncy
nzdnok curncy
nzdsek curncy
cadchf curncy
cadnok curncy
cadsek curncy
chfnok curncy
chfsek curncy
noksek curncy

# %%
#

twoy_swap_1
ussa2 curncy
eusa2 curncy
bpsws2 curncy
jysw2 curncy
adsw2 curncy
ndsw2 curncy
cdsw2 curncy
sfsw2 curncy
nksw2 curncy



twoy_swap_2
eusa2 curncy
bpsws2 curncy
jysw2 curncy
adsw2 curncy
ndsw2 curncy
cdsw2 curncy
sfsw2 curncy
nksw2 curncy
sksw2 curncy

# %%
CAD	GCAN10YR Index	px_last
CAD	GCAN2YR Index	px_last
NOK	GNOR10YR Index	px_last
NOK	GNOR2YR index	px_last
NZD	GNZGB10 Index	px_last
NZD	GNZGB2 Index	px_last
SEK	GSGB10YR Index	px_last
SEK	GSGB2YR Index	px_last

# %%
CAD	gtcad3m govt	yld_cnv_last

EUR	GTDEM10Y Govt	yld_cnv_last
EUR	GTDEM2Y Govt	yld_cnv_last
EUR	GTDEM3M Govt	yld_cnv_last
JPY	GTJPY10Y GOVT	yld_cnv_last
JPY	GTJPY2Y govt	yld_cnv_last
JPY	GTJPY3M GOVT	yld_cnv_last
NOK	GTNOK3M Govt	yld_cnv_last
NZD	GTNZD3m Govt	yld_cnv_last
SEK	GTSEK3M Govt	yld_cnv_last

# %%
GBP	GUKG10 index	px_last
GBP	GUKG2 index	px_last
GBP	GUKG3m index	px_last

USD	USGG10YR INDEX	px_last
USD	USGG2YR INDEX	px_last
USD	USGG3M INDEX	px_last

# %%
#n/a	CL1 Comdty	px_last
#n/a	BCOM Index	px_last
#n/a	MXWD Index	px_last
