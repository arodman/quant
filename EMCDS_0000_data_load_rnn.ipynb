# %%
#K:\2020_2431\cds\rnn
    
#rnn_data
# unique_varaibles

# %%
import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from alphasuite.providers import MarketDataProvider
from alphasuite.market import market_data_upload

import pandas as pd

import pandas
from datetime import datetime
from mdng_client import OTReader
reader = OTReader(tz='America/New_York', env='PROD')

# %%
   
 #parameters

start = '2009-12-31'
end = datetime.today().strftime('%Y-%m-%d')


import pandas as pd 
time = pd.date_range(start=start, end=end, freq='7d')
print(time)
#np.array(times)
#>>> from datetime import datetime as date
#>>> date.today().strftime("%A")
#'Monday'

#time = DataFrame(times,columns=['date'])
#print(time)
# Out:
# DatetimeIndex(['2009-12-31', '2010-01-07', '2010-01-14', '2010-01-21',
#                '2010-01-28', '2010-02-04', '2010-02-11', '2010-02-18',
#                '2010-02-25', '2010-03-04',
#                ...
#                '2021-06-03', '2021-06-10', '2021-06-17', '2021-06-24',
#                '2021-07-01', '2021-07-08', '2021-07-15', '2021-07-22',
#                '2021-07-29', '2021-08-05'],
#               dtype='datetime64[ns]', length=606, freq='7D')

# %%
#First only extract weekly CDS adn save it
      
#EXTRACT CDS DATA
czech_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.CZ.5Y.LAST_PRICE', start_date=start).data()
czech_cds5y.columns=['czech_cds5y']
#print(czech_cds5y)

russia_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.RU.5Y.LAST_PRICE', start_date=start).data()
russia_cds5y.columns=['russia_cds5y'] 
#print(russia_cds5y)

peru_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.PE.5Y.LAST_PRICE', start_date=start).data()
peru_cds5y.columns=['peru_cds5y'] 
#print(peru_cds5y)
#peru cds	mdp	dataquery		CDSI.PE.5Y.LAST_PRICE

china_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.CN.5Y.LAST_PRICE', start_date=start).data()
china_cds5y.columns=['china_cds5y'] 
#print(china_cds5y)
#China cds	mdp	dataquery		CDS.CY.5Y.LAST_PRICE
#China cds	mdp	dataquery		CDS.CY.5Y.LAST_PRICE
#china cds	mdp	dataquery		CDSI.CN.5Y.LAST_PRICE

#india_cds5y = MarketDataProvider(source='MARKIT', tickers='CDSI.IN.5Y.LAST_PRICE', start_date=start).data()
#print(india_cds5y)
#india cds	mdp	dataquery		CDS.IN.5Y.LAST_PRICE
#china_cds5y.columns=['china_cds5y'] 

brazil_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.BR.5Y.LAST_PRICE', start_date=start).data()
brazil_cds5y.columns=['brazil_cds5y'] 
#print(brazil_cds5y)
#BRAZIL cds	mdp	dataquery		CDSI.BR.5Y.LAST_PRICE

chile_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.CL.5Y.LAST_PRICE', start_date=start).data()
chile_cds5y.columns=['chile_cds5y'] 
#print(chile_cds5y)
#chile cds	mdp	dataquery		CDSI.CL.5Y.LAST_PRICE

colombia_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.CO.5Y.LAST_PRICE', start_date=start).data()
colombia_cds5y.columns=['colombia_cds5y'] 
#print(colombia_cds5y)
#colombia cds	mdp	dataquery		CDSI.CO.5Y.LAST_PRICE

hungary_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.HU.5Y.LAST_PRICE', start_date=start).data()
hungary_cds5y.columns=['hungary_cds5y'] 
#print(hungary_cds5y)
#hungary cds	mdp	dataquery		CDSI.HU.5Y.LAST_PRICE

israel_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.IL.5Y.LAST_PRICE', start_date=start).data()
israel_cds5y.columns=['israel_cds5y'] 
#print(israel_cds5y)
#israel cds	mdp	dataquery		CDSI.IL.5Y.LAST_PRICE

southafrica_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.ZA.5Y.LAST_PRICE', start_date=start).data()
southafrica_cds5y.columns=['southafrica_cds5y'] 
#print(southafrica_cds5y)
#south africa cds	mdp	dataquery		CDSI.ZA.5Y.LAST_PRICE

mexico_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.MX.5Y.LAST_PRICE', start_date=start).data()
mexico_cds5y.columns=['mexico_cds5y'] 
#print(mexico_cds5y)
#mexico cds	mdp	dataquery		CDSI.MX.5Y.LAST_PRICE

korea_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.KR.5Y.LAST_PRICE', start_date=start).data()
korea_cds5y.columns=['korea_cds5y']
#print(korea_cds5y)
#korea cds	mdp	dataquery		CDSI.KR.5Y.LAST_PRICE

malaysia_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.MY.5Y.LAST_PRICE', start_date=start).data()
malaysia_cds5y.columns=['malaysia_cds5y']
#print(malaysia_cds5y)
#malaysia cds	mdp	dataquery		CDSI.MY.5Y.LAST_PRICE

poland_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.PL.5Y.LAST_PRICE', start_date=start).data()
poland_cds5y.columns=['poland_cds5y']
#print(poland_cds5y)
#polan cds	mdp	dataquery		CDSI.PL.5Y.LAST_PRICE

turkey_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.TR.5Y.LAST_PRICE', start_date=start).data()
turkey_cds5y.columns=['turkey_cds5y']
#print(turkey_cds5y)
#turkey cds	mdp	dataquery		CDSI.TR.5Y.LAST_PRICE

indonesia_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.ID.5Y.LAST_PRICE', start_date=start).data()
indonesia_cds5y.columns=['indonesia_cds5y']
#print(indonesia_cds5y)
#indonesia cds	mdp	dataquery		CDSI.ID.5Y.LAST_PRICE

thailand_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.TH.5Y.LAST_PRICE', start_date=start).data()
thailand_cds5y.columns=['thailand_cds5y']
#print(thailand_cds5y)
#indonesia cds	mdp	dataquery		CDSI.ID.5Y.LAST_PRICE

philippines_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.PH.5Y.LAST_PRICE', start_date=start).data()
philippines_cds5y.columns=['philippines_cds5y']
#print(philippines_cds5y)

argentina_cds5y = MarketDataProvider(source='dataquery', tickers='CDSI.AR.5Y.LAST_PRICE', start_date=start).data()
argentina_cds5y.columns=['argentina_cds5y']
#print(argentina_cds5y)
#argentina cds	mdp	dataquery		CDSI.AR.5Y.LAST_PRICE

####add taiwan


cds_db = pd.concat([philippines_cds5y,
                     czech_cds5y,
                     thailand_cds5y,
                     turkey_cds5y,
                     indonesia_cds5y,
                     poland_cds5y,
                     malaysia_cds5y,
                     korea_cds5y,
                     mexico_cds5y,
                     southafrica_cds5y,
                     israel_cds5y,
                     hungary_cds5y,
                     colombia_cds5y,
                     chile_cds5y,
                     brazil_cds5y,
                     china_cds5y,
                     russia_cds5y,
                     peru_cds5y], axis=1).fillna(method="ffill").dropna() 


cds_db.head()
#cds_db['date'] = cds_db.index
#print(cds_db)
cds_db.to_csv (r'K:\2020_2431\q\sandbox\rnn_cds.csv', index = True, header=True)
#cds_rs=cds_rs
#print(cds_rs)

# %%
symbols = ['BBGTKR::BLOOMBERG::BRL CURNCY','BBGTKR::BLOOMBERG::CLP CURNCY',
          'BBGTKR::BLOOMBERG::CNH CURNCY','BBGTKR::BLOOMBERG::COP CURNCY',
          'BBGTKR::BLOOMBERG::CZK CURNCY','BBGTKR::BLOOMBERG::IDR CURNCY',
          'BBGTKR::BLOOMBERG::ILS CURNCY','BBGTKR::BLOOMBERG::INR CURNCY',
          'BBGTKR::BLOOMBERG::KRW CURNCY','BBGTKR::BLOOMBERG::MXN CURNCY',
          'BBGTKR::BLOOMBERG::PEN CURNCY','BBGTKR::BLOOMBERG::PLN CURNCY',
          'BBGTKR::BLOOMBERG::RUB CURNCY','BBGTKR::BLOOMBERG::HUF CURNCY',
          'BBGTKR::BLOOMBERG::ZAR CURNCY','BBGTKR::BLOOMBERG::THB CURNCY',
          'BBGTKR::BLOOMBERG::TWD CURNCY','BBGTKR::BLOOMBERG::MYR CURNCY',
          'BBGTKR::BLOOMBERG::PHP CURNCY','BBGTKR::BLOOMBERG::TRY CURNCY']


# # notice here we are retrieving data from dataquery and bloomberg using the bloomberg ticker

fx =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
fx.head()
fx=fx.fillna(method='bfill')
fx.to_csv (r'K:\2020_2431\q\sandbox\rnn_fx_tmp.csv', index = True, header=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-11fc9e30d048> in <module>
#      16                         start=start,
#      17                         end=end,
# ---> 18                         fields='PRICE',
#      19                         )
#      20 fx.head()
#
# C:\Anaconda\lib\site-packages\mdng_client\utils\validation.py in wrapped(cls, *args, **kwargs)
#      23         if args:
#      24             raise ValueError(f"All arguments for {func.__name__} must be passed as keyword args")
# ---> 25         return func(cls, **kwargs)
#      26
#      27     return wrapped
#
# C:\Anaconda\lib\site-packages\mdng_client\utils\validation.py in wrapped(cls, **kwargs)
#      57         kwargs['end'] = parse_date(kwargs['end'], 'end')
#      58
# ---> 59         return func(cls, **kwargs)
#      60
#      61     return wrapped
#
# ...

# %%
#Equities MSCI INDEX EXTRACT daily
symbols = ['BBGTKR::BLOOMBERG::MXBR Index','BBGTKR::BLOOMBERG::MXCL Index',
          'BBGTKR::BLOOMBERG::MXCN Index','BBGTKR::BLOOMBERG::MXCO Index',
          'BBGTKR::BLOOMBERG::MXCZ Index','BBGTKR::BLOOMBERG::MXHU Index',
          'BBGTKR::BLOOMBERG::MXIL Index','BBGTKR::BLOOMBERG::MXIN Index',
          'BBGTKR::BLOOMBERG::MXKR Index','BBGTKR::BLOOMBERG::MXMX Index',
          'BBGTKR::BLOOMBERG::MXPE Index','BBGTKR::BLOOMBERG::MXPL Index',
          'BBGTKR::BLOOMBERG::MXRU Index','BBGTKR::BLOOMBERG::MXTR Index',
          'BBGTKR::BLOOMBERG::MXZA Index','BBGTKR::BLOOMBERG::MXTH Index',
          'BBGTKR::BLOOMBERG::TAMSCI Index','BBGTKR::BLOOMBERG::MXMY Index',
          'BBGTKR::BLOOMBERG::PHP CURNCY','BBGTKR::BLOOMBERG::MXID Index']

# notice here we are retrieving data from dataquery and bloomberg using the bloomberg ticker

l_msci =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
l_msci.head()
l_msci=l_msci.fillna(method='bfill')
l_msci.to_csv (r'K:\2020_2431\q\sandbox\rnn_l_msci_tmp.csv', index = True, header=True)

# %%
#Equities MSCI INDEX EXTRACT daily
symbols = ['BBGTKR::BLOOMBERG::MXBR Index','BBGTKR::BLOOMBERG::MXCL Index',
          'BBGTKR::BLOOMBERG::MXCN Index','BBGTKR::BLOOMBERG::MXCO Index',
          'BBGTKR::BLOOMBERG::MXCZ Index','BBGTKR::BLOOMBERG::MXHU Index',
          'BBGTKR::BLOOMBERG::MXIL Index','BBGTKR::BLOOMBERG::MXIN Index',
          'BBGTKR::BLOOMBERG::MXKR Index','BBGTKR::BLOOMBERG::MXMX Index',
          'BBGTKR::BLOOMBERG::MXPE Index','BBGTKR::BLOOMBERG::MXPL Index',
          'BBGTKR::BLOOMBERG::MXRU Index','BBGTKR::BLOOMBERG::MXTR Index',
          'BBGTKR::BLOOMBERG::MXZA Index','BBGTKR::BLOOMBERG::MXTH Index',
          'BBGTKR::BLOOMBERG::TAMSCI Index','BBGTKR::BLOOMBERG::MXMY Index',
          'BBGTKR::BLOOMBERG::PHP CURNCY','BBGTKR::BLOOMBERG::MXID Index']

# # notice here we are retrieving data from dataquery and bloomberg using the bloomberg ticker

l_msci_v =reader.get_daily_ticks(symbols=symbols,
                        start=start,
                        end=end,
                        fields='VOLUME',
                        )
l_msci_v.head()
l_msci_v=l_msci_v.fillna(method='bfill')
l_msci_v.to_csv (r'K:\2020_2431\q\sandbox\rnn_l_msci_volume_tmp.csv', index = True, header=True)

# %%
#Vix
vix =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::VIX INDEX'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
vix.head()
vix=vix.fillna(method='bfill')
vix.to_csv (r'K:\2020_2431\q\sandbox\rnn_vix_tmp.csv', index = True, header=True)

# %%
#s&p retunr
     ##   is stock sp500 weekly retunr#SP500 Weekly Returns	Global
msci_us =reader.get_daily_ticks(symbols=['BBGTKR::BLOOMBERG::MXUS INDEX'],
                        start=start,
                        end=end,
                        fields='PRICE',
                        )
msci_us.head()
msci_us=msci_us.fillna(method='bfill')
msci_us=pd.merge(time, msci_us,  how='left', left_on=['date'], right_on = ['TIME']).fillna(method='bfill')
msci_us.to_csv (r'K:\2020_2431\q\sandbox\msci_us_tmp.csv', index = False, header=True)
