# %%
#REGIME SWITCHING PRIOCESS

# %%
#improt packages

import datetime as dt
from datetime import datetime
import matplotlib
matplotlib.use('Agg')
import pandas as pd
from pandas import DataFrame
from statsmodels.regression.rolling import RollingOLS
import matplotlib.pyplot as plt
import numpy as np # numerical python
import pandas as pd # pannel datasets
import matplotlib.pyplot as plt 
import seaborn as sns
from datetime import date

#stacked
import tkinter
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('TkAgg')
import pandas as pd

import pandas as pd 
import os

import PIL
from PIL import Image
#import os
from PyPDF2 import PdfFileMerger
from PyPDF2 import PdfFileMerger



######
####related to regim swithc plot 

import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import requests
from io import BytesIO

# NBER recessions
#from pandas_datareader.data import DataReader
from datetime import datetime

import matplotlib.pyplot as plt
import matplotlib.ticker as plticke
#print(df_rs)
import statsmodels.formula.api as smf
#import imgkit
#import wkhtmltopdf

import dataframe_image as dfi



import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt

import matplotlib.ticker as ticker
import matplotlib.ticker as plticker

from codetiming import Timer
timeclock = Timer(name="class")
timeclock.start()

# %%
#parameters

start = '2009-12-31'
end = datetime.today().strftime('%Y-%m-%d')



time = pd.date_range(start=start, end=end, freq='7d')
print(time)
#np.array(times)
#>>> from datetime import datetime as date
#>>> date.today().strftime("%A")
#'Monday'

time = DataFrame(time,columns=['date'])
print(time)
# Out:
# DatetimeIndex(['2009-12-31', '2010-01-07', '2010-01-14', '2010-01-21',
#                '2010-01-28', '2010-02-04', '2010-02-11', '2010-02-18',
#                '2010-02-25', '2010-03-04',
#                ...
#                '2021-09-16', '2021-09-23', '2021-09-30', '2021-10-07',
#                '2021-10-14', '2021-10-21', '2021-10-28', '2021-11-04',
#                '2021-11-11', '2021-11-18'],
#               dtype='datetime64[ns]', length=621, freq='7D')
#           date
# 0   2009-12-31
# 1   2010-01-07
# 2   2010-01-14
# 3   2010-01-21
# 4   2010-01-28
# ..         ...
# 616 2021-10-21
# 617 2021-10-28
# 618 2021-11-04
# 619 2021-11-11
# 620 2021-11-18
#
# [621 rows x 1 columns]

# %%
#read csv

fx_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\fx_tmp.csv')
l_msci_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\l_msci_tmp.csv')
msci_us_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\msci_us_tmp.csv')
ust_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\ust_tmp.csv')
us_y_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\us_y_tmp.csv')
y_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\y_tmp.csv')
oil_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\oil_tmp.csv')


#VARAIBLES
#oil LOG(CL1 ) oil
#World Equities: log (msci mxaw)
#Relative equities:   log msci country 1 - log msci country 2
#Rates difference: log 2y rate country 1 - log 2y rate country 2
#Relative Yield curve: (3m-10y of country 1) - (3m-10y of country 2)

# %% [markdown]
# # pREPARIGN DATA

# %%
#load data base and then create weekly variatons
#fx
fx_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\fx_tmp.csv')
fx_tmp.rename(columns={'TIME':'date'}, inplace=True)
fx_tmp=fx_tmp.fillna(method='bfill')
fx_tmp=fx_tmp.fillna(method='ffill')

###rename
fx_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::EURUSD CURNCY':'fx_EURUSD'}, inplace=True)
fx_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::GBPUSD CURNCY':'fx_GBPUSD'}, inplace=True)
fx_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::EURNOK CURNCY':'fx_EURNOK'}, inplace=True)
fx_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::AUDUSD CURNCY':'fx_AUDUSD'}, inplace=True)
fx_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::NZDUSD CURNCY':'fx_NZDUSD'}, inplace=True)
fx_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::USDCAD CURNCY':'fx_USDCAD'}, inplace=True)
fx_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::USDJPY CURNCY':'fx_USDJPY'}, inplace=True)
fx_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::EURCHF CURNCY':'fx_EURCHF'}, inplace=True)
print(fx_tmp)

#dv#,log'logdv
list_x0=['EURUSD','GBPUSD','EURNOK','AUDUSD','NZDUSD','USDCAD','USDJPY','EURCHF']
loop_list=list_x0
for x in range(len(loop_list)): 
    print(x)
    variable=str(loop_list[x])
    variable="fx_"+str(variable)
    print(variable)
    fx_tmp[str(variable)]=pd.to_numeric(fx_tmp[str(variable)])
    fx_tmp[str("dv_"+variable)]= ((fx_tmp[str(variable)].diff()) /(fx_tmp[str(variable)].shift(1))).round(6)
    fx_tmp[str("wv_"+variable)]= ((fx_tmp[str(variable)].diff()) /(fx_tmp[str(variable)].shift(5))).round(6)
    fx_tmp[str("log_"+variable)] = np.log(fx_tmp[str(variable)])
    fx_tmp[str("log_dv_"+variable)] = np.log(fx_tmp[str(variable)]) - np.log(fx_tmp[str(variable)].shift(1))
    fx_tmp[str("log_wv_"+variable)] = np.log(fx_tmp[str(variable)]) - np.log(fx_tmp[str(variable)].shift(5))

print(fx_tmp)

#brazil_cds5y#
#cds_rs['wv_br#azil_cds5y']= ((cds_rs.brazil_cds5y.diff()) /(cds_rs.brazil_cds5y.shift())).round(6)
#cds_rs['wd_brazil_cds5y']= ((cds_rs.brazil_cds5y.diff())).round(6)
#Relative equities:   log msci country 1 - log msci country 2
# Out:
#             date  fx_AUDUSD  fx_EURCHF  fx_EURNOK  fx_EURUSD  fx_GBPUSD  \
# 0     2010-01-01     0.8980    1.48365     8.2811     1.4324     1.6151
# 1     2010-01-04     0.9126    1.48440     8.2317     1.4413     1.6085
# 2     2010-01-05     0.9119    1.48485     8.2128     1.4365     1.5992
# 3     2010-01-06     0.9198    1.48064     8.1621     1.4408     1.6019
# 4     2010-01-07     0.9174    1.47971     8.1749     1.4308     1.5933
# ...          ...        ...        ...        ...        ...        ...
# 3099  2021-11-17     0.7267    1.05076     9.9023     1.1319     1.3487
# 3100  2021-11-18     0.7277    1.05266    10.0223     1.1371     1.3494
# 3101  2021-11-19     0.7235    1.04786    10.0683     1.1290     1.3451
# 3102  2021-11-22     0.7225    1.04830    10.0319     1.1237     1.3397
# 3103  2021-11-23     0.7228    1.04983    10.0091     1.1248     1.3378
#
#       fx_NZDUSD  fx_USDCAD  fx_USDJPY
# 0        0.7231     1.0528      93.04
# ...

# %%
#print(cds_rs.columns)
#print(cds_rs)

#fx_tmp.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\fx_g10_rs_0.csv', index = False, header=True)

# %%
#y
y_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\y_tmp.csv')
y_tmp.rename(columns={'TIME':'date'}, inplace=True)
y_tmp=y_tmp.fillna(method='bfill')
y_tmp=y_tmp.fillna(method='ffill')

#CHF
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTCHF10Y GOVT':'y_10Y_CHF'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTCHF2Y GOVT':'y_2Y_CHF'}, inplace=True)
#y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTCHF3M GOVT':'y_3M_CHF'}, inplace=True)
y_tmp["y_3M_CHF"] = y_tmp["y_2Y_CHF"]

#JPY
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTJPY10Y GOVT':'y_10Y_JPY'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTJPY2Y GOVT':'y_2Y_JPY'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTJPY3M GOVT':'y_3M_JPY'}, inplace=True)
#EUR
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTDEM10Y GOVT':'y_10Y_EUR'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTDEM2Y GOVT':'y_2Y_EUR'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTDEM3M GOVT':'y_3M_EUR'}, inplace=True)
#GBP
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GUKG10 INDEX':'y_10Y_GBP'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GUKG2 INDEX':'y_2Y_GBP'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GUKG3M INDEX':'y_3M_GBP'}, inplace=True)
#NOK
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTNOK10Y GOVT':'y_10Y_NOK_no'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTNOK2Y GOVT':'y_2Y_NOK_no'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GNOR10YR INDEX':'y_10Y_NOK'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GNOR2YR INDEX':'y_2Y_NOK'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTNOK3M GOVT':'y_3M_NOK'}, inplace=True)
#AID
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTAUD10Y GOVT':'y_10Y_AUD'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTAUD2Y GOVT':'y_2Y_AUD'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTAUD3M GOVT':'y_3M_AUD'}, inplace=True)
#SEK
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GSGB10YR INDEX':'y_10Y_SEK_no'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GSGB2YR INDEX':'y_2Y_SEK_no'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTSEK10Y GOVT':'y_10Y_SEK'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTSEK2Y GOVT':'y_2Y_SEK'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTSEK3M GOVT':'y_3M_SEK'}, inplace=True)
#USD
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::USGG10YR INDEX':'y_10Y_USD'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::USGG2YR INDEX':'y_2Y_USD'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::USGG3M INDEX':'y_3M_USD'}, inplace=True)
#CAD
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GCAN10YR INDEX':'y_10Y_CAD_no'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GCAN2YR INDEX':'y_2Y_CAD_no'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTCAD10Y GOVT':'y_10Y_CAD'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTCAD2Y GOVT':'y_2Y_CAD'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTCAD3M GOVT':'y_3M_CAD'}, inplace=True)
#NZD
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GNZGB10 INDEX':'y_10Y_NZD_no'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GNZGB2 INDEX':'y_2Y_NZD_no'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTNZD10Y GOVT':'y_10Y_NZD'}, inplace=True)
y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTNZD2Y GOVT':'y_2Y_NZD'}, inplace=True)

y_tmp.rename(columns={'BBGTKR::BLOOMBERG::GTNZD3M GOVT':'y_3M_NZD'}, inplace=True)







#y_tmp[str("log_"+variable_slope)] = np.log(y_tmp[str(variable_slope)])

###EUR,chf
list_x1=["EUR","USD","GBP","NOK","AUD","NZD","CAD","JPY","SEK","CHF"]
loop_list=list_x1
for x in range(len(loop_list)): 
    print(x)
    variable=str(loop_list[x])
    variable_10Y="y_10Y_"+str(variable)
    variable_2Y="y_2Y_"+str(variable)
    variable_1Y="y_1Y_"+str(variable)
    variable_3M="y_3M_"+str(variable)
    print(variable)
    y_tmp[str(variable_10Y)]=pd.to_numeric(y_tmp[str(variable_10Y)])
    y_tmp[str(variable_2Y)]=pd.to_numeric(y_tmp[str(variable_2Y)])
    y_tmp[str(variable_3M)]=pd.to_numeric(y_tmp[str(variable_3M)])
    variable_slope_3M="y_slope_3M_"+str(variable)
    y_tmp[str(variable_slope_3M)]=(y_tmp[str(variable_3M)])-(y_tmp[str(variable_10Y)])
    
    #variable_slope_1Y="y_slope_1Y_"+str(variable)
    #y_tmp[str(variable_slope_1Y)]=(y_tmp[str(variable_1Y)])-(y_tmp[str(variable_10Y)])
    
    
    y_tmp[str("log_"+variable_10Y)] = np.log(y_tmp[str(variable_10Y)])
    y_tmp[str("log_dv_"+variable_10Y)] = np.log(y_tmp[str(variable_10Y)]) - np.log(y_tmp[str(variable_10Y)].shift(1))
    y_tmp[str("log_wv_"+variable_10Y)] = np.log(y_tmp[str(variable_10Y)]) - np.log(y_tmp[str(variable_10Y)].shift(5))
    y_tmp[str("log_"+variable_2Y)] = np.log(y_tmp[str(variable_2Y)])
    y_tmp[str("log_dv_"+variable_2Y)] = np.log(y_tmp[str(variable_2Y)]) - np.log(y_tmp[str(variable_2Y)].shift(1))
    y_tmp[str("log_wv_"+variable_2Y)] = np.log(y_tmp[str(variable_2Y)]) - np.log(y_tmp[str(variable_2Y)].shift(5))
    y_tmp[str("log_"+variable_3M)] = np.log(y_tmp[str(variable_3M)])
    y_tmp[str("log_dv_"+variable_3M)] = np.log(y_tmp[str(variable_3M)]) - np.log(y_tmp[str(variable_3M)].shift(1))
    y_tmp[str("log_wv_"+variable_3M)] = np.log(y_tmp[str(variable_3M)]) - np.log(y_tmp[str(variable_3M)].shift(5))
    
    
print(y_tmp)
#y_tmp.to_clipboard()
# Out:
# 0
# EUR
# 1
# USD
# 2
# GBP
# 3
# NOK
# 4
# AUD
# 5
# NZD
# 6
# CAD
# 7
# JPY
# 8
# SEK
# 9
# CHF
#             date  y_10Y_CAD_no  y_2Y_CAD_no  y_10Y_NOK  y_2Y_NOK  \
# 0     2010-01-01         3.610        1.472      4.146     2.314
# 1     2010-01-04         3.607        1.459      4.177     2.290
# 2     2010-01-05         3.565        1.390      4.147     2.306
# 3     2010-01-06         3.616        1.391      4.124     2.291
# 4     2010-01-07         3.637        1.385      4.122     2.273
# ...          ...           ...          ...        ...       ...
# 3077  2021-10-19         1.588        0.829      1.732     1.055
# 3078  2021-10-20         1.588        0.829      1.732     1.055
# 3079  2021-10-21         1.588        0.829      1.732     1.055
# 3080  2021-10-22         1.588        0.829      1.732     1.055
# 3081  2021-10-25         1.588        0.829      1.732     1.055
#
#       y_10Y_NZD_no  y_2Y_NZD_no  y_10Y_SEK_no  y_2Y_SEK_no  y_10Y_AUD  ...  \
# ...

# %%
msci_us_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\msci_us_tmp.csv')
msci_us_tmp.rename(columns={'TIME':'date'}, inplace=True)
msci_us_tmp=msci_us_tmp.fillna(method='bfill')
msci_us_tmp=msci_us_tmp.fillna(method='ffill')

msci_us_tmp.rename(columns={'BBGTKR::BLOOMBERG::MXUS INDEX':'msci_USD'}, inplace=True)


list_x0=['USD']
loop_list=list_x0
for x in range(len(loop_list)): 
    print(x)
    variable=str(loop_list[x])
    variable="msci_"+str(variable)
    print(variable)
    msci_us_tmp[str(variable)]=pd.to_numeric(msci_us_tmp[str(variable)])
    msci_us_tmp[str("dv_"+variable)]= ((msci_us_tmp[str(variable)].diff()) /(msci_us_tmp[str(variable)].shift(1))).round(6)
    msci_us_tmp[str("wv_"+variable)]= ((msci_us_tmp[str(variable)].diff()) /(msci_us_tmp[str(variable)].shift(5))).round(6)
    msci_us_tmp[str("log_"+variable)] = np.log(msci_us_tmp[str(variable)])
    msci_us_tmp[str("log_dv_"+variable)] = np.log(msci_us_tmp[str(variable)]) - np.log(msci_us_tmp[str(variable)].shift(1))
    msci_us_tmp[str("log_wv_"+variable)] = np.log(msci_us_tmp[str(variable)]) - np.log(msci_us_tmp[str(variable)].shift(5))
    
    
print(msci_us_tmp)
##calcaualte retunr



#CL1 COMDTY
#
oil_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\oil_tmp.csv')
oil_tmp.rename(columns={'TIME':'date'}, inplace=True)
oil_tmp=oil_tmp.fillna(method='bfill')
oil_tmp=oil_tmp.fillna(method='ffill')

oil_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::CL1 COMDTY':'oil'}, inplace=True)


list_x0=['oil']
loop_list=list_x0
for x in range(len(loop_list)): 
    print(x)
    variable=str(loop_list[x])
    print(variable)
    oil_tmp[str(variable)]=pd.to_numeric(oil_tmp[str(variable)])
    oil_tmp[str("dv_"+variable)]= ((oil_tmp[str(variable)].diff()) /(oil_tmp[str(variable)].shift(1))).round(6)
    oil_tmp[str("wv_"+variable)]= ((oil_tmp[str(variable)].diff()) /(oil_tmp[str(variable)].shift(5))).round(6)
    oil_tmp[str("log_"+variable)] = np.log(oil_tmp[str(variable)])
    oil_tmp[str("log_dv_"+variable)] = np.log(oil_tmp[str(variable)]) - np.log(oil_tmp[str(variable)].shift(1))
    oil_tmp[str("log_wv_"+variable)] = np.log(oil_tmp[str(variable)]) - np.log(oil_tmp[str(variable)].shift(5))

    
print(oil_tmp)
# Out:
# 0
# msci_USD
#             date  msci_USD  dv_msci_USD  wv_msci_USD  log_msci_USD  \
# 0     2010-01-04   1078.36          NaN          NaN      6.983197
# 1     2010-01-05   1081.73     0.003125          NaN      6.986317
# 2     2010-01-06   1082.67     0.000869          NaN      6.987185
# 3     2010-01-07   1086.71     0.003732          NaN      6.990910
# 4     2010-01-08   1090.03     0.003055          NaN      6.993960
# ...          ...       ...          ...          ...           ...
# 2987  2021-11-10   4510.91    -0.009297    -0.009348      8.414254
# 2988  2021-11-11   4514.21     0.000732     0.000726      8.414985
# 2989  2021-11-12   4549.32     0.007778     0.007699      8.422733
# 2990  2021-11-15   4549.22    -0.000022    -0.000022      8.422711
# 2991  2021-11-16   4568.66     0.004273     0.004269      8.426975
#
#       log_dv_msci_USD  log_wv_msci_USD
# 0                 NaN              NaN
# 1            0.003120              NaN
# ...

# %%
#msci equity indicator
l_msci_tmp= pd.read_csv (r'K:\2020_2431\q\sandbox_fx_g10\l_msci_tmp.csv')
l_msci_tmp.rename(columns={'TIME':'date'}, inplace=True)
l_msci_tmp=l_msci_tmp.fillna(method='bfill')
l_msci_tmp=l_msci_tmp.fillna(method='ffill')

#AUD	MXAU INDEX
#CAD	MXCA Index
#CHF	MXCH Index
#EUR	MXEU Index
#GBP	MXGB Index
#JPY	MXJP INDEX
#NOK	MXNO Index
#NZD	MXNZ Index
#SEK	MXSE Index
#USD	MXUS INDEX

l_msci_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::MXJP Index':'msci_JPY'}, inplace=True)
l_msci_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::MXNZ Index':'msci_NZD'}, inplace=True)
l_msci_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::MXSE Index':'msci_SEK'}, inplace=True)
l_msci_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::MXGB Index':'msci_GBP'}, inplace=True)
l_msci_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::MXCH Index':'msci_CHF'}, inplace=True)
l_msci_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::MXEU Index':'msci_EUR'}, inplace=True)
l_msci_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::MXCA Index':'msci_CAD'}, inplace=True)
l_msci_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::MXNO Index':'msci_NOK'}, inplace=True)
l_msci_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::MXAU Index':'msci_AUD'}, inplace=True)
l_msci_tmp.rename(columns={'BBGTKR::BLOOMBERG_PARENT::MXWD Index':'msci_world'}, inplace=True)


#dv#,log'logdv
list_x0=['JPY','NZD','SEK','GBP','CHF','EUR','CAD','NOK','AUD','world']
loop_list=list_x0
for x in range(len(loop_list)): 
    print(x)
    variable=str(loop_list[x])
    variable="msci_"+str(variable)
    print(variable)
    l_msci_tmp[str(variable)]=pd.to_numeric(l_msci_tmp[str(variable)])
    l_msci_tmp[str("dv_"+variable)]= ((l_msci_tmp[str(variable)].diff()) /(l_msci_tmp[str(variable)].shift(1))).round(6)
    l_msci_tmp[str("wv_"+variable)]= ((l_msci_tmp[str(variable)].diff()) /(l_msci_tmp[str(variable)].shift(5))).round(6)
    l_msci_tmp[str("log_"+variable)] = np.log(l_msci_tmp[str(variable)])
    l_msci_tmp[str("log_dv_"+variable)] = np.log(l_msci_tmp[str(variable)]) - np.log(l_msci_tmp[str(variable)].shift(1))
    l_msci_tmp[str("log_wv_"+variable)] = np.log(l_msci_tmp[str(variable)]) - np.log(l_msci_tmp[str(variable)].shift(5))

print(l_msci_tmp)
# Out:
# 0
# msci_JPY
# 1
# msci_NZD
# 2
# msci_SEK
# 3
# msci_GBP
# 4
# msci_CHF
# 5
# msci_EUR
# 6
# msci_CAD
# 7
# msci_NOK
# 8
# msci_AUD
# 9
# msci_world
#             date  msci_AUD  msci_CAD  msci_CHF  msci_EUR  msci_GBP  msci_JPY  \
# 0     2010-01-01   1001.76   1542.02    864.66     88.28   1633.94    569.35
# 1     2010-01-04   1001.76   1542.02    864.66     89.57   1633.94    574.55
# 2     2010-01-05   1011.81   1544.51    859.43     89.54   1640.86    577.00
# 3     2010-01-06   1010.77   1550.14    856.96     89.63   1642.87    584.23
# 4     2010-01-07   1006.28   1541.16    856.67     89.63   1641.88    584.36
# ...          ...       ...       ...       ...       ...       ...       ...
# 3076  2021-10-18   1435.63   2638.33   1591.21    154.68   2024.23   1239.55
# 3077  2021-10-19   1435.63   2638.33   1591.21    154.68   2024.23   1239.55
# 3078  2021-10-20   1435.63   2638.33   1591.21    154.68   2024.23   1239.55
# ...

# %%
data=pd.merge(fx_tmp, l_msci_tmp,  how='left', left_on=['date'], right_on = ['date'])
data=pd.merge(data, msci_us_tmp,  how='left', left_on=['date'], right_on = ['date'])
data=pd.merge(data, y_tmp,  how='left', left_on=['date'], right_on = ['date'])
data=pd.merge(data, oil_tmp,  how='left', left_on=['date'], right_on = ['date'])

data = data.set_index('date')
data.index = pd.to_datetime(data.index)
data.info()
data=data.fillna(method='ffill')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3104 entries, 2010-01-01 to 2021-11-23
# Columns: 259 entries, fx_AUDUSD to log_wv_oil
# dtypes: float64(259)
# memory usage: 6.2 MB

# %%
#slopes, coefficientes, spreads

list_x0=['EURUSD','GBPUSD','EURNOK','AUDUSD','NZDUSD','USDCAD','USDJPY','EURCHF']

#Relative equities:   log msci country 1 - log msci country 2
data["rel_msci_EURUSD"]=data["log_msci_EUR"]-data["log_msci_USD"]
data["rel_msci_USDEUR"]=data["log_msci_USD"]-data["log_msci_EUR"]

data["rel_msci_GBPUSD"]=data["log_msci_GBP"]-data["log_msci_USD"]
data["rel_msci_USDGBP"]=data["log_msci_USD"]-data["log_msci_GBP"]

data["rel_msci_AUDUSD"]=data["log_msci_AUD"]-data["log_msci_USD"]
data["rel_msci_USDAUD"]=data["log_msci_USD"]-data["log_msci_AUD"]

data["rel_msci_EURNOK"]=data["log_msci_EUR"]-data["log_msci_NOK"]
data["rel_msci_NOKEUR"]=data["log_msci_NOK"]-data["log_msci_EUR"]

data["rel_msci_NZDUSD"]=data["log_msci_NZD"]-data["log_msci_USD"]
data["rel_msci_USDNZD"]=data["log_msci_USD"]-data["log_msci_NZD"]

data["rel_msci_CADUSD"]=data["log_msci_CAD"]-data["log_msci_USD"]
data["rel_msci_USDCAD"]=data["log_msci_USD"]-data["log_msci_CAD"]

data["rel_msci_JPYUSD"]=data["log_msci_JPY"]-data["log_msci_USD"]
data["rel_msci_USDJPY"]=data["log_msci_USD"]-data["log_msci_JPY"]

data["rel_msci_EURCHF"]=data["log_msci_EUR"]-data["log_msci_CHF"]
data["rel_msci_CHFEUR"]=data["log_msci_CHF"]-data["log_msci_EUR"]



#Rates difference: log 2y rate country 1 - log 2y rate country 2
#log_y_2Y_SEK  
data["rel_log_y_2Y_EURUSD"]=data["log_y_2Y_EUR"]-data["log_y_2Y_USD"]
data["rel_log_y_2Y_USDEUR"]=data["log_y_2Y_USD"]-data["log_y_2Y_EUR"]

data["rel_log_y_2Y_GBPUSD"]=data["log_y_2Y_GBP"]-data["log_y_2Y_USD"]
data["rel_log_y_2Y_USDGBP"]=data["log_y_2Y_USD"]-data["log_y_2Y_GBP"]

data["rel_log_y_2Y_AUDUSD"]=data["log_y_2Y_AUD"]-data["log_y_2Y_USD"]
data["rel_log_y_2Y_USDAUD"]=data["log_y_2Y_USD"]-data["log_y_2Y_AUD"]

data["rel_log_y_2Y_EURNOK"]=data["log_y_2Y_EUR"]-data["log_y_2Y_NOK"]
data["rel_log_y_2Y_NOKEUR"]=data["log_y_2Y_NOK"]-data["log_y_2Y_EUR"]

data["rel_log_y_2Y_NZDUSD"]=data["log_y_2Y_NZD"]-data["log_y_2Y_USD"]
data["rel_log_y_2Y_USDNZD"]=data["log_y_2Y_USD"]-data["log_y_2Y_NZD"]

data["rel_log_y_2Y_CADUSD"]=data["log_y_2Y_CAD"]-data["log_y_2Y_USD"]
data["rel_log_y_2Y_USDCAD"]=data["log_y_2Y_USD"]-data["log_y_2Y_CAD"]

data["rel_log_y_2Y_JPYUSD"]=data["log_y_2Y_JPY"]-data["log_y_2Y_USD"]
data["rel_log_y_2Y_USDJPY"]=data["log_y_2Y_USD"]-data["log_y_2Y_JPY"]

data["rel_log_y_2Y_EURCHF"]=data["log_y_2Y_EUR"]-data["log_y_2Y_CHF"]
data["rel_log_y_2Y_CHFEUR"]=data["log_y_2Y_CHF"]-data["log_y_2Y_EUR"]
#####



data["rel_y_2Y_EURUSD"]=data["y_2Y_EUR"]-data["y_2Y_USD"]
data["rel_y_2Y_USDEUR"]=data["y_2Y_USD"]-data["y_2Y_EUR"]

data["rel_y_2Y_GBPUSD"]=data["y_2Y_GBP"]-data["y_2Y_USD"]
data["rel_y_2Y_USDGBP"]=data["y_2Y_USD"]-data["y_2Y_GBP"]

data["rel_y_2Y_AUDUSD"]=data["y_2Y_AUD"]-data["y_2Y_USD"]
data["rel_y_2Y_USDAUD"]=data["y_2Y_USD"]-data["y_2Y_AUD"]

data["rel_y_2Y_EURNOK"]=data["y_2Y_EUR"]-data["y_2Y_NOK"]
data["rel_y_2Y_NOKEUR"]=data["y_2Y_NOK"]-data["y_2Y_EUR"]

data["rel_y_2Y_NZDUSD"]=data["y_2Y_NZD"]-data["y_2Y_USD"]
data["rel_y_2Y_USDNZD"]=data["y_2Y_USD"]-data["y_2Y_NZD"]

data["rel_y_2Y_CADUSD"]=data["y_2Y_CAD"]-data["y_2Y_USD"]
data["rel_y_2Y_USDCAD"]=data["y_2Y_USD"]-data["y_2Y_CAD"]

data["rel_y_2Y_JPYUSD"]=data["y_2Y_JPY"]-data["y_2Y_USD"]
data["rel_y_2Y_USDJPY"]=data["y_2Y_USD"]-data["y_2Y_JPY"]

data["rel_y_2Y_EURCHF"]=data["y_2Y_EUR"]-data["y_2Y_CHF"]
data["rel_y_2Y_CHFEUR"]=data["y_2Y_CHF"]-data["y_2Y_EUR"]



#Relative Yield curve: (3m-10y of country 1) - (3m-10y of country 2)

#y_slope_3M_

data["rel_slope_3M_EURUSD"]=data["y_slope_3M_EUR"]-data["y_slope_3M_USD"]
data["rel_slope_3M_USDEUR"]=data["y_slope_3M_USD"]-data["y_slope_3M_EUR"]

data["rel_slope_3M_GBPUSD"]=data["y_slope_3M_GBP"]-data["y_slope_3M_USD"]
data["rel_slope_3M_USDGBP"]=data["y_slope_3M_USD"]-data["y_slope_3M_GBP"]

data["rel_slope_3M_AUDUSD"]=data["y_slope_3M_AUD"]-data["y_slope_3M_USD"]
data["rel_slope_3M_USDAUD"]=data["y_slope_3M_USD"]-data["y_slope_3M_AUD"]

data["rel_slope_3M_EURNOK"]=data["y_slope_3M_EUR"]-data["y_slope_3M_NOK"]
data["rel_slope_3M_NOKEUR"]=data["y_slope_3M_NOK"]-data["y_slope_3M_EUR"]

data["rel_slope_3M_NZDUSD"]=data["y_slope_3M_NZD"]-data["y_slope_3M_USD"]
data["rel_slope_3M_USDNZD"]=data["y_slope_3M_USD"]-data["y_slope_3M_NZD"]

data["rel_slope_3M_CADUSD"]=data["y_slope_3M_CAD"]-data["y_slope_3M_USD"]
data["rel_slope_3M_USDCAD"]=data["y_slope_3M_USD"]-data["y_slope_3M_CAD"]

data["rel_slope_3M_JPYUSD"]=data["y_slope_3M_JPY"]-data["y_slope_3M_USD"]
data["rel_slope_3M_USDJPY"]=data["y_slope_3M_USD"]-data["y_slope_3M_JPY"]

data["rel_slope_3M_EURCHF"]=data["y_slope_3M_EUR"]-data["y_slope_3M_CHF"]
data["rel_slope_3M_CHFEUR"]=data["y_slope_3M_CHF"]-data["y_slope_3M_EUR"]

#y_2Y_SEK

print(data)
# Out:
#             fx_AUDUSD  fx_EURCHF  fx_EURNOK  fx_EURUSD  fx_GBPUSD  fx_NZDUSD  \
# date
# 2010-01-01     0.8980    1.48365     8.2811     1.4324     1.6151     0.7231
# 2010-01-04     0.9126    1.48440     8.2317     1.4413     1.6085     0.7344
# 2010-01-05     0.9119    1.48485     8.2128     1.4365     1.5992     0.7346
# 2010-01-06     0.9198    1.48064     8.1621     1.4408     1.6019     0.7378
# 2010-01-07     0.9174    1.47971     8.1749     1.4308     1.5933     0.7319
# ...               ...        ...        ...        ...        ...        ...
# 2021-11-17     0.7267    1.05076     9.9023     1.1319     1.3487     0.6998
# 2021-11-18     0.7277    1.05266    10.0223     1.1371     1.3494     0.7044
# 2021-11-19     0.7235    1.04786    10.0683     1.1290     1.3451     0.7004
# 2021-11-22     0.7225    1.04830    10.0319     1.1237     1.3397     0.6958
# 2021-11-23     0.7228    1.04983    10.0091     1.1248     1.3378     0.6949
#
# ...

# %%
rs=data
# now we can do regime swtich analysys
#df_rs=df

rs.to_csv (r'K:\2020_2431\q\sandbox_fx_g10\fx_g10_rs_111.csv', index = True, header=True)

# %%
#load fx database and then create  variations
#fx_rs = pd.read_csv (r'K:\2020_2431\q\sandbox\fx_tmp.csv')
#fx_rs.columns=['date','FX_BRL','FX_CLP','FX_CNH','FX_COP','FX_CZK','FX_IDR','FX_ILS','FX_INR','FX_KRW','FX_MXN',
#               'FX_PEN','FX_PLN','FX_RUB','FX_TRY','FX_ZAR','FX_THB','FX_TWD','FX_MYR','FX_PHP']
#fx_rs.rename(columns={'BBGTKR::BLOOMBERG::BRL CURNCY':'FX_BRL'}, inplace=True)
#print(fx_rs.columns)
#FX_BRL
#fx_rs['wv_FX_BRL']= ((fx_rs.FX_BRL.diff()) /(fx_rs.FX_BRL.shift())).round(6)
#fx_rs['wd_FX_BRL']= ((fx_rs.FX_BRL.diff())).round(6)
#print(fx_rs)
#l_msci_rs.rename(columns={'BBGTKR::BLOOMBERG::MXCL Index':'MSCI_CLP'}, inplace=True)
##MSCI_BRL
#l_msci_rs['wv_MSCI_BRL']= ((l_msci_rs.MSCI_BRL.diff()) /(l_msci_rs.MSCI_BRL.shift())).round(6)
#l_msci_rs['wd_MSCI_BRL']= ((l_msci_rs.MSCI_BRL.diff())).round(6)


#vix_rs = pd.read_csv (r'K:\2020_2431\q\sandbox\vix_tmp.csv')
#vix_rs.columns=['date','vix']
#vix_rs['wv_vix']= ((vix_rs.vix.diff()) /(vix_rs.vix.shift())).round(6)
#vix_rs['wd_vix']= ((vix_rs.vix.diff())).round(6)
#print(vix_rs)
#CONCTENATE ALL DATABASES
#cds_rs
#fx_rs
#l_msci_rs
#vix_rs
#msci_us_rs
#ust_rs

#rs=pd.merge(cds_rs, fx_rs,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
#print(rs.columns)
#rs=pd.merge(rs, l_msci_rs,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
#print(rs.columns)
#rs=pd.merge(rs, vix_rs,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
#print(rs.columns)
#rs=pd.merge(rs, msci_us_rs,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
#print(rs.columns)
#rs=pd.merge(rs, ust_rs,  how='left', left_on=['date'], right_on = ['date']).fillna(method='bfill')
#print(rs.columns)
#Run regressiosn of the residual 
#Residual local MSCI


#MSCI_CNH
#name_text=str("wv_MSCI_CNH")
#df['Y']=df["wv_MSCI_CNH"]
#name_text="res_"+name_text
#print(name_text)
#endog=df['Y']
#model = RollingOLS(endog =endog, exog=exog,window=w)
#rres = model.fit()
#params = rres.params
#df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
#df['res']=(df['Y']-df['pred'])
#df.rename(columns={'res':str(name_text)}, inplace=True)
#print(df.columns)

#run regresison to find residual of fx model
#residul local fx return

#FX_BRL
#name_text=str("wv_FX_BRL")
#df['Y']=df["wv_FX_BRL"]
#name_text="res_"+name_text
#print(name_text)
#endog=df['Y']
#model = RollingOLS(endog =endog, exog=exog,window=w)
#rres = model.fit()
#params = rres.params
#df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
#df['res']=(df['Y']-df['pred'])
#df.rename(columns={'res':str(name_text)}, inplace=True)
#print(df.columns)


#residual regional CDS
#wv_BRL_reg_cds5y
#name_text=str("wv_BRL_reg_cds5y")
#df['Y']=df["wv_BRL_reg_cds5y"]
#name_text="res_"+name_text
#print(name_text)
#endog=df['Y']
#model = RollingOLS(endog =endog, exog=exog,window=w)
#rres = model.fit()
#params = rres.params
#df['pred']=params.const+(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)
#df['res']=(df['Y']-df['pred'])
#df.rename(columns={'res':str(name_text)}, inplace=True)
#print(df.columns)

# %%
#a=rs.columns
#print(rs.columns)

#data.to_clipboard()
#print(rs)

print(data)
# Out:
#             fx_AUDUSD  fx_EURCHF  fx_EURNOK  fx_EURUSD  fx_GBPUSD  fx_NZDUSD  \
# date
# 2010-01-01     0.8980    1.48365     8.2811     1.4324     1.6151     0.7231
# 2010-01-04     0.9126    1.48440     8.2317     1.4413     1.6085     0.7344
# 2010-01-05     0.9119    1.48485     8.2128     1.4365     1.5992     0.7346
# 2010-01-06     0.9198    1.48064     8.1621     1.4408     1.6019     0.7378
# 2010-01-07     0.9174    1.47971     8.1749     1.4308     1.5933     0.7319
# ...               ...        ...        ...        ...        ...        ...
# 2021-11-17     0.7267    1.05076     9.9023     1.1319     1.3487     0.6998
# 2021-11-18     0.7277    1.05266    10.0223     1.1371     1.3494     0.7044
# 2021-11-19     0.7235    1.04786    10.0683     1.1290     1.3451     0.7004
# 2021-11-22     0.7225    1.04830    10.0319     1.1237     1.3397     0.6958
# 2021-11-23     0.7228    1.04983    10.0091     1.1248     1.3378     0.6949
#
# ...

# %%
#file location
location_first= ("K:\\2020_2431\\q\\fx_g10\\regime\\")
today = str(date.today())+"_"
location_last = '_fig.jpg'

#K:\2020_2431\q\fx_g10\regime
#title_graph="EM CDS - Rating Fit Model "
#x_label="Average Rating [S&P, Ftch, and Mdys]"
#y_label="CDS Value"

dateTimeObj = str(datetime.now())
print(dateTimeObj)


today = str(date.today())
print(today)
#time stamp
end = str(today)

title0="G10FX// Pre Regime Switch Model: G10FX explained by "
# Out:
# 2021-11-24 09:51:45.807498
# 2021-11-24

# %%
#Sovereign CDS weekly change explained by
#Res Local MSCI return 
#Res FX Exchange rate change
#Change in Rating
#Residual change in Regional SCDS
#Return SPX
#Change VIX
#Difference Treasury Yield

#rolling regression with a constantn
#make abosluties of all variables,
#then sum
#then estimate the percentage of each variable effect. 

#Residual Parameters
#Residual local MSCI
#residul local fx return
#residual regional CDS


#df=rs
#df['const'] = 1
#df['X1']=df['wv_vix']
#df['X2']=df['wv_ust']
#df['X3']=df['wv_msci_us']
#exog=df[['const','X1','X2','X3']]
##rolling window 12
#w=12
#df['const'] = 1

data['X4']=data["log_dv_oil"]
data['X5']=data['log_dv_msci_USD']


rs=data
df=rs
df=df.reset_index(level=0, inplace=True)
#df['X4']=df["log_dv_oil"]
#df['X5']=df['log_dv_msci_USD']

name_text_const='idiosyncratic'
name_text_X1="Relative Equities"
name_text_X2="Rate Differentials"
name_text_X3="Relative slope"
name_text_X4="Oil"
name_text_X5="World Equities"


#rolling window 
w=30
r=30
#parameter
parameter_t=20

#https://datascienceanywhere.medium.com/visualizing-time-series-data-in-python-e49fa5d10ea
#https://www.geeksforgeeks.org/create-a-stacked-bar-plot-in-matplotlib/



#VARAIBLES
#oil LOG(CL1 ) oil
#World Equities: log (msci mxaw)
#Relative equities:   log msci country 1 - log msci country 2
#Rates difference: log 2y rate country 1 - log 2y rate country 2
#Relative Yield curve: (3m-10y of country 1) - (3m-10y of country 2)



#y fx g10, dv_fx_EURUSD,  log_dv_fx_EURUSD log_dv_fx_GBPUSD
#x1 rel equi  rel_msci_EUR_USD
#X2 rate differ rel_log_y_2Y_CHF_EUR  rel_y_2Y_EUR_CHF
#x3 Relative Yield curve  rel_slope_3M_AUD_USD
#X4 OIL  log_dv_oil
#X5 WORLD EQUITIES log_dv_msci_USD

#z=df.head()
#z.to_clipboard()

# %%
parameter_t=20

# %%
#z.to_clipboard()
df=rs
df.to_clipboard()

a=df[str("log_dv_fx_"+str("EURUSD"))]

# %%
df['Y']=df[str("log_dv_fx_"+str("EURUSD"))]
#a=df["log_dv_fx_EURUSD"]

# %%
#wv_
####update!!!!
#del location

#lst = ['BRL','COP','MXN','CLP','PEN','CZK','HUF','PLN','RUB','ILS','ZAR','TRY','IDR','THB','MYR','KRW','PHP']
#lst2 = ['brazil','colombia','mexico','chile','peru','czech','hungary','poland','russia','israel','southafrica',
#       'turkey','indonesia','thailand','malaysia','korea','philippines']

list_x0=['EURUSD','GBPUSD','EURNOK','AUDUSD','NZDUSD','USDCAD','EURCHF']
#'USDJPY'




#list_im = ["fig_c_BRL4.jpg","fig_c_BRL5.jpg"]
lst=list_x0
for x in range(len(lst)):      
    country1=str(lst[x])  
    print(country1)
 
    
    name_text=str(country1)
    df['Y']=df[str("log_dv_fx_"+str(name_text))]
    df['X1']=df["rel_msci_"+str(country1)]
    df['X2']=df["rel_log_y_2Y_"+str(country1)]
    df['X3']=df["rel_slope_3M_"+str(country1)]
    
    location_first= ("K:\\2020_2431\\q\\fx_g10\\regime\\")
    today = str(date.today())+"_"
    location_last = '_fig.jpg'




    name_text_res="res_reg"+name_text
    name_text_reg="pred_reg"+name_text
    print(name_text)
    endog=df['Y']
    #exog=df[['const','X1','X2','X3','X4','X5']]
    exog=df[['X1','X2','X3','X4','X5']]
    model = RollingOLS(endog =endog, exog=exog,window=w)
    rres = model.fit()
    params = rres.params
    df['pred']=(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)+(df.X4*params.X4)+(df.X5*params.X5)
    #df['pred']=params.const +(df.X1*params.X1)+(df.X2*params.X2)+(df.X3*params.X3)+(df.X4*params.X4)+(df.X5*params.X5)
    df['res']=(df['Y']-df['pred'])
    df.rename(columns={'res':str(name_text_res)}, inplace=True)
    df.rename(columns={'pred':str(name_text_reg)}, inplace=True)
    print(df.columns)

    #df['abs_const']=abs(params.const) 
    df['abs_X1']=abs(df.X1*params.X1) 
    df['abs_X2']=abs(df.X2*params.X2) 
    df['abs_X3']=abs(df.X3*params.X3) 
    df['abs_X4']=abs(df.X4*params.X4) 
    df['abs_X5']=abs(df.X5*params.X5) 

    #df['sum_abs']=df[['abs_const','abs_X1','abs_X2','abs_X3','abs_X4','abs_X5']].sum(axis=1)
    df['sum_abs']=df[['abs_X1','abs_X2','abs_X3','abs_X4','abs_X5']].sum(axis=1)
    #df['p_abs_const']= (df['abs_const'] / df['sum_abs'])
    df['p_abs_X1']= (df['abs_X1'] / df['sum_abs'])
    df['p_abs_X2']= (df['abs_X2'] / df['sum_abs'])
    df['p_abs_X3']= (df['abs_X3'] / df['sum_abs'])
    df['p_abs_X4']= (df['abs_X4'] / df['sum_abs'])
    df['p_abs_X5']= (df['abs_X5'] / df['sum_abs'])


    #df['avg_p_abs_const']=df['p_abs_const'].rolling(r).mean()        
    df['avg_p_abs_X1']=df['p_abs_X1'].rolling(r).mean()
    df['avg_p_abs_X2']=df['p_abs_X2'].rolling(r).mean()
    df['avg_p_abs_X3']=df['p_abs_X3'].rolling(r).mean()
    df['avg_p_abs_X4']=df['p_abs_X4'].rolling(r).mean()
    df['avg_p_abs_X5']=df['p_abs_X5'].rolling(r).mean()


    #modify names
    name_text_g=name_text+" reg expl by "
    #name_text_const_g= name_text+" "+name_text_const
    name_text_X1_g=name_text+" "+name_text_X1
    name_text_X2_g=name_text+" "+name_text_X2
    name_text_X3_g=name_text+" "+name_text_X3
    name_text_X4_g=name_text+" "+name_text_X4
    name_text_X5_g=name_text+" "+name_text_X5


    #create nerw columsna nd then rename
    #df['avg_p_abs_const_g']=df['avg_p_abs_const']
    df['avg_p_abs_X1_g']=df['avg_p_abs_X1']
    df['avg_p_abs_X2_g']=df['avg_p_abs_X2']
    df['avg_p_abs_X3_g']=df['avg_p_abs_X3']
    df['avg_p_abs_X4_g']=df['avg_p_abs_X4']
    df['avg_p_abs_X5_g']=df['avg_p_abs_X5']


    #rename for finalt table
    #df.rename(columns={'avg_p_abs_const':str(name_text_const_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X1':str(name_text_X1_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X2':str(name_text_X2_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X3':str(name_text_X3_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X4':str(name_text_X4_g)}, inplace=True)
    df.rename(columns={'avg_p_abs_X5':str(name_text_X5_g)}, inplace=True)


    #stached bar 
    title=title0+name_text_g+end
    y_label="Percentage"
    x_label=" time series "+" "+end
    location1=location_first+name_text_g+location_last
    print(location1)
    #g=df[['date','avg_p_abs_const_g','avg_p_abs_X1_g','avg_p_abs_X2_g',
    #      'avg_p_abs_X3_g','avg_p_abs_X4_g','avg_p_abs_X5_g']]
    g=df[['date','avg_p_abs_X1_g','avg_p_abs_X2_g',
          'avg_p_abs_X3_g','avg_p_abs_X4_g','avg_p_abs_X5_g']]
    
    fig,ax = plt.subplots(figsize=(15,6))
    df1 = g.set_index('date')
    df1.plot(kind='area',ax=ax,stacked=True,color=['orange','blue','green',"yellow","black","brown"])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=8)
    plt.legend(loc="lower left")
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(location1, bbox_inches='tight')
    del location1

    ##varaible1
    title=title0+name_text_X1_g+end
    y_label="Percentage"
    x_label=name_text_X1+" time series"+" "+end
    name0=name_text_X1_g
    locationx1=location_first+name0+location_last
    print(locationx1)

    g=df[['date','avg_p_abs_X1_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['orange'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=8)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx1, bbox_inches='tight')
    del locationx1
    del name0

    ##varaible2 (/4)
    title=title0+name_text_X2_g+end
    y_label="Percentage"
    x_label=name_text_X2+" time series"+" "+end
    name0=name_text_X2_g
    locationx2=location_first+name0+location_last
    print(locationx2)
    g=df[['date','avg_p_abs_X2_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['blue'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=8)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx2, bbox_inches='tight')
    del locationx2
    del name0

    ##varaible3 (/4)
    title=title0+name_text_X3_g+end
    y_label="Percentage"
    x_label=name_text_X3+" time series"+" "+end
    name0=name_text_X3_g
    locationx3=location_first+name0+location_last
    print(locationx3)
    g=df[['date','avg_p_abs_X3_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['green'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=8)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx3, bbox_inches='tight')
    del locationx3
    del name0

    ##varaible4 (/4)
    title=title0+name_text_X4_g+end
    y_label="Percentage"
    x_label=name_text_X4+" time series"+" "+end
    name0=name_text_X4_g
    locationx4=location_first+name0+location_last
    print(locationx4)
    g=df[['date','avg_p_abs_X4_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['yellow'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=8)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx4, bbox_inches='tight')
    del locationx4
    del name0

    ##varaible5 (/4)
    title=title0+name_text_X5_g+end
    y_label="Percentage"
    x_label=name_text_X5+" time series"+" "+end
    name0=name_text_X5_g
    locationx5=location_first+name0+location_last
    print(locationx5)
    g=df[['date','avg_p_abs_X5_g']]
    df1 = g.set_index('date') # setting "Years" as index
    fig,ax = plt.subplots(figsize=(15,6))
    #df1.plot(kind='line',ax=ax)
    df1.plot(kind='area',ax=ax,color=['black'])
    plt.ylabel(str(y_label), size=20)
    plt.xlabel(str(x_label), size=8)
    plt.title(str(title), size=parameter_t)
    plt.grid()
    plt.savefig(locationx5, bbox_inches='tight')
    del locationx5
    del name0


print("Complete")
# Out:
# EURUSD
# EURUSD
# Index(['date', 'fx_AUDUSD', 'fx_EURCHF', 'fx_EURNOK', 'fx_EURUSD', 'fx_GBPUSD',
#        'fx_NZDUSD', 'fx_USDCAD', 'fx_USDJPY', 'dv_fx_EURUSD',
#        ...
#        'rel_slope_3M_EURCHF', 'rel_slope_3M_CHFEUR', 'X4', 'X5', 'Y', 'X1',
#        'X2', 'X3', 'pred_regEURUSD', 'res_regEURUSD'],
#       dtype='object', length=332)
# K:\2020_2431\q\fx_g10\regime\EURUSD reg expl by _fig.jpg
# K:\2020_2431\q\fx_g10\regime\EURUSD Relative Equities_fig.jpg
# K:\2020_2431\q\fx_g10\regime\EURUSD Rate Differentials_fig.jpg
# K:\2020_2431\q\fx_g10\regime\EURUSD Relative slope_fig.jpg
# K:\2020_2431\q\fx_g10\regime\EURUSD Oil_fig.jpg
# K:\2020_2431\q\fx_g10\regime\EURUSD World Equities_fig.jpg
# GBPUSD
# GBPUSD
# C:\Anaconda_2020.11\lib\site-packages\statsmodels\regression\rolling.py:365: RuntimeWarning: invalid value encountered in subtract
#   xpx -= remove_x.T @ remove_x
# ...

# %%
###https://stackoverflow.com/questions/30227466/combine-several-images-horizontally-with-python
#part 3 pdf ALL COUNTRUES
os.chdir('K:/2020_2431/q/fx_g10/regime')
print(os.getcwd())


#K:\2020_2431\q\fx_g10\regime  
final_location_first = ("K:\\2020_2431\\q\\fx_g10\\regime\\report_f\\001")
final_location_last = '.pdf'

#GBPUSD Relative Equities_fig
#GBPUSD Relative slope_fig
#GBPUSD World Equities_fig
#GBPUSD Rate Differentials_fig
#EURCHF Oil_fig##

#name_text_const='idiosyncratic'
#name_text_X1="Relative Equities"
#name_text_X2="Rate Differentials"
#name_text_X3="Relative slope"
#name_text_X4="Oil"
#name_text_X5="World Equities"


list_x0=['EURUSD','GBPUSD','EURNOK','AUDUSD','NZDUSD','USDCAD','EURCHF']    
#list_im = ["fig_c_BRL4.jpg","fig_c_BRL5.jpg"]



lst=list_x0
for x in range(len(lst)):      
    country=str(lst[x])  

    
    fig0=str(country)+" reg expl by _fig.jpg"
    fig1=str(country)+" Relative Equities_fig.jpg"
    fig2=str(country)+" Rate Differentials_fig.jpg"
    fig3=str(country)+" Relative slope_fig.jpg"
    fig4=str(country)+" Oil_fig.jpg"
    fig5=str(country)+" World Equities_fig.jpg"
    fig6=str(country)+" reg expl by _fig.jpg"
    fig7=str(country)+"_1.jpg"
    fig8=str(country)+"_2.jpg"
    fig9=str(country)+"_3.jpg"
    fig10=str(country)+"_f.jpg"


    #cds
    #######
    list_im = [str(fig1),str(fig2),str(fig3)]
    imgs    = [ PIL.Image.open(i) for i in list_im ]
    # pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
    min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
    imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

    # save that beautiful picture
    imgs_comb = np.vstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( str(fig7) )    


    #######
    list_im = [str(fig4),str(fig5),str(fig6)]
    imgs    = [ PIL.Image.open(i) for i in list_im ]
    # pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
    min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
    imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

    # save that beautiful picture
    imgs_comb = np.vstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( str(fig8) )   

    ######

    list_im = [str(fig7),str(fig8)]
    imgs    = [ PIL.Image.open(i) for i in list_im ]
    # pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
    min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
    imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

    # save that beautiful picture
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( str(fig9) ) 
    
    #######
    list_im = [str(fig0),str(fig9)]
    imgs    = [ PIL.Image.open(i) for i in list_im ]
    # pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
    min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
    imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

    # save that beautiful picture
    imgs_comb = np.vstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( str(fig10) )  
    imgs_comb.save( str(final_location_first+country+final_location_last) ) 
    

    
    
    
    
    
    
    

print("Complete")  


#df.to_csv (r'K:\2020_2431\q\sandbox\cds_rs_2.csv', index = False, header=True)
    
#asbo of all variables, 
#summ all absoletes
#and then dividend
#take out the residual, rename it as idyosunceratic
#then make an average



#print(endog.head())
#print(endog.tail())
#print(exog.head())
#print(exog.tail())
#model = pd.stats.ols.MovingOLS(y=df.Y, x=df[['X1', 'X2', 'X3']],window_type='rolling', window=100, intercept=True)
#df['Y_hat'] = model.y_predict
#print(df.head())
#print(df.tail())
#print(df)
#df=rs[['wv_MSCI_BRL','wv_vix','wv_ust','wv_msci_us']]
#>>> from statsmodels.regression.rolling import RollingOLS
#>>> from statsmodels.datasets import longley
#>>> data = longley.load(as_pandas=False)
#>>> exog = add_constant(data.exog, prepend=False)
#>>> mod = RollingOLS(data.endog, exog)
#>>> rolling_res = mod.fit(reset=50)
# Out:
# K:\2020_2431\q\fx_g10\regime
# <ipython-input-21-7b46cb5f7ce3>:54: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
# <ipython-input-21-7b46cb5f7ce3>:57: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   imgs_comb = np.vstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
# <ipython-input-21-7b46cb5f7ce3>:67: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
# ...

# %%
#del location
#del name_text
#print(location)
#print(location_first)
#print(name_text)
#print(location_last)

# %%
#pip install main

# %%
#https://www.statsmodels.org/devel/examples/notebooks/generated/markov_regression.html
#https://matplotlib.org/2.0.2/examples/pylab_examples/fill_between_demo.html
  
# Specifically, in the good state, the weekly SCDS spread changes are mainly determined by local,
#regional and fundamental factors; whereas global variables have a stronger influence in the
#bad regime#

#In particular, US market returns play a dominant role in influencing the SCDS spread
#change in the bad state suggesting loss aversion and flight–to–quality behavior of investors.


#Ammer and Cai [2] examine the
#relationship between SCDS spreads and bond yields for nine emerging market sovereigns and find that
#these two measures of credit risk deviate significantly in the short run with the former leading the later in
#price discovery. They attribute such deviation to the higher liquidity in trading of SCDS.


#The good state is defined as
#the market condition that is characterized by tightening SCDS spreads (negative changes) and low
#volatility, while the bad state is the market condition with widening SCDS spreads (positive changes)
#and high volatility



#Si icnorpaor intereceptieopsn 
# es una regreison de markiov escondidad
#X1'res_wv_BRL_reg_cds5y',------RES REGIONAL +  (POSITIVE)
#X2'res_wv_FX_BRL',------RES FX + POSTIVE (POSITIVE)
#X3'res_wv_MSCI_BRL',----RES LOCAL MSCI -NEGATIVE 
#X4'wv_vix',------VIX +(MIXED IN PAPER REGRESSION)
#X5'wd_ust',-------UST + (MOSTLY NEGATIVE)
#X6'wv_msci_us']]-----SPX - NEGATIVE

# %%
#K:\2020_2431\q\fx_g10\regime\report_f2


import subprocess

src=r'K:\2020_2431\q\fx_g10\regime\report_f\001AUDUSD.pdf'
dst=r'K:\2020_2431\q\fx_g10\regime\report_f\group1\001AUDUSD.pdf'
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


src=r'K:\2020_2431\q\fx_g10\regime\report_f\001EURCHF.pdf'
dst=r'K:\2020_2431\q\fx_g10\regime\report_f\group1\001EURCHF.pdf'
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


src=r'K:\2020_2431\q\fx_g10\regime\report_f\001EURNOK.pdf'
dst=r'K:\2020_2431\q\fx_g10\regime\report_f\group1\001EURNOK.pdf'
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)



src=r'K:\2020_2431\q\fx_g10\regime\report_f\001EURUSD.pdf'
dst=r'K:\2020_2431\q\fx_g10\regime\report_f\group2\001EURUSD.pdf'
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)

src=r'K:\2020_2431\q\fx_g10\regime\report_f\001GBPUSD.pdf'
dst=r'K:\2020_2431\q\fx_g10\regime\report_f\group2\001GBPUSD.pdf'
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)


src=r'K:\2020_2431\q\fx_g10\regime\report_f\001NZDUSD.pdf'
dst=r'K:\2020_2431\q\fx_g10\regime\report_f\group2\001NZDUSD.pdf'
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)



src=r'K:\2020_2431\q\fx_g10\regime\report_f\001USDCAD.pdf'
dst=r'K:\2020_2431\q\fx_g10\regime\report_f\group2\001USDCAD.pdf'
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)

# %%
source_dir = 'K:/2020_2431/q/fx_g10/regime/report_f/group1/'
source_dir2 = 'K:/2020_2431/q/fx_g10/regime/report_f2/'

merger = PdfFileMerger()
for item in os.listdir(source_dir):
    if item.endswith('pdf'):
        #print(item)
        merger.append(source_dir + item)

merger.write(source_dir2 + 'R_Regimeswitch_Complete1.pdf')       
merger.close()
print("Complete!!!!")


source_dir = 'K:/2020_2431/q/fx_g10/regime/report_f/group2/'
source_dir2 = 'K:/2020_2431/q/fx_g10/regime/report_f2/'

merger = PdfFileMerger()
for item in os.listdir(source_dir):
    if item.endswith('pdf'):
        #print(item)
        merger.append(source_dir + item)

merger.write(source_dir2 + 'R_Regimeswitch_Complete2.pdf')       
merger.close()
print("Complete!!!!")
# Out:
# Complete!!!!
# Complete!!!!

# %%
#source_dir2 = 'K:/2020_2431/q/cds_report/images/rs/report_f2/'
#os.chdir('K:/2020_2431/q/cds_report/images/rs/report_f')
#os.chdir('K:/2020_2431/q/cds_report/images/rs')
#final_location_first = ("K:\\2020_2431\\q\\cds_report\\images\\rs\\report_f\\001")
#cds_rs.to_csv (r'K:\2020_2431\q\sandbox\cds_rs_0.csv', index = False, header=True)

#location_first= ("K:\\2020_2431\\q\\cds_report\\images\\rs\\")


#res.summary()
#print(res_filardo)
# Note that tables is a list. The table at index 1 is the "core" table. Additionally, read_html puts dfs in a list, so we want index 0
#results_as_html = summary.tables[1].as_html()
#pd.read_html(results_as_html, header=0, index_col=0)[0]#
#results_as_html1 = summary.tables[0].as_html()
#pd.read_html(results_as_html1, header=0, index_col=0)[0]
#dfi.export(results_as_html1, 'df_styled.png')
#summary=summary.as_latex() 
#summary1=summary.as_latex_tabular
#summary.generate_pdf('basic_maketitle2', clean_tex=False)

# %%
import subprocess

src=r'K:\2020_2431\q\fx_g10\regime\report_f2\R_Regimeswitch_Complete1.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\g10_fx\R_Regimeswitch_Complete1.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)



src=r'K:\2020_2431\q\fx_g10\regime\report_f2\R_Regimeswitch_Complete2.pdf'
dst=r'P:\Technology\AlphaQuant\pdf_render_svc_files\AlanM\g10_fx\R_Regimeswitch_Complete2.pdf'  
cmd='copy "%s" "%s"' % (src, dst)
status = subprocess.call(cmd, shell=True)

# %%
#ax.fill_between(a.index, 0, 1,  color="gray", alpha=0.9)
#ax.fill_between(x, 0, 1, where=y.values, color="k", alpha=0.1)
#ax.fill_between(usrec.index, 0, 1, where=usrec["USREC"].values, color="k", alpha=0.1)
#ax.fill_between(x, 0, y, where=y<-0.1, color="k")
#ax.fill_between(x, 0, 1, where=y<-0.1, facecolor='red', alpha=0.5)
#ax.axhline(-theta, color='green', lw=1, alpha=0.8)

# %%
#mod_filardo = sm.tsa.MarkovAutoregression(a,k_regimes=2,order=1,switching_ar=False,exog_tvtp=b,)
##np.random.seed(12345)
#res_filardo = mod_filardo.fit(search_reps=20)
##res_filardo.summary()
#fig, ax = plt.subplots(figsize=(12, 3))
#ax.plot(res_filardo.smoothed_marginal_probabilities[0])
##ax.fill_between(usrec.index, 0, 1, where=usrec["USREC"].values, color="gray", alpha=0.2)
##ax.set_xlim(dta_filardo.index[6], dta_filardo.index[-1])
#ax.set(title="Smoothed probability of a xxx state")
#plt.savefig("asd1.jpg", bbox_inches='tight')
## Fit the 2-regime model
#mod_fedfunds3 = sm.tsa.MarkovRegression(dta_fedfunds.iloc[4:], k_regimes=2, exog=exog)
#res_fedfunds3 = mod_fedfunds3.fit()

# %%
# Do something
timeclock.stop()
#Elapsed time: 397.8075 seconds
#Elapsed time: 398.0356 seconds
# Out:
# Elapsed time: 70.2837 seconds
# 70.28366460000001
